# %%
import sys
sys.path.insert(0, "/global/u1/p/prakharb/desilike")

# %%
import desilike, inspect
print(inspect.getfile(desilike))
# Out:
# /global/u1/p/prakharb/desilike/desilike/__init__.py

# %%
import re
import os
import numpy as np
from scipy import interpolate
import matplotlib.pyplot as plt
from desilike.jax import numpy as jnp
from desilike.jax import jit, interp1d
from desilike import jax
from desilike import plotting, utils, BaseCalculator
from desilike.theories.galaxy_clustering.base import BaseTheoryPowerSpectrumMultipolesFromWedges, BaseTheoryPowerSpectrumMultipoles
from desilike.theories.galaxy_clustering.full_shape import BasePTPowerSpectrumMultipoles, FOLPSPowerSpectrumMultipoles, BaseTracerPowerSpectrumMultipoles
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# from .base import BaseTheoryPowerSpectrumMultipoles, BaseTheoryCorrelationFunctionMultipoles, BaseTheoryCorrelationFunctionFromPowerSpectrumMultipoles
# from .power_template import DirectPowerSpectrumTemplate, StandardPowerSpectrumTemplate

# %%
from desilike.theories.galaxy_clustering.full_shape import DirectPowerSpectrumTemplate, KaiserTracerPowerSpectrumMultipoles, SimpleTracerPowerSpectrumMultipoles, FOLPSAXTracerPowerSpectrumMultipoles,FOLPSTracerPowerSpectrumMultipoles,FOLPSv2TracerPowerSpectrumMultipoles
from desilike.observables.galaxy_clustering import TracerPowerSpectrumMultipolesObservable
from desilike.likelihoods import ObservablesGaussianLikelihood
from desilike.parameter import ParameterCollection
from desilike import setup_logging
# from desilike_private.theories.galaxy_clustering.full_shape import FOLPSv2TracerPowerSpectrumMultipoles

z=1.
rot= np.array([[2/3,-2/3],[0,1]])
template = DirectPowerSpectrumTemplate(z=z, fiducial='DESI')
for param in ['omega_b', 'n_s']: template.params[param].update(fixed=True)
template.init.params['m_ncdm'].update(value=0.06)

# theory = FOLPSAXPowerSpectrumMultipoles(template=template)
theory2 = FOLPSv2TracerPowerSpectrumMultipoles(template=template,prior_basis='standard',kernels='fk',ells=[0,2,4,6,8])
theory3 = FOLPSv2TracerPowerSpectrumMultipoles(template=template,prior_basis='standard',kernels='fk')

# theory.compute()

# %%
theory2.all_params['b2'].value
# Out:
# ✅ Using NumPy with CPU.
# Loading matrices from matrices_nfftlog128_Afull_True_remove-DeltaP_False.npy
# /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/code/cosmoprimo/main/lib/python3.10/site-packages/cosmoprimo/eisenstein_hu.py:25: UserWarning: EisensteinHuNoWiggleEngine cannot cope with massive neutrinos
#   warnings.warn('{} cannot cope with massive neutrinos'.format(self.__class__.__name__))
# Loading matrices from matrices_nfftlog128_Afull_True_remove-DeltaP_False.npy
# 0.0

# %%
theory2()
# Out:
# Array([[ 2.62367778e+04,  2.78331726e+04,  2.87755310e+04,
#          2.91803590e+04,  2.91451389e+04,  2.87589481e+04,
#          2.80966216e+04,  2.72289430e+04,  2.62168110e+04,
#          2.51128892e+04,  2.39633037e+04,  2.28054610e+04,
#          2.16704563e+04,  2.05811595e+04,  1.95550753e+04,
#          1.86030782e+04,  1.77328470e+04,  1.69466129e+04,
#          1.62427690e+04,  1.56174765e+04,  1.50651163e+04,
#          1.45787126e+04,  1.41502880e+04,  1.37704022e+04,
#          1.34295553e+04,  1.31189482e+04,  1.28300707e+04,
#          1.25549935e+04,  1.22866465e+04,  1.20190495e+04,
#          1.17472063e+04,  1.14678026e+04,  1.11785515e+04,
#          1.08787226e+04,  1.05683845e+04,  1.02488872e+04,
#          9.92214611e+03,  9.59113804e+03,  9.25907630e+03,
#          8.92943346e+03,  8.60571294e+03,  8.29110228e+03,
#          7.98858522e+03,  7.70071119e+03,  7.42931452e+03,
#          7.17605617e+03,  6.94186487e+03,  6.72732179e+03,
#          6.53259466e+03,  6.35674362e+03,  6.19864306e+03,
#          6.05696272e+03,  5.93005426e+03,  5.81624812e+03,
#          5.71374076e+03,  5.62054681e+03,  5.53468230e+03,
#          5.45425435e+03,  5.37751694e+03,  5.30275049e+03,
#          5.22837597e+03,  5.15330537e+03,  5.07657202e+03,
#          4.99724913e+03,  4.91494955e+03,  4.82972700e+03,
#          4.74164688e+03,  4.65086599e+03,  4.55797795e+03,
#          4.46369975e+03,  4.36874044e+03,  4.27382471e+03,
#          4.17973704e+03,  4.08726577e+03,  3.99719026e+03,
#          3.91020150e+03,  3.82674417e+03,  3.74721354e+03,
#          3.67200044e+03,  3.60143466e+03,  3.53548703e+03,
#          3.47399030e+03,  3.41677901e+03,  3.36368746e+03,
#          3.31444621e+03,  3.26864250e+03,  3.22585729e+03,
#          3.18567665e+03,  3.14769301e+03,  3.11151453e+03,
#          3.07676006e+03,  3.04305267e+03,  3.01002000e+03,
#          2.97730651e+03,  2.94468168e+03,  2.91198767e+03,
#          2.87906842e+03,  2.84576908e+03,  2.81194163e+03,
#          2.77758069e+03,  2.74283313e+03],
#        [ 1.74675369e+04,  1.85083647e+04,  1.91100257e+04,
#          1.93516548e+04,  1.92993960e+04,  1.90136108e+04,
#          1.85452184e+04,  1.79423242e+04,  1.72461133e+04,
#          1.64919577e+04,  1.57106800e+04,  1.49271549e+04,
#          1.41618203e+04,  1.34295135e+04,  1.27413985e+04,
#          1.21041976e+04,  1.15224401e+04,  1.09970797e+04,
#          1.05265835e+04,  1.01079973e+04,  9.73726510e+03,
#          9.40952317e+03,  9.11934608e+03,  8.86050065e+03,
#          8.62682178e+03,  8.41268378e+03,  8.21275832e+03,
#          8.02217720e+03,  7.83669946e+03,  7.65283948e+03,
#          7.46777707e+03,  7.27975281e+03,  7.08764467e+03,
#          6.89125689e+03,  6.69085102e+03,  6.48739650e+03,
#          6.28214790e+03,  6.07688334e+03,  5.87346017e+03,
#          5.67378044e+03,  5.47970433e+03,  5.29282843e+03,
#          5.11457161e+03,  4.94606980e+03,  4.78802149e+03,
#          4.64100701e+03,  4.50519240e+03,  4.38054502e+03,
#          4.26683108e+03,  4.16330461e+03,  4.06914386e+03,
#          3.98346574e+03,  3.90528879e+03,  3.83364346e+03,
#          3.76755661e+03,  3.70604430e+03,  3.64815081e+03,
#          3.59301321e+03,  3.53990340e+03,  3.48813104e+03,
#          3.43709581e+03,  3.38645188e+03,  3.33592348e+03,
#          3.28526244e+03,  3.23442706e+03,  3.18353605e+03,
#          3.13270949e+03,  3.08208762e+03,  3.03191542e+03,
#          2.98245733e+03,  2.93396202e+03,  2.88665356e+03,
#          2.84071833e+03,  2.79632358e+03,  2.75361968e+03,
#          2.71271005e+03,  2.67359711e+03,  2.63625927e+03,
#          2.60066709e+03,  2.56677229e+03,  2.53445784e+03,
#          2.50358474e+03,  2.47401837e+03,  2.44562847e+03,
#          2.41828731e+03,  2.39187078e+03,  2.36626309e+03,
#          2.34135770e+03,  2.31706010e+03,  2.29331050e+03,
#          2.27007268e+03,  2.24731782e+03,  2.22502500e+03,
#          2.20318338e+03,  2.18180499e+03,  2.16091344e+03,
#          2.14053381e+03,  2.12069301e+03,  2.10141984e+03,
#          2.08273449e+03,  2.06464403e+03],
#        [ 1.38762786e+03,  1.46594813e+03,  1.50861055e+03,
#          1.52223206e+03,  1.51236965e+03,  1.48408898e+03,
#          1.44168525e+03,  1.38918341e+03,  1.32999562e+03,
#          1.26700826e+03,  1.20269059e+03,  1.13899535e+03,
#          1.07747410e+03,  1.01920629e+03,  9.64955312e+02,
#          9.15126129e+02,  8.69937718e+02,  8.29339220e+02,
#          7.93100777e+02,  7.60897477e+02,  7.32338866e+02,
#          7.06994485e+02,  6.84415189e+02,  6.64125335e+02,
#          6.45679352e+02,  6.28690834e+02,  6.12819079e+02,
#          5.97774310e+02,  5.83326141e+02,  5.69307687e+02,
#          5.55604164e+02,  5.42167789e+02,  5.28988119e+02,
#          5.16100638e+02,  5.03558516e+02,  4.91436849e+02,
#          4.79812767e+02,  4.68765876e+02,  4.58365840e+02,
#          4.48661377e+02,  4.39686317e+02,  4.31446250e+02,
#          4.23927038e+02,  4.17096923e+02,  4.10902768e+02,
#          4.05284042e+02,  4.00167840e+02,  3.95475661e+02,
#          3.91130221e+02,  3.87062074e+02,  3.83206612e+02,
#          3.79509867e+02,  3.75932479e+02,  3.72441014e+02,
#          3.69016414e+02,  3.65656954e+02,  3.62367182e+02,
#          3.59160910e+02,  3.56062622e+02,  3.53101321e+02,
#          3.50309529e+02,  3.47719782e+02,  3.45365373e+02,
#          3.43280391e+02,  3.41485731e+02,  3.39989660e+02,
#          3.38798803e+02,  3.37914627e+02,  3.37318640e+02,
#          3.36984864e+02,  3.36885015e+02,  3.36986037e+02,
#          3.37246465e+02,  3.37622361e+02,  3.38068253e+02,
#          3.38539880e+02,  3.39000978e+02,  3.39417101e+02,
#          3.39753883e+02,  3.39980010e+02,  3.40084178e+02,
#          3.40063879e+02,  3.39917830e+02,  3.39646064e+02,
#          3.39255761e+02,  3.38763312e+02,  3.38186513e+02,
#          3.37544003e+02,  3.36855296e+02,  3.36140544e+02,
#          3.35420014e+02,  3.34714027e+02,  3.34043008e+02,
#          3.33426642e+02,  3.32875493e+02,  3.32394314e+02,
#          3.31987281e+02,  3.31658109e+02,  3.31409858e+02,
#          3.31239042e+02,  3.31135321e+02],
#        [-9.17946380e-01, -1.33089415e+00, -1.77781805e+00,
#         -2.23092848e+00, -2.66252342e+00, -3.04756963e+00,
#         -3.36446496e+00, -3.59751753e+00, -3.73663229e+00,
#         -3.77752811e+00, -3.72196061e+00, -3.57641767e+00,
#         -3.35164803e+00, -3.06055901e+00, -2.71796644e+00,
#         -2.33863481e+00, -1.93771335e+00, -1.52826222e+00,
#         -1.12086234e+00, -7.23711888e-01, -3.42343629e-01,
#          2.04468284e-02,  3.64604232e-01,  6.93642645e-01,
#          1.01331339e+00,  1.33071324e+00,  1.65461208e+00,
#          1.99461607e+00,  2.36059197e+00,  2.76208416e+00,
#          3.20797237e+00,  3.70482753e+00,  4.25751955e+00,
#          4.86791420e+00,  5.53593195e+00,  6.25820961e+00,
#          7.02960957e+00,  7.84191645e+00,  8.68579268e+00,
#          9.55055261e+00,  1.04249863e+01,  1.12981141e+01,
#          1.21591689e+01,  1.29984370e+01,  1.38081921e+01,
#          1.45813064e+01,  1.53130395e+01,  1.59999254e+01,
#          1.66400258e+01,  1.72352238e+01,  1.77882829e+01,
#          1.83029393e+01,  1.87841816e+01,  1.92371807e+01,
#          1.96675529e+01,  2.00813787e+01,  2.04846894e+01,
#          2.08828669e+01,  2.12801184e+01,  2.16803484e+01,
#          2.20867962e+01,  2.25006810e+01,  2.29226046e+01,
#          2.33529121e+01,  2.37903298e+01,  2.42322947e+01,
#          2.46761722e+01,  2.51192117e+01,  2.55582661e+01,
#          2.59901990e+01,  2.64120358e+01,  2.68212555e+01,
#          2.72163229e+01,  2.75960840e+01,  2.79596453e+01,
#          2.83067064e+01,  2.86381693e+01,  2.89552999e+01,
#          2.92595455e+01,  2.95525723e+01,  2.98363639e+01,
#          3.01129975e+01,  3.03845484e+01,  3.06530727e+01,
#          3.09200875e+01,  3.11863093e+01,  3.14522740e+01,
#          3.17183731e+01,  3.19847861e+01,  3.22509456e+01,
#          3.25157810e+01,  3.27780944e+01,  3.30365506e+01,
#          3.32896495e+01,  3.35356748e+01,  3.37728373e+01,
#          3.39993521e+01,  3.42134309e+01,  3.44133123e+01,
#          3.45982452e+01,  3.47686299e+01],
#        [ 2.43217778e-03,  5.02628673e-03,  9.14749280e-03,
#          1.51547113e-02,  2.33525839e-02,  3.39702337e-02,
#          4.71419716e-02,  6.28944667e-02,  8.11485794e-02,
#          1.01729382e-01,  1.24383271e-01,  1.48802490e-01,
#          1.74657188e-01,  2.01624281e-01,  2.29412646e-01,
#          2.57776407e-01,  2.86530592e-01,  3.15554672e-01,
#          3.44793639e-01,  3.74254163e-01,  4.03993642e-01,
#          4.34105051e-01,  4.64699974e-01,  4.95886016e-01,
#          5.27754467e-01,  5.60369106e-01,  5.93749673e-01,
#          6.27863365e-01,  6.62615756e-01,  6.97854695e-01,
#          7.33378169e-01,  7.68933623e-01,  8.04239869e-01,
#          8.39000079e-01,  8.72918807e-01,  9.05724282e-01,
#          9.37178958e-01,  9.67124436e-01,  9.95453646e-01,
#          1.02216371e+00,  1.04731149e+00,  1.07104073e+00,
#          1.09356250e+00,  1.11513427e+00,  1.13606319e+00,
#          1.15668190e+00,  1.17732660e+00,  1.19833539e+00,
#          1.22001685e+00,  1.24257883e+00,  1.26619934e+00,
#          1.29098547e+00,  1.31693473e+00,  1.34400728e+00,
#          1.37207536e+00,  1.40090309e+00,  1.43021713e+00,
#          1.45969397e+00,  1.48895484e+00,  1.51759828e+00,
#          1.54522088e+00,  1.57148053e+00,  1.59605365e+00,
#          1.61862523e+00,  1.63901084e+00,  1.65714639e+00,
#          1.67298986e+00,  1.68654832e+00,  1.69799013e+00,
#          1.70754480e+00,  1.71546275e+00,  1.72202720e+00,
#          1.72756465e+00,  1.73241250e+00,  1.73691607e+00,
#          1.74139943e+00,  1.74609197e+00,  1.75119466e+00,
#          1.75689921e+00,  1.76336936e+00,  1.77062800e+00,
#          1.77863285e+00,  1.78732754e+00,  1.79664130e+00,
#          1.80645927e+00,  1.81661673e+00,  1.82694246e+00,
#          1.83726118e+00,  1.84739616e+00,  1.85720802e+00,
#          1.86659034e+00,  1.87544636e+00,  1.88368741e+00,
#          1.89123957e+00,  1.89811359e+00,  1.90437789e+00,
#          1.91011424e+00,  1.91541616e+00,  1.92038730e+00,
#          1.92512010e+00,  1.92968857e+00]], dtype=float64)

# %%
theory2.init.params['b2'].update(value=2.)
theory2.init.params['b3'].update(value=-2)
# theory3.init.params['X_FoG_p'].update(value=0.)

# %%
# theory2.template.init.params['m_ncdm'].update(value=0.4)
# theory3.template.init.params['m_ncdm'].update(value=0.4)
import matplotlib.pyplot as plt
a,b,c,_,_=theory2()
d,e,f= theory3()
k=theory2.k

plt.plot(k,k*a)
plt.plot(k,k*d)
# Out:
# Loading matrices from matrices_nfftlog128_Afull_True_remove-DeltaP_False.npy
# Loading matrices from matrices_nfftlog128_Afull_True_remove-DeltaP_False.npy

# %%
import matplotlib.pyplot as plt
import numpy as np
k=theory2.k
# Compute relative difference
rel_diff = (k*a - k*P0) / (k*P0)  # Assuming a = desilike P0, P0 = FOLPS P0
rel_diff2 = (k*b - k*P2) / (k*P2)  # Assuming b = desilike P0, P0 = FOLPS P0

# Create figure and axes
fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True,
                               gridspec_kw={'height_ratios': [3, 1]},
                               figsize=(7, 6),
                               constrained_layout=True)

# --- Top panel: k * P_ell(k)
ax1.plot(k, k*a, label='Desilike fk l=0', c='r')
ax1.plot(k, k*P0, label='FOLPS fk l=0', ls=":", lw=4, c='r')

ax1.plot(k, k*b, label='Desilike fk l=2', c='b')
ax1.plot(k, k*P2, label='FOLPS fk l=2', ls=":", lw=4, c='b')

ax1.set_ylabel(r'$k P_{\ell}(k) \, [h^{-1} \, \mathrm{Mpc}]^2$', fontsize=14)
# ax1.set_title(r'$\ell = 0$', fontsize=14)
ax1.legend()
ax1.grid(True)

# --- Bottom panel: relative difference
ax2.plot(k, rel_diff * 100, color='r', label='l=0')
ax2.plot(k, rel_diff2 * 100, color='b',label='l=2')
ax2.axhline(0, color='gray', lw=1, ls='--')
ax2.set_xlabel(r'$k \, [h\, \mathrm{Mpc}^{-1}]$', fontsize=14)
ax2.set_ylabel(r'$\Delta \%$', fontsize=12)
ax2.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Compute relative difference
rel_diff = (k*d - k*P02) / (k*P02)  # Assuming a = desilike P0, P0 = FOLPS P0
rel_diff2 = (k*e - k*P22) / (k*P22)
# Create figure and axes
fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True,
                               gridspec_kw={'height_ratios': [3, 1]},
                               figsize=(7, 6),
                               constrained_layout=True)

# --- Top panel: k * P_ell(k)
ax1.plot(k, k*d, label='Desilike eds l=0', c='r')
ax1.plot(k, k*P02, label='FOLPS eds l=0', ls=":", lw=4, c='r')

ax1.plot(k, k*e, label='Desilike eds l=2', c='b')
ax1.plot(k, k*P22, label='FOLPS eds l=2', ls=":", lw=4, c='b')

ax1.set_ylabel(r'$k P_{\ell}(k) \, [h^{-1} \, \mathrm{Mpc}]^2$', fontsize=14)
ax1.set_title(r'$\ell = 0$', fontsize=14)
ax1.legend()
ax1.grid(True)

# --- Bottom panel: relative difference
ax2.plot(k, rel_diff * 100, color='r')
ax2.plot(k, rel_diff2 * 100, color='b')
ax2.axhline(0, color='gray', lw=1, ls='--')
ax2.set_xlabel(r'$k \, [h\, \mathrm{Mpc}^{-1}]$', fontsize=14)
ax2.set_ylabel(r'$\Delta \%$', fontsize=12)
ax2.grid(True)

plt.show()

# %%
plt.plot(k,k*d,label='eds',c='b')
plt.plot(folps_k,folps_k*P02,label='eds FOLPS', ls=':', lw=4,c='b')

# %%
for param in theory2.init.params:
    print(f"{param.name}: value = {param.value}, fixed = {param.fixed}")
# Out:
# b1: value = 1.5, fixed = False
# b2: value = 0.0, fixed = False
# bs: value = 0.0, fixed = False
# b3: value = 0.0, fixed = True
# alpha0: value = 0.0, fixed = False
# alpha2: value = 0.0, fixed = False
# alpha4: value = 0.0, fixed = False
# ct: value = 0.0, fixed = True
# sn0: value = 0.0, fixed = False
# sn2: value = 0.0, fixed = False
# sn4: value = 0.0, fixed = False
# X_FoG_p: value = 0.0, fixed = False

# %%
for param in theory2.template.init.params:
    print(f"{param.name}: value = {param.value}, fixed = {param.fixed}")
# Out:
# h: value = 0.6736, fixed = False
# omega_cdm: value = 0.12, fixed = False
# omega_b: value = 0.02237, fixed = True
# logA: value = 3.036394, fixed = False
# n_s: value = 0.9649, fixed = True
# tau_reio: value = 0.0544, fixed = True
# m_ncdm: value = 0.4, fixed = True
# N_eff: value = 3.046, fixed = True
# w0_fld: value = -1.0, fixed = True
# wa_fld: value = 0.0, fixed = True
# Omega_k: value = 0.0, fixed = True

# %%
np.exp(3.036394)/10**10
# Out:
# 2.0829994682666578e-09

# %%
import os

# Select the backend before importing folps.py
os.environ["FOLPS_BACKEND"] = "numpy"  #'numpy' or 'jax'

from folps import *
from cosmo_class import *

# param name for tau in classy

# %%
# %%time
#linear power spectrum
#set tau here 
classy  = run_class(h = 0.6736, ombh2 = 0.02237, omch2 = 0.122, omnuh2 = 0.06/93.14, 
                    As = 2.0829994682666578e-09, ns = 0.9649, z = 1, z_scale=[0.97],
                    N_ur = 2.0328,
                    khmin = 0.0001, khmax = 2.0, nbk = 1000, spectra = 'matter')
kwargs = {'z': 1., 'h': 0.6736, 'Omega_m': classy['cosmo'].Omega0_m(),
          'fnu':classy['cosmo'].scale_independent_growth_factor_f(1.)}

matrix = MatrixCalculator(A_full=False)
mmatrices = matrix.get_mmatrices()


nonlinear = NonLinearPowerSpectrumCalculator(mmatrices=mmatrices,
                                             kernels='fk',
                                             **kwargs)

nonlinear2 = NonLinearPowerSpectrumCalculator(mmatrices=mmatrices,
                                             kernels='eds',
                                             **kwargs)
table, table_now = nonlinear.calculate_loop_table(k=classy['k'], pklin=classy['pk'],cosmo=classy['cosmo'], **kwargs)
table2, table_now2 = nonlinear2.calculate_loop_table(k=classy['k'], pklin=classy['pk'],cosmo=classy['cosmo'], **kwargs)
# Bias parameters
b1 = 1.5
b2 = 0.0
# bs2 = -4./7*(b1 - 1)
b3nl = 32./315*(b1 - 1)
bs2=0.0
# b3nl=-2
# EFT parameters
alpha0 = 0                #units: [Mpc/h]^2
alpha2 =0         #units: [Mpc/h]^2
alpha4 = 0.0               #units: [Mpc/h]^2
ctilde = 0.0               #units: [Mpc/h]^4
# Stochatic parameters
PshotP = 1. /1e-4
alphashot0 = 0.0
alphashot2 = 0.0         #units: [Mpc/h]^2
X_Fog_pk = 0
pars = [b1, b2, bs2, b3nl, alpha0, alpha2, alpha4, ctilde, alphashot0, alphashot2, PshotP, X_Fog_pk]
qpar, qper = 1., 1.


# folps_k = np.logspace(np.log10(0.01), np.log10(0.2), num=100) # array of  output k in [h/Mpc]
folps_k = theory2.k
multipoles = RSDMultipolesPowerSpectrumCalculator()#model='EFT'
P0, P2, P4  = multipoles.get_rsd_pkell(kobs=folps_k, qpar=qpar, qper=qper, pars=pars,
                                       table=table, table_now=table_now,
                                       bias_scheme='folps', damping=None)
P02, P22, P42 = multipoles.get_rsd_pkell(kobs=folps_k, qpar=qpar, qper=qper, pars=pars,
                                        table=table2, table_now=table_now2,
                                       bias_scheme='folps', damping=None)
# Out:
# Loading matrices from matrices_nfftlog128_Afull_False_remove-DeltaP_False.npy
# CPU times: user 1.99 s, sys: 44.7 ms, total: 2.04 s
# Wall time: 1.38 s

# %%
[[18347.01483726 20966.65611185 25978.32618427 32591.96305862
  39233.11474292 43878.03871228]
 [19470.19908638 22247.04686148 27558.50494776 34565.95881387
  41600.68379564 46519.84257646]
 [20137.51236963 23005.93037711 28491.44854741 35726.50678343
  42987.59306913 48063.86893204]
template.init.update(with_now='peakaverage')
template()
template.calculate()
# theory.initialize()
# theory.calculate()
# Out:
# /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/code/cosmoprimo/main/lib/python3.10/site-packages/cosmoprimo/eisenstein_hu.py:25: UserWarning: EisensteinHuNoWiggleEngine cannot cope with massive neutrinos
#   warnings.warn('{} cannot cope with massive neutrinos'.format(self.__class__.__name__))

# %%
print(hasattr(template, 'pk_dd'))       # should be True
print(hasattr(template, 'pknow_dd'))    # should be True
print(template.pk_dd.shape)
# Out:
# True
# True
# (400,)

# %%
kwargs['Omega_m']
# Out:
# 0.3195995451884574

# %%
# import folps
import desilike
print(desilike.__file__)
# Out:
# /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/code/desilike/main/lib/python3.10/site-packages/desilike/__init__.py

# %%
theory2.initialize()
theory2.calculate()
# Out:
# Loading matrices from matrices_nfftlog128_Afull_True_remove-DeltaP_False.npy
# /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/code/cosmoprimo/main/lib/python3.10/site-packages/cosmoprimo/eisenstein_hu.py:25: UserWarning: EisensteinHuNoWiggleEngine cannot cope with massive neutrinos
#   warnings.warn('{} cannot cope with massive neutrinos'.format(self.__class__.__name__))
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 2
#       1 theory2.initialize()
# ----> 2 theory2.calculate()
#
# Cell In[20], line 38, in FOLPSv2PowerSpectrumMultipoles.calculate(self)
#      36 self.template()
#      37 self.template.initialize()
# ---> 38 self.template.calculate()
#      39 cosmo_params['pkttlin'] = self.template.pk_dd * self.template.fk**2
#      40 cosmo_params['f0'] = self.template.f0
#
# File /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/code/desilike/main/lib/python3.10/site-packages/desilike/theories/galaxy_clustering/power_template.py:252, in DirectPowerSpectrumTemplate.calculate(self)
#     250 def calculate(self):
#     251     # compute the power spectrum for the current cosmo
# --> 252     BasePowerSpectrumExtractor._set_base(self, with_now=self.with_now)
#     253     self.pk_dd = self.pk_dd_interpolator(self.k)
#     254     if self.with_now:
#
# File /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/code/desilike/main/lib/python3.10/site-packages/desilike/theories/galaxy_clustering/power_template.py:51, in BasePowerSpectrumExtractor._set_base(self, fiducial, with_now)
#      49 def _set_base(self, fiducial=False, with_now=False):
#      50     cosmo = self.fiducial if fiducial else self.cosmo
# ---> 51     if not isinstance(cosmo, Cosmology): cosmo = cosmo.cosmo
#      52     fo = cosmo.get_fourier()
#      53     state = {}
#
# File /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/code/desilike/main/lib/python3.10/site-packages/desilike/theories/primordial_cosmology.py:129, in Cosmoprimo.__getattr__(self, name)
#     127 if 'cosmo' in self.__dict__:
#     128     return get_from_cosmo(self.cosmo, name)
# --> 129 raise AttributeError('{} has not attribute {}; try calling it first?'.format(self, name))
#
# AttributeError: <desilike.theories.primordial_cosmology.Cosmoprimo object at 0x7f1e2879fd30> has not attribute cosmo; try calling it first?

# %%
pars = [1.0, 0.5, 0.3, 0.1, 0.01, 0.02, 0.03, 0.04, 0.001, 0.002, 0.0]
theory2()
# Out:
# Loading matrices from matrices_nfftlog128_Afull_True_remove-DeltaP_False.npy
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/code/desilike/main/lib/python3.10/site-packages/desilike/base.py:1195, in BaseCalculator.__getattr__(self, name)
#    1194 try:
# -> 1195     return object.__getattribute__(self, name)
#    1196 except AttributeError as exc:
#
# AttributeError: 'FOLPSv2PowerSpectrumMultipoles' object has no attribute 'kt'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 2
#       1 pars = [1.0, 0.5, 0.3, 0.1, 0.01, 0.02, 0.03, 0.04, 0.001, 0.002, 0.0]
# ----> 2 theory2.combine_bias_terms_poles(pars)
#
# Cell In[6], line 69, in FOLPSv2PowerSpectrumMultipoles.combine_bias_terms_poles(self, pars, nd)
#      68 def combine_bias_terms_poles(self, pars, nd=1e-4):
# ---> 69     table = (self.kt,) + tuple(self.pt.table) + tuple(self.pt.scalars)
#      70     table_now = (self.kt,) + tuple(self.pt.table_now) + tuple(self.pt.scalars_now)
#      71     # pars = list(pars) + [1. / nd]  # add shot noise
#
# File /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/code/desilike/main/lib/python3.10/site-packages/desilike/base.py:1197, in BaseCalculator.__getattr__(self, name)
#    1195     return object.__getattribute__(self, name)
#    1196 except AttributeError as exc:
# -> 1197     raise AttributeError('calculator {} has no attribute {}; '
#    1198                          'have you run any calculation already by calling this calculator or calculators '
#    1199                          'that depend on it (typically, a likelihood?)'.format(self.__class__.__name__, name)) from exc
#
# AttributeError: calculator FOLPSv2PowerSpectrumMultipoles has no attribute kt; have you run any calculation already by calling this calculator or calculators that depend on it (typically, a likelihood?)

# %%
dir(theory)
# Out:
# ['__call__',
#  '__class__',
#  '__clear__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_default_options',
#  '_get_non_linear',
#  '_klim',
#  '_mpicomm',
#  '_pt_attrs',
#  'all_params',
#  'calculate',
#  'combine_bias_terms_poles',
#  'copy',
#  'deepcopy',
#  'ells',
#  'from_state',
#  'fsigma8',
#  'get',
#  'info',
#  'init',
#  'initialize',
#  'install',
#  'k',
#  'kt',
#  'load',
#  'log_critical',
#  'log_debug',
#  'log_error',
#  'log_info',
#  'log_warning',
#  'logger',
#  'matrices',
#  'mpicomm',
#  'mu',
#  'options',
#  'params',
#  'pt',
#  'runtime_info',
#  'save',
#  'set_k_mu',
#  'sigma8',
#  'template',
#  'to_poles',
#  'varied_params',
#  'wmu',
#  'z']

# %%
p = theory.calculate

# %%
theory.calculate
# Out:
# <bound method FOLPSAXPowerSpectrumMultipoles.calculate of <__main__.FOLPSAXPowerSpectrumMultipoles object at 0x7f44242b3a30>>

# %%
a,b,c=theory()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 a,b,c=theory()
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
import desilike

# %%
desilike._file_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 desilike._file_
#
# AttributeError: module 'desilike' has no attribute '_file_'

# %%
# Out:
# /bin/bash: module: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `module'
# /bin/bash: ml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `ml'
# Defaulting to user installation because normal site-packages is not writeable
# Collecting git+https://github.com/cosmodesi/desilike
#   Cloning https://github.com/cosmodesi/desilike to /tmp/pip-req-build-hqkq_qr2
#   Running command git clone --filter=blob:none --quiet https://github.com/cosmodesi/desilike /tmp/pip-req-build-hqkq_qr2
#   Resolved https://github.com/cosmodesi/desilike to commit c948d980209378c1596562eb90cfa4319e53b1a5
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting cosmoprimo@ git+https://github.com/cosmodesi/cosmoprimo (from desilike==0.0.1)
#   Cloning https://github.com/cosmodesi/cosmoprimo to /tmp/pip-install-39jfedb5/cosmoprimo_b57a05c0d15e4b418b8ddd222ad07a94
#   Running command git clone --filter=blob:none --quiet https://github.com/cosmodesi/cosmoprimo /tmp/pip-install-39jfedb5/cosmoprimo_b57a05c0d15e4b418b8ddd222ad07a94
#   Resolved https://github.com/cosmodesi/cosmoprimo to commit f35dec664b50dea83033204a8cdb6ec586be30b9
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy<2.0,>=1.18.0 in /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages (from desilike==0.0.1) (1.26.3)
# Requirement already satisfied: scipy in /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages (from desilike==0.0.1) (1.11.4)
# Requirement already satisfied: pyyaml in /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages (from desilike==0.0.1) (6.0.1)
# Requirement already satisfied: mpi4py in /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages (from desilike==0.0.1) (3.1.5)
# Building wheels for collected packages: desilike, cosmoprimo
#   Building wheel for desilike (pyproject.toml) ... done
#   Created wheel for desilike: filename=desilike-0.0.1-py3-none-any.whl size=501560 sha256=e25f315036c850044544b000696bc4ea35db0f0e16a1f1bb93efd36b659042d9
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ij7u_9ng/wheels/12/fb/39/dd1f32f29c95bb831021fcf14606a92f728d46c0ea048f3f7c
#   Building wheel for cosmoprimo (pyproject.toml) ... done
#   Created wheel for cosmoprimo: filename=cosmoprimo-1.0.0-py3-none-any.whl size=5670751 sha256=f8c34e3c8dd0a0b412008ae5e23b40096f73d13fb3a3e8e99534814a485340e6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ij7u_9ng/wheels/3d/e4/33/8b1cd15473790760456c98a7d5eafa65e9db2945fecdef2a00
# Successfully built desilike cosmoprimo
# Installing collected packages: cosmoprimo, desilike
# Successfully installed cosmoprimo-1.0.0 desilike-0.0.1

# %%
# !python -m pip install git+https://github.com/cosmodesi/desilike
# Out:
# Collecting git+https://github.com/cosmodesi/desilike
#   Cloning https://github.com/cosmodesi/desilike to /tmp/pip-req-build-m70walvh
#   Running command git clone --filter=blob:none --quiet https://github.com/cosmodesi/desilike /tmp/pip-req-build-m70walvh
#   Resolved https://github.com/cosmodesi/desilike to commit c948d980209378c1596562eb90cfa4319e53b1a5
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting cosmoprimo@ git+https://github.com/cosmodesi/cosmoprimo
#   Cloning https://github.com/cosmodesi/cosmoprimo to /tmp/pip-install-sje7gw1i/cosmoprimo_a8ff0fa10f2f40d7ad366e7ebcc31d6c
#   Running command git clone --filter=blob:none --quiet https://github.com/cosmodesi/cosmoprimo /tmp/pip-install-sje7gw1i/cosmoprimo_a8ff0fa10f2f40d7ad366e7ebcc31d6c
#   Resolved https://github.com/cosmodesi/cosmoprimo to commit f35dec664b50dea83033204a8cdb6ec586be30b9
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting numpy<2.0,>=1.18.0
#   Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 108.1 MB/s eta 0:00:0000:010:01
# Collecting pyyaml
#   Downloading PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (751 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 751.2/751.2 kB 87.7 MB/s eta 0:00:00
# Collecting scipy
#   Downloading scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.7/37.7 MB 71.6 MB/s eta 0:00:0000:0100:01
# Collecting mpi4py
#   Downloading mpi4py-4.1.0-cp310-cp310-manylinux1_x86_64.manylinux_2_5_x86_64.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 114.1 MB/s eta 0:00:00
# Building wheels for collected packages: cosmoprimo
#   Building wheel for cosmoprimo (pyproject.toml) ... done
#   Created wheel for cosmoprimo: filename=cosmoprimo-1.0.0-py3-none-any.whl size=5670751 sha256=edf2420720f4f6163c6e5e430afa647f1ec2c77af2d56dfcb2e48d850c8aade3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ebfzf4_r/wheels/3d/e4/33/8b1cd15473790760456c98a7d5eafa65e9db2945fecdef2a00
# Successfully built cosmoprimo
# Installing collected packages: pyyaml, numpy, mpi4py, scipy, cosmoprimo
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.6
#     Uninstalling numpy-2.2.6:
#       Successfully uninstalled numpy-2.2.6
# Successfully installed cosmoprimo-1.0.0 mpi4py-4.1.0 numpy-1.26.4 pyyaml-6.0.2 scipy-1.15.3
#
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
from folps import  f_over_f0_EH

# %%
kwargs = {'z': 1., 'h': 0.6736, 'Omega_m': classy['cosmo'].Omega0_m(),
          'fnu':classy['cosmo'].scale_independent_growth_factor_f(1.)}
f_over_f0_EH(zev=kwargs['z'], k=folps_k, OmM0=classy['cosmo'].Omega0_m(), h=kwargs['h'], fnu=kwargs['fnu'], Nnu=3, Neff=3.046)
# Out:
# (array([0.01      , 0.01034952, 0.01071127, 0.01108565, 0.01147312,
#         0.01187414, 0.01228917, 0.01271871, 0.01316326, 0.01362334,
#         0.01409951, 0.01459233, 0.01510237, 0.01563023, 0.01617655,
#         0.01674196, 0.01732713, 0.01793276, 0.01855955, 0.01920826,
#         0.01987963, 0.02057447, 0.0212936 , 0.02203787, 0.02280815,
#         0.02360535, 0.02443041, 0.02528432, 0.02616807, 0.02708271,
#         0.02802932, 0.02900901, 0.03002295, 0.03107233, 0.03215838,
#         0.0332824 , 0.0344457 , 0.03564966, 0.03689571, 0.0381853 ,
#         0.03951998, 0.0409013 , 0.0423309 , 0.04381047, 0.04534176,
#         0.04692656, 0.04856676, 0.05026429, 0.05202116, 0.05383943,
#         0.05572125, 0.05766884, 0.05968452, 0.06177064, 0.06392968,
#         0.06616418, 0.06847678, 0.07087022, 0.07334731, 0.07591098,
#         0.07856426, 0.08131027, 0.08415227, 0.0870936 , 0.09013774,
#         0.09328828, 0.09654894, 0.09992356, 0.10341614, 0.1070308 ,
#         0.11077179, 0.11464354, 0.11865062, 0.12279775, 0.12708984,
#         0.13153195, 0.13612932, 0.14088738, 0.14581174, 0.15090823,
#         0.15618285, 0.16164183, 0.16729161, 0.17313887, 0.17919051,
#         0.18545367, 0.19193573, 0.19864437, 0.20558748, 0.21277328,
#         0.22021024, 0.22790713, 0.23587306, 0.24411741, 0.25264992,
#         0.26148067, 0.27062007, 0.28007892, 0.28986838, 0.3       ]),
#  array([0.99651311, 0.99641545, 0.99631212, 0.99620284, 0.9960873 ,
#         0.99596519, 0.99583619, 0.99569993, 0.99555608, 0.99540424,
#         0.99524404, 0.99507505, 0.99489686, 0.99470902, 0.99451106,
#         0.99430249, 0.99408281, 0.99385149, 0.99360797, 0.99335166,
#         0.99308198, 0.99279827, 0.99249988, 0.99218613, 0.99185628,
#         0.99150958, 0.99114525, 0.99076246, 0.99036036, 0.98993805,
#         0.98949459, 0.989029  , 0.98854027, 0.98802733, 0.98748908,
#         0.98692434, 0.98633193, 0.98571058, 0.98505898, 0.98437577,
#         0.98365953, 0.98290878, 0.98212197, 0.98129752, 0.98043376,
#         0.97952896, 0.97858133, 0.97758901, 0.97655006, 0.97546249,
#         0.97432422, 0.9731331 , 0.97188691, 0.97058336, 0.96922007,
#         0.96779458, 0.96630439, 0.96474688, 0.96311937, 0.96141912,
#         0.95964328, 0.95778896, 0.95585318, 0.9538329 , 0.95172501,
#         0.94952634, 0.94723364, 0.94484364, 0.94235299, 0.93975832,
#         0.9370562 , 0.9342432 , 0.93131583, 0.92827062, 0.92510408,
#         0.92181275, 0.91839316, 0.91484191, 0.91115562, 0.90733098,
#         0.90336477, 0.89925386, 0.89499522, 0.89058599, 0.88602342,
#         0.88130496, 0.87642825, 0.87139114, 0.86619174, 0.86082839,
#         0.85529975, 0.84960477, 0.84374273, 0.83771327, 0.83151641,
#         0.82515256, 0.81862257, 0.81192769, 0.80506967, 0.79805069]),
#  0.8788752574183382)

# %%
template.f0
# Out:
# 0.8766185289981336

# %% [markdown]
# # Test with A_full = False

# %%
import sys
sys.path.insert(0, "/global/u1/p/prakharb/desilike")

# %%
import re
import os
import numpy as np
from scipy import interpolate
import matplotlib.pyplot as plt
from desilike.jax import numpy as jnp
from desilike.jax import jit, interp1d
from desilike import jax
from desilike import plotting, utils, BaseCalculator
from desilike.theories.galaxy_clustering.base import BaseTheoryPowerSpectrumMultipolesFromWedges, BaseTheoryPowerSpectrumMultipoles
from desilike.theories.galaxy_clustering.full_shape import BasePTPowerSpectrumMultipoles, FOLPSPowerSpectrumMultipoles, BaseTracerPowerSpectrumMultipoles
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# from .base import BaseTheoryPowerSpectrumMultipoles, BaseTheoryCorrelationFunctionMultipoles, BaseTheoryCorrelationFunctionFromPowerSpectrumMultipoles
# from .power_template import DirectPowerSpectrumTemplate, StandardPowerSpectrumTemplate

# %%
from desilike.theories.galaxy_clustering.full_shape import DirectPowerSpectrumTemplate, KaiserTracerPowerSpectrumMultipoles, SimpleTracerPowerSpectrumMultipoles, FOLPSAXTracerPowerSpectrumMultipoles,FOLPSTracerPowerSpectrumMultipoles,FOLPSv2TracerPowerSpectrumMultipoles
from desilike.observables.galaxy_clustering import TracerPowerSpectrumMultipolesObservable
from desilike.likelihoods import ObservablesGaussianLikelihood
from desilike.parameter import ParameterCollection
from desilike import setup_logging
# from desilike_private.theories.galaxy_clustering.full_shape import FOLPSv2TracerPowerSpectrumMultipoles

z=1.
template = DirectPowerSpectrumTemplate(z=z, fiducial='DESI')
for param in ['omega_b', 'n_s']: template.params[param].update(fixed=True)
template.init.params['m_ncdm'].update(value=0.4)

# theory = FOLPSAXPowerSpectrumMultipoles(template=template)
theory2 = FOLPSv2TracerPowerSpectrumMultipoles(template=template,prior_basis='standard',kernels='fk',A_full=False)
# theory3 = FOLPSv2TracerPowerSpectrumMultipoles(template=template,prior_basis='standard',kernels='eds')

# theory.compute()

# %%
a,b,c=theory2()

# %% [markdown]
# # Desilike Bispectrum Test

# %%
from desilike.theories.galaxy_clustering.full_shape import DirectPowerSpectrumTemplate, KaiserTracerPowerSpectrumMultipoles, FOLPSv2TracerBispectrumMultipoles, FOLPSAXTracerPowerSpectrumMultipoles,FOLPSTracerPowerSpectrumMultipoles,FOLPSv2TracerPowerSpectrumMultipoles, FOLPSv2PowerSpectrumMultipoles
from desilike.observables.galaxy_clustering import TracerPowerSpectrumMultipolesObservable
from desilike.likelihoods import ObservablesGaussianLikelihood
from desilike.parameter import ParameterCollection
from desilike import setup_logging
# from desilike_private.theories.galaxy_clustering.full_shape import FOLPSv2TracerPowerSpectrumMultipoles

z=1.
template = DirectPowerSpectrumTemplate(z=z, fiducial='DESI')
for param in ['omega_b', 'n_s']: template.params[param].update(fixed=True)
# template.init.params['m_ncdm'].update(value=0.4)
ks = np.logspace(np.log10(0.0001), np.log10(0.4), 30)

k1k2T = np.vstack([ks,ks]).T
# theory = FOLPSv2PowerSpectrumMultipoles(template=template)
theory2 = FOLPSv2TracerBispectrumMultipoles(template=template,prior_basis='standard',kernels='fk',k=ks)
# theory3 = FOLPSv2TracerPowerSpectrumMultipoles(template=template,prior_basis='standard',kernels='eds')

# theory.compute()

# %%
theory2()
# Out:
# 0.01221776008605957
# (array([3.35680843e+07, 3.35680843e+07, 3.35680843e+07, 3.35680843e+07,
#         3.35680843e+07, 3.35680843e+07, 3.35020678e+07, 3.32278776e+07,
#         3.33985616e+07, 5.37670824e+07, 8.86463292e+07, 1.44392388e+08,
#         2.33141914e+08, 3.65078728e+08, 5.48829524e+08, 7.83149698e+08,
#         1.04239651e+09, 1.26659461e+09, 1.35547198e+09, 1.22310068e+09,
#         8.92777836e+08, 5.49298020e+08, 3.44714514e+08, 2.22069935e+08,
#         9.50929750e+07, 4.63784462e+07, 1.79621874e+07, 6.84808018e+06,
#         2.47459763e+06, 8.07517673e+05]),
#  array([2.11314354e+07, 2.11314354e+07, 2.11314354e+07, 2.11314354e+07,
#         2.11314354e+07, 2.11314354e+07, 2.10335892e+07, 2.04251984e+07,
#         1.98383014e+07, 3.24920866e+07, 5.44234123e+07, 8.98586938e+07,
#         1.45700176e+08, 2.29305194e+08, 3.46760560e+08, 4.98228922e+08,
#         6.68310182e+08, 8.18692702e+08, 8.81553478e+08, 7.94648219e+08,
#         5.70818724e+08, 3.41229825e+08, 2.11288869e+08, 1.36335931e+08,
#         5.69078138e+07, 2.73797792e+07, 1.00802555e+07, 3.83054622e+06,
#         1.33022074e+06, 4.21673816e+05]))

# %%
B000,B202=theory2.power
k = theory2.k

# %%
import matplotlib.pyplot as plt
import numpy as np
k=ks
# Compute relative difference
rel_diff = (k*B000 - k*B000_folps) / (k*B000)  # Assuming a = desilike P0, P0 = FOLPS P0
rel_diff2 = (k*B202 - k*B202_folps) / (k*B202)  # Assuming b = desilike P0, P0 = FOLPS P0

# Create figure and axes
fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True,
                               gridspec_kw={'height_ratios': [3, 1]},
                               figsize=(7, 6),
                               constrained_layout=True)

# --- Top panel: k * P_ell(k)
ax1.plot(k, B000, label='Desilike  l=000', c='r')
ax1.plot(k, B000_folps, label='FOLPS l=000', ls=":", lw=4, c='r')

ax1.plot(k, B202, label='Desilike l=202', c='b')
ax1.plot(k, B202_folps, label='FOLPS l=202', ls=":", lw=4, c='b')

ax1.set_ylabel(r'$k^2 B(k,k)$', fontsize=14)
# ax1.set_title(r'$\ell = 0$', fontsize=14)
ax1.set_xscale('log')
ax1.set_yscale('log')
ax1.set_xlim(0.001,0.3)
ax1.legend()
ax1.grid(True)

# --- Bottom panel: relative difference
ax2.plot(k, rel_diff * 100, color='r', label='l=0')
ax2.plot(k, rel_diff2 * 100, color='b',label='l=2')
ax2.axhline(0, color='gray', lw=1, ls='--')
ax2.set_xlabel(r'$k \, [h\, \mathrm{Mpc}^{-1}]$', fontsize=14)
ax2.set_ylabel(r'$\Delta \%$', fontsize=12)
ax2.grid(True)
plt.savefig("bisprectrum_test.png")
plt.show()

# %%
# Out:
# 0.8766185289981336

# %%
import os

# Select the backend before importing folps.py
os.environ["FOLPS_BACKEND"] = "numpy"  #'numpy' or 'jax'

from folps import *
from cosmo_class import *
#linear power spectrum
#set tau here 
classy  = run_class(h = 0.6736, ombh2 = 0.02237, omch2 = 0.122, omnuh2 = 0.06/93.14, 
                    As = 2.0829994682666578e-09, ns = 0.9649, z = 1, z_scale=[0.97],
                    N_ur = 2.0328,
                    khmin = 0.0001, khmax = 2.0, nbk = 1000, spectra = 'matter')
kwargs = {'z': 1., 'h': 0.6736, 'Omega_m': classy['cosmo'].Omega0_m(),
          'fnu':classy['cosmo'].scale_independent_growth_factor_f(1.)}

matrix = MatrixCalculator(A_full=False)
mmatrices = matrix.get_mmatrices()


nonlinear = NonLinearPowerSpectrumCalculator(mmatrices=mmatrices,
                                             kernels='fk',
                                             **kwargs)

nonlinear2 = NonLinearPowerSpectrumCalculator(mmatrices=mmatrices,
                                             kernels='eds',
                                             **kwargs)
table, table_now = nonlinear.calculate_loop_table(k=classy['k'], pklin=classy['pk'],cosmo=classy['cosmo'], **kwargs)
table2, table_now2 = nonlinear2.calculate_loop_table(k=classy['k'], pklin=classy['pk'],cosmo=classy['cosmo'], **kwargs)

#pars for Bispectrum
z_pk=1.;


b1v = 1.5;
b2v = 0.0;
bsv = 0;
c1v = 0; 
c2v = 0
X_FoG_b = 0

Omv=classy['cosmo'].Omega0_m();
hv=classy['cosmo'].h(); 
f=classy['cosmo'].scale_independent_growth_factor_f(z_pk)

qparv = 1; qperpv = 1;
Bshotv=0.0
Pshotv=0.0

f0 = nonlinear.f0

bisp_nuis_params = [b1v, b2v, bsv, c1v, c2v, Bshotv, Pshotv, X_FoG_b]

# ks1 = np.logspace(np.log10(0.0001), np.log10(0.4), 30)
# ks2 = np.logspace(np.log10(0.0001), np.log10(0.4), 26)
# k1k2T = np.vstack([ks,ks]).T



ks1 = np.logspace(np.log10(0.0001), np.log10(0.4), 30)
ks2 = np.logspace(np.log10(0.0001), np.log10(0.4), 26)

# Pad ks2 with NaNs
ks2_padded = np.pad(ks2, (0, len(ks1) - len(ks2)), constant_values=np.nan)

k1k2T = np.vstack([ks1, ks2_padded]).T
print(k1k2T.shape) 

bispectrum = BispectrumCalculator(basis='sugiyama')


# B000_folps, B202_folps = bispectrum.Bisp_Sugiyama(f=f0, f0=f0, bpars=bisp_nuis_params,
#                                       pk_input=pklir, z_pk=z_pk,
#                                       k1k2pairs=k1k2T, qpar=1, qperp=1, precision=[4, 5, 5], damping='lor')
# Out:
# ✅ Using NumPy with CPU.
# Loading matrices from matrices_nfftlog128_Afull_False_remove-DeltaP_False.npy
# (30, 2)

# %%
# %%time
pklir = get_linear_ir_ini(table[0], table[1], table_now[1], h=classy['cosmo'].h)
B000_folps, B202_folps = bispectrum.Bisp_Sugiyama(f=f0, f0=f0, bpars=bisp_nuis_params,
                                      pk_input=pklir, z_pk=z_pk,
                                      k1k2pairs=k1k2T, qpar=1, qperp=1, precision=[4, 5, 5], damping='lor')
# Out:
# CPU times: user 16.7 ms, sys: 264 µs, total: 17 ms
# Wall time: 15 ms

# %%
a=np.load('/global/homes/p/prakharb/FOLPSpipe/folps/desilike_mcmc/kr_pk.npy')
a
# Out:
# array([0.02031268, 0.02516689, 0.03020486, 0.03517139, 0.04012842,
#        0.04507161, 0.05004095, 0.05507535, 0.0600698 , 0.06512571,
#        0.07011277, 0.07502157, 0.08004289, 0.08504873, 0.09004322,
#        0.09502533, 0.1000098 , 0.10504149, 0.1100224 , 0.11502614,
#        0.12001702, 0.12502202, 0.13002994, 0.13502229, 0.14005739,
#        0.14502593, 0.1500209 , 0.15502526, 0.160035  , 0.16505188,
#        0.17003695, 0.1750324 , 0.18003276, 0.18504025, 0.1900268 ,
#        0.19500211, 0.20001755, 0.20502544, 0.21001923, 0.21502351,
#        0.22001683, 0.22501584, 0.23002834, 0.23502663, 0.2400277 ,
#        0.24503438, 0.25002842, 0.25501355, 0.26001043, 0.26502644,
#        0.27002398, 0.27502142, 0.28002714, 0.28503308, 0.29001812,
#        0.29500021, 0.30001302])

# %%
import numpy as np

ks1 = np.logspace(np.log10(0.0001), np.log10(0.4), 30)
ks2 = np.logspace(np.log10(0.0001), np.log10(0.4), 30)

# Pad ks2 with NaNs
ks2_padded = np.pad(ks2, (0, len(ks1) - len(ks2)), constant_values=np.nan)

k1k2T = np.vstack([ks1, ks2_padded]).T
print(k1k2T.shape)
# Out:
# (30, 2)

# %%
B000_folps
# Out:
# array([3.19337591e+07, 3.19161507e+07, 3.19543523e+07, 3.20280225e+07,
#        3.21182891e+07, 3.22105629e+07, 3.18972127e+07, 3.19354563e+07,
#        4.20534752e+07, 7.05446880e+07, 1.21433417e+08, 2.04491373e+08,
#        3.32655204e+08, 5.16507840e+08, 7.53435451e+08, 1.00971224e+09,
#        1.20110623e+09, 1.20976199e+09, 9.91635279e+08, 7.04615709e+08,
#        4.62737318e+08, 2.27452427e+08, 1.12549663e+08, 5.33317219e+07,
#        1.88975129e+07, 6.81211988e+06,            nan,            nan,
#                   nan,            nan])

# %%
B202_folps
# Out:
# array([2.01402688e+07, 1.97878759e+07, 1.95786730e+07, 1.94841122e+07,
#        1.94730862e+07, 1.95163243e+07, 1.89961855e+07, 1.81230663e+07,
#        2.38345226e+07, 3.96243751e+07, 6.82561501e+07, 1.15519483e+08,
#        1.89596916e+08, 2.98406248e+08, 4.43869158e+08, 6.10935947e+08,
#        7.52048390e+08, 7.86275412e+08, 6.62198794e+08, 4.74304294e+08,
#        3.17410516e+08, 1.60409977e+08, 7.95540071e+07, 3.87421310e+07,
#        1.38237386e+07, 4.99123361e+06,            nan,            nan,
#                   nan,            nan])
