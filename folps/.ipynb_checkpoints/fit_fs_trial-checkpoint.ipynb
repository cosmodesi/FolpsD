# %%
#!/usr/bin/env python
# coding: utf-8

# In[ ]:


import sys
import os
sys.path.insert(0, "/global/u1/p/prakharb/desilike")
#sys.path.insert(0, "/global/u1/p/prakharb/desilike")
#sys.path.insert(0, "/global/u1/p/prakharb/cosmoprimo")
import desilike, inspect
print(inspect.getfile(desilike))


import numpy as np
import matplotlib.pyplot as plt
from desilike.theories.galaxy_clustering import LPTVelocileptorsTracerPowerSpectrumMultipoles, REPTVelocileptorsTracerPowerSpectrumMultipoles,  DirectPowerSpectrumTemplate, ShapeFitPowerSpectrumTemplate
from desilike.theories.galaxy_clustering.full_shape import FOLPSv2TracerBispectrumMultipoles, FOLPSv2TracerPowerSpectrumMultipoles, FOLPSAXTracerPowerSpectrumMultipoles, FOLPSTracerPowerSpectrumMultipoles, PyBirdTracerPowerSpectrumMultipoles
from desilike.observables.galaxy_clustering import TracerPowerSpectrumMultipolesObservable 
from desilike.observables import ObservableCovariance
from desilike.emulators import EmulatedCalculator, Emulator, TaylorEmulatorEngine
from desilike.likelihoods import ObservablesGaussianLikelihood, SumLikelihood
from desilike.theories import Cosmoprimo
from cosmoprimo.fiducial import DESI
from desilike import setup_logging
from desilike.parameter import Parameter, ParameterPrior
import argparse
# Out:
# /global/u1/p/prakharb/desilike/desilike/__init__.py

# %%
######### Settings #########

#model: LCDM or HS
model = 'LCDM'

#Put 'True' to resume chain. 'False' to start from 0 steps
restart_chain = False

#Biasing and EFT parametrization: 'physical' or 'default' (non-physical)
prior_basis = 'standard' #Prior to be used 

k_max = 0.20

#width for EFT and SN paramss
width_EFT = 12.5
width_SN0 = 2.0
width_SN2 = 5.0

pt_model = "folps"  # Change this to "rept_velocileptors" or "pybird" as needed

sampler = 'cobaya'

set_emulator = True

GR_criteria = 0.01  # R - 1 < GR_criteria 


# Argument parser
#parser = argparse.ArgumentParser(description="Run MCMC analysis with different tracers")
#parser.add_argument("--tracers", nargs="+", required=True, help="List of tracers to use")
#args = parser.parse_args()


# List of tracers
# tracers = ['BGS', 'LRG1', 'LRG2', 'LRG3', 'ELG', 'QSO']  # Add more tracers as needed
tracers = [ 'LRG1']
#tracers = args.tracers
all_tracers = {'BGS', 'LRG1', 'LRG2', 'LRG3', 'ELG', 'QSO'}

if set(tracers) == all_tracers:
    tracers_str = "all"
else:
    tracers_str = "+".join(tracers)

chain_name = f'chains/MCMC-fs_klim_0-0.02-{k_max}_2-0.02-{k_max}-{tracers_str}-GCcomb_schoneberg2024-bbn_planck2018-ns10_{prior_basis}-prior_{model}_{pt_model}v1_new'
chain_name = f'chains/MCMC-fs-fake'
# chain_name = f'fake'
# chain_name= f'fake2'
if not set_emulator:
    chain_name += '_noemu'
#print(chain_name)


# Define file paths for each tracer (in the same order as the tracers list above)
all_tracer_params = {
    'BGS': {
        'data_fn': '/global/cfs/cdirs/desi/survey/catalogs/Y1/LSS/iron/LSScats/v1.5/unblinded/desipipe/forfit_2pt/forfit_power_syst-rotation-hod-photo_klim_0-0.02-0.20_2-0.02-0.20_BGS_BRIGHT-21.5_GCcomb_z0.1-0.4.npy'
    },
    'LRG1': {
        'data_fn': '/global/cfs/cdirs/desi/survey/catalogs/Y1/LSS/iron/LSScats/v1.5/unblinded/desipipe/forfit_2pt/forfit_power_syst-rotation-hod-photo_klim_0-0.02-0.20_2-0.02-0.20_LRG_GCcomb_z0.4-0.6.npy'
    },
    'LRG2': {
        'data_fn': '/global/cfs/cdirs/desi/survey/catalogs/Y1/LSS/iron/LSScats/v1.5/unblinded/desipipe/forfit_2pt/forfit_power_syst-rotation-hod-photo_klim_0-0.02-0.20_2-0.02-0.20_LRG_GCcomb_z0.6-0.8.npy'
    },
    'LRG3': {
        'data_fn': '/global/cfs/cdirs/desi/survey/catalogs/Y1/LSS/iron/LSScats/v1.5/unblinded/desipipe/forfit_2pt/forfit_power_syst-rotation-hod-photo_klim_0-0.02-0.20_2-0.02-0.20_LRG_GCcomb_z0.8-1.1.npy'
    },
    'ELG': {
       'data_fn': '/global/cfs/cdirs/desi/survey/catalogs/Y1/LSS/iron/LSScats/v1.5/unblinded/desipipe/forfit_2pt/forfit_power_syst-rotation-hod-photo_klim_0-0.02-0.20_2-0.02-0.20_ELG_LOPnotqso_GCcomb_z1.1-1.6.npy'
    },
    'QSO': {
        'data_fn': '/global/cfs/cdirs/desi/survey/catalogs/Y1/LSS/iron/LSScats/v1.5/unblinded/desipipe/forfit_2pt/forfit_power_syst-rotation-hod-photo_klim_0-0.02-0.20_2-0.02-0.20_QSO_GCcomb_z0.8-2.1.npy'
    }
}  



#Define a cosmology to get sigma_8, Omega_m and fR0
cosmo = Cosmoprimo(engine='class')
cosmo.init.params['H0'] = dict(derived=True)
cosmo.init.params['Omega_m'] = dict(derived=True)
cosmo.init.params['sigma8_m'] = dict(derived=True) 
#cosmo.init.params['fR0'] = dict(derived=False, latex ='f_{R0}')
fiducial = DESI() #fiducial cosmology

#Update cosmo priors
for param in ['n_s', 'h','omega_cdm', 'omega_b', 'logA', 'tau_reio']:
    cosmo.params[param].update(fixed = False)
    if param == 'tau_reio':
        cosmo.params[param].update(fixed = True)
        
    if param == 'n_s':
            cosmo.params[param].update(fixed = True)
            # cosmo.params[param].update(prior={'dist': 'norm', 'loc': 0.9649, 'scale': 0.042})
    if param == 'omega_b':
            cosmo.params[param].update(prior={'dist': 'norm', 'loc': 0.02237, 'scale': 0.00037})
    if param == 'h':
            cosmo.params[param].update(prior = {'dist':'uniform','limits': [0.5,0.9]})
    if param == 'omega_cdm':
        cosmo.params[param].update(prior = {'dist':'uniform','limits': [0.05, 0.2]})
    #if param == 'm_ncdm':
        #cosmo.params[param].update(prior = {'dist':'uniform','limits': [0.0, 5]})
    if param == 'logA':
        cosmo.params[param].update(prior = {'dist':'uniform','limits': [2.0, 4.0]})
    #if param == 'fR0':
    #    if model != 'HS':
    #        print('model '+str(model))
    #        cosmo.params[param].update(fixed=True, value=0.0)
    #    else:
    #        print('model HS')
    #        cosmo.params[param].update(
    #        prior={'dist': 'uniform', 'limits': [0, 9e-5]},
    #        fixed=False,
    #        ref={'limits': [0, 9e-5]}
    #        )

#Define tracer types and their corresponding redshifts
all_tracer_redshifts = {
                        'BGS': 0.295,
                        'LRG1': 0.510,
                        # 'LRG2': 0.706,
                        'LRG2': 0.8,
                        'LRG3': 0.930,
                        'ELG': 1.317,
                        'QSO': 1.491
                        }

tracer_params = {index: all_tracer_params[tracer] for index, tracer in enumerate(tracers)}
tracer_redshifts = {tracer: all_tracer_redshifts[tracer] for tracer in tracers}

#Initialize an empty list to store the theory objects
theories = []

#Iterate over each tracer and create the corresponding theory object
for tracer in tracers:
    if tracer in tracer_redshifts:
        z = tracer_redshifts[tracer]
    else:
        print(f'Invalid tracer: {tracer}. Skipping.') 
        continue

    #Create the template and theory objects
    template = DirectPowerSpectrumTemplate(fiducial = fiducial,cosmo = cosmo, z=z) #cosmology and fiducial cosmology defined above
    

    # Activate the corresponding model
    if pt_model == "lpt_velocileptors":
        print("LPTVelocileptorsTracerPowerSpectrumMultipoles activated")
        theory = LPTVelocileptorsTracerPowerSpectrumMultipoles(template=template, prior_basis="physical")
    elif pt_model == "rept_velocileptors":
        print("REPTVelocileptorsTracerPowerSpectrumMultipoles activated")
        theory = REPTVelocileptorsTracerPowerSpectrumMultipoles(template=template, prior_basis="physical")
    elif pt_model == "ept_velocileptors":
        print("EPTMomentsVelocileptorsTracerPowerSpectrumMultipoles activated")
        theory = EPTMomentsVelocileptorsTracerPowerSpectrumMultipoles(template=template, prior_basis="physical")
    elif pt_model == "pybird":
        print("PyBirdPowerSpectrumMultipoles activated")
        theory = PyBirdTracerPowerSpectrumMultipoles(template=template)
    else:
        print("No valid pt_model specified, defaulting to FOLPS model")
        theory = FOLPSv2TracerPowerSpectrumMultipoles(template=template, prior_basis="standard") #Add the prior_basis='physical' argument to use physically motivated priors
        # theory = FOLPSv2TracerBispectrumMultipoles(template=template, prior_basis="standard")   
    #Update bias and EFT priors
    # theory.params['bs'].update(fixed=True)
    if prior_basis == 'physical':
        theory.params['b1p'].update(prior = {'dist':'uniform','limits': [1e-5, 10]})
        theory.params['b2p'].update(prior = {'dist':'uniform','limits': [-50, 50]})
        theory.params['bsp'].update(prior = {'dist': 'norm', 'loc': 0, 'scale': 20})
        theory.params['alpha0p'].update(prior={'dist': 'norm', 'loc': 0, 'scale': width_EFT})
        theory.params['alpha2p'].update(prior={'dist': 'norm', 'loc': 0, 'scale': width_EFT})
        theory.params['alpha4p'].update(prior={'dist': 'norm', 'loc': 0, 'scale': width_EFT})
        theory.params['sn0p'].update(prior={'dist': 'norm', 'loc': 0, 'scale': width_SN0})
        theory.params['sn2p'].update(prior={'dist': 'norm', 'loc': 0, 'scale': width_SN2})
        theory.params['X_FoG_p'].update(fixed=True)
    else:
        theory.params['b1'].update(prior = {'dist':'uniform','limits': [1e-5, 10]})
        theory.params['b2'].update(prior = {'dist':'uniform','limits': [-50, 50]})
        theory.params['bs'].update(prior = {'dist': 'norm', 'loc': 0, 'scale': 20})
        theory.params['alpha0'].update(prior={'dist': 'norm', 'loc': 0, 'scale': width_EFT})
        theory.params['alpha2'].update(prior={'dist': 'norm', 'loc': 0, 'scale': width_EFT})
        theory.params['alpha4'].update(prior={'dist': 'norm', 'loc': 0, 'scale': width_EFT})
        theory.params['sn0'].update(prior={'dist': 'norm', 'loc': 0, 'scale': width_SN0})
        theory.params['sn2'].update(prior={'dist': 'norm', 'loc': 0, 'scale': width_SN2})
        theory.params['X_FoG_p'].update(prior = {'dist':'uniform','limits': [0, 10]})
        theory.params['X_FoG_p'].update(fixed=True)

    
    #Append the theory object to the list
    theories.append(theory)

#Print used priors
for param in theory.all_params:
    print(param,':',theory.all_params[param].prior)

#Define a function to create an observable
def create_observable(data_fn, #wmatrix_fn, covariance_fn,
                      theory, tracer_index):
    #Load and process covariance
    covariance = ObservableCovariance.load(data_fn)
    #covariance = covariance.select(xlim=(0.02, k_max), projs=[0, 2])
    
    #power spectrum
    data = covariance.observables('power')

    indices = np.where((data.flatx > 0.02) & (data.flatx < k_max))[0]
    print(data.attrs['ellsin'])
    #Create and return the observable: following  https://desi.lbl.gov/trac/wiki/keyprojects/y1kp3/clusteringproducts#a101:Iwanttowritemychi2
    return TracerPowerSpectrumMultipolesObservable(
        data=data,
        covariance=covariance.select(observables=data, select_observables=True),
        klim={ell: [0.02, k_max, 0.005] for ell in [0, 2]},
        theory=theories[tracer_index],
        kin=data.attrs['kin'],
        wmatrix=data.attrs['wmatrix'][indices, :],
        ellsin=data.attrs['ellsin'],
        wshotnoise=data.attrs['wshotnoise'][indices]
    )

#Create observables for each tracer
observables = [create_observable(params['data_fn'], 
                                 #params['wmatrix_fn'], params['covariance_fn'],
                                 theories, i) 
                for i, params in tracer_params.items()]


if set_emulator:
    # Create an emulated theory for each tracer
    for i in range(len(theories)):
        emulator_filename = f'Emulator_test_bs_ps/emu_-{tracers_str}_{str(tracers[i])}.npy'
        
        if os.path.exists(emulator_filename):
            print(f"FS emulator {i} already exists, loading it now")
            emulator = EmulatedCalculator.load(emulator_filename)  
            theories[i].init.update(pt=emulator)
         
        else:
            theories[i] = observables[i].wmatrix.theory
            emulator = Emulator(theories[i].pt,
                                 engine=TaylorEmulatorEngine(method='finite', order=4))
            emulator.set_samples()
            emulator.fit()
            emulated_pt = emulator.to_calculator()
            emulated_pt.save(emulator_filename)
            theories[i].init.update(pt=emulated_pt)

print('All theories have been emulated successfully' if set_emulator else 'EMULATOR NOT ACTIVATED, proceeding without emulation')

# Analytic marginalization over eft and nuisance parameters
# for i in range(len(theories)): 
#     if prior_basis == 'physical':
#         params_list = ['alpha0p', 'alpha2p', 'alpha4p', 'sn0p', 'sn2p']
#     else:
#         params_list = ['alpha0', 'alpha2', 'alpha4', 'sn0', 'sn2']

#     for param in params_list:    
#         theories[i].params[param].update(derived = '.marg')

        
#Rename the eft and nuisance parameters to get a parameter for each tracer (i.e. QSO_alpha0, QSO_alpha2, BGS_alpha0,...)        
for i in range(len(theories)):    
    for param in theories[i].init.params:
        # Update latex just to have better labels
        param.update(namespace='{}'.format(tracers[i]))
# Out:
# No valid pt_model specified, defaulting to FOLPS model
# Loading matrices from matrices_nfftlog128_Afull_True_remove-DeltaP_False.npy
# Loading matrices from matrices_nfftlog128_Afull_True_remove-DeltaP_False.npy
# h : uniform[0.5, 0.9]({})
# omega_cdm : uniform[0.05, 0.2]({})
# omega_b : norm({'loc': 0.02237, 'scale': 0.00037})
# logA : uniform[2.0, 4.0]({})
# n_s : uniform[0.8, 1.2]({})
# tau_reio : uniform[0.01, 0.8]({})
# m_ncdm : uniform[0.0, 5.0]({})
# N_eff : uniform[0.01, 10.0]({})
# w0_fld : uniform[-3.0, 1.0]({})
# wa_fld : uniform[-3.0, 2.0]({})
# Omega_k : uniform[-0.3, 0.3]({})
# H0 : uniform({})
# Omega_m : uniform({})
# sigma8_m : uniform({})
# b1 : uniform[1e-05, 10]({})
# b2 : uniform[-50, 50]({})
# bs : norm({'loc': 0.0, 'scale': 20.0})
# b3 : uniform({})
# alpha0 : norm({'loc': 0.0, 'scale': 12.5})
# alpha2 : norm({'loc': 0.0, 'scale': 12.5})
# alpha4 : norm({'loc': 0.0, 'scale': 12.5})
# ct : uniform({})
# sn0 : norm({'loc': 0.0, 'scale': 2.0})
# sn2 : norm({'loc': 0.0, 'scale': 5.0})
# X_FoG_p : uniform[0, 10]({})
# [000191.34] [0/1] 08-18 13:56  ObservableCovariance      INFO     Loading /global/cfs/cdirs/desi/survey/catalogs/Y1/LSS/iron/LSScats/v1.5/unblinded/desipipe/forfit_2pt/forfit_power_syst-rotation-hod-photo_klim_0-0.02-0.20_2-0.02-0.20_LRG_GCcomb_z0.4-0.6.npy.
# [0, 2, 4]
# FS emulator 0 already exists, loading it now
# [000191.35] [0/1] 08-18 13:56  Emulator                  INFO     Loading Emulator_test_bs_ps/emu_-LRG1_LRG1.npy.
# All theories have been emulated successfully

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /global/u1/p/prakharb/desilike/desilike/base.py:1212, in BaseCalculator.__getattr__(self, name)
#    1211 try:
# -> 1212     return object.__getattribute__(self, name)
#    1213 except AttributeError as exc:
#
# AttributeError: 'WindowedPowerSpectrumMultipoles' object has no attribute 'flatpower'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# File /global/u1/p/prakharb/desilike/desilike/base.py:1212, in BaseCalculator.__getattr__(self, name)
#    1211 try:
# -> 1212     return object.__getattribute__(self, name)
#    1213 except AttributeError as exc:
#
# File /global/u1/p/prakharb/desilike/desilike/observables/galaxy_clustering/window.py:442, in WindowedPowerSpectrumMultipoles.power(self)
#     440 @property
#     441 def power(self):
# --> 442     return unpack(self.k, self.flatpower)
#
# File /global/u1/p/prakharb/desilike/desilike/base.py:1214, in BaseCalculator.__getattr__(self, name)
#    1213 except AttributeError as exc:
# -> 1214     raise AttributeError('calculator {} has no attribute {}; '
#    1215                          'have you run any calculation already by calling this calculator or calculators '
#    1216                          'that depend on it (typically, a likelihood?)'.format(self.__class__.__name__, name)) from exc
#
# AttributeError: calculator WindowedPowerSpectrumMultipoles has no attribute flatpower; have you run any calculation already by calling this calculator or calculators that depend on it (typically, a likelihood?)
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# File /global/u1/p/prakharb/desilike/desilike/base.py:1212, in BaseCalculator.__getattr__(self, name)
#    1211 try:
# -> 1212     return object.__getattribute__(self, name)
#    1213 except AttributeError as exc:
#
# File /global/u1/p/prakharb/desilike/desilike/observables/galaxy_clustering/power_spectrum.py:380, in TracerPowerSpectrumMultipolesObservable.theory(self)
#     378 @property
#     379 def theory(self):
# --> 380     return self.wmatrix.power
#
# File /global/u1/p/prakharb/desilike/desilike/base.py:1214, in BaseCalculator.__getattr__(self, name)
#    1213 except AttributeError as exc:
# -> 1214     raise AttributeError('calculator {} has no attribute {}; '
#    1215                          'have you run any calculation already by calling this calculator or calculators '
#    1216                          'that depend on it (typically, a likelihood?)'.format(self.__class__.__name__, name)) from exc
#
# AttributeError: calculator WindowedPowerSpectrumMultipoles has no attribute power; have you run any calculation already by calling this calculator or calculators that depend on it (typically, a likelihood?)
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 observables[0].plot()
#
# File /global/u1/p/prakharb/desilike/desilike/plotting.py:148, in plotter.<locals>.get_wrapper.<locals>.wrapper(fn, kw_save, show, fig, *args, **kwargs)
#     145     interactive = kwargs.pop('interactive', None)
#     147 if (interactive is None) or (interactive is False):
# --> 148     fig = func(*args, **kwargs)
#     149     if fn is not None:
#     150         savefig(fn, **(kw_save or {}))
#
# File /global/u1/p/prakharb/desilike/desilike/observables/galaxy_clustering/power_spectrum.py:265, in TracerPowerSpectrumMultipolesObservable.plot(self, scaling, kw_theory, fig)
#     262     lax = fig.axes
#     263     show_legend = False
# --> 265 data, theory, std = self.data, self.theory, self.std
#     266 k_exp = 1 if scaling == 'kpk' else 0
#     268 for ill, ell in enumerate(self.ells):
#
# File /global/u1/p/prakharb/desilike/desilike/base.py:1214, in BaseCalculator.__getattr__(self, name)
#    1212     return object.__getattribute__(self, name)
#    1213 except AttributeError as exc:
# -> 1214     raise AttributeError('calculator {} has no attribute {}; '
#    1215                          'have you run any calculation already by calling this calculator or calculators '
#    1216                          'that depend on it (typically, a likelihood?)'.format(self.__class__.__name__, name)) from exc
#
# AttributeError: calculator TracerPowerSpectrumMultipolesObservable has no attribute theory; have you run any calculation already by calling this calculator or calculators that depend on it (typically, a likelihood?)

# %%
setup_logging()
Likelihoods = []
for i in range(len(theories)):
    Likelihoods.append(ObservablesGaussianLikelihood(observables = [observables[i]]))

# %%
theories[0].all_params['omega_b'].prior
# Out:
# norm({'loc': 0.02237, 'scale': 0.00037})

# %%
likelihood = SumLikelihood(likelihoods = (Likelihoods))

likelihood()

observables[0].plot()



# Run the sampler and save the chain
# from desilike.samplers import EmceeSampler, MCMCSampler

# if sampler == 'cobaya':
#     if restart_chain is False:
#         sampler = MCMCSampler(likelihood, save_fn = chain_name)
#         sampler.run(check={'max_eigen_gr': GR_criteria})
#     else:
#         sampler = MCMCSampler(likelihood ,save_fn = chain_name, 
#                               chains=f'{chain_name}.npy')
#         sampler.run(check={'max_eigen_gr': GR_criteria})
    
# else:
#     if restart_chain is False:
#         sampler = EmceeSampler(likelihood ,save_fn = chain_name)
#         sampler.run(check={'max_eigen_gr': GR_criteria})
#     else:
#         sampler = EmceeSampler(likelihood ,save_fn = chain_name, 
#                                chains=f'{chain_name}.npy')
#         sampler.run(check={'max_eigen_gr': GR_criteria})
# Out:
# /global/u1/p/prakharb/desilike/desilike/base.py:445: UserWarning: Derived parameter loglikelihood of <desilike.likelihoods.base.SumLikelihood object at 0x7fa350730a30> is already derived in <desilike.likelihoods.base.ObservablesGaussianLikelihood object at 0x7fa3507301c0>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike/desilike/base.py:445: UserWarning: Derived parameter logprior of <desilike.likelihoods.base.SumLikelihood object at 0x7fa350730a30> is already derived in <desilike.likelihoods.base.ObservablesGaussianLikelihood object at 0x7fa3507301c0>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# (72,) (72,)

# %%
# Out:
# [000000.00] [0/1] 08-19 09:18  Chain                     INFO     Loading /global/homes/p/prakharb/FOLPSpipe/folps/chains/MCMC-fs_abacus2gen_folpsv2_omegab_sims_fixed_ns_kmax_0.201_standard_bias_X_FoG_fixed.npy.
# chain: Chain(shape=(35070,), params=ParameterCollection(['h', 'omega_cdm', 'omega_b', 'logA', 'LRG2.b1', 'LRG2.b2', 'LRG2.bs', 'fweight', 'logposterior', 'n_s', 'tau_reio', 'm_ncdm', 'N_eff', 'w0_fld', 'wa_fld', 'Omega_k', 'LRG2.b3', 'LRG2.ct', 'LRG2.X_FoG_p', 'H0', 'Omega_m', 'sigma8_m', 'loglikelihood', 'logprior', 'LRG2.alpha0', 'LRG2.alpha2', 'LRG2.sn0', 'LRG2.sn2']))
# Removed no burn in

# %%
# Out:
# 0.6728055102692372

# %% [markdown]
# # Bispectrum Likelihood Tests

# %%
import sys
import os
sys.path.insert(0, "/global/u1/p/prakharb/desilike")
#sys.path.insert(0, "/global/u1/p/prakharb/desilike")
#sys.path.insert(0, "/global/u1/p/prakharb/cosmoprimo")
import desilike, inspect
print(inspect.getfile(desilike))


import numpy as np
import matplotlib.pyplot as plt
from desilike.theories.galaxy_clustering import LPTVelocileptorsTracerPowerSpectrumMultipoles, REPTVelocileptorsTracerPowerSpectrumMultipoles,  DirectPowerSpectrumTemplate, ShapeFitPowerSpectrumTemplate
from desilike.theories.galaxy_clustering.full_shape import FOLPSv2TracerPowerSpectrumMultipoles, FOLPSv2TracerBispectrumMultipoles
from desilike.observables.galaxy_clustering import TracerPowerSpectrumMultipolesObservable 
from desilike.observables import ObservableCovariance
from desilike.emulators import EmulatedCalculator, Emulator, TaylorEmulatorEngine
from desilike.likelihoods import ObservablesGaussianLikelihood, SumLikelihood
from desilike.theories import Cosmoprimo
from cosmoprimo.fiducial import DESI
from desilike import setup_logging
from desilike.parameter import Parameter, ParameterPrior
import argparse
import sys, os, shutil
import time
import emcee
import numpy as np
from schwimmbad import MPIPool
from datetime import datetime
from desilike_mcmc.mike_data_tools import *
# Out:
# /global/u1/p/prakharb/desilike/desilike/__init__.py

# %%
# In[ ]:


######### Settings #########

#model: LCDM or HS
model = 'LCDM'

#Put 'True' to resume chain. 'False' to start from 0 steps
restart_chain = False

#Biasing and EFT parametrization: 'physical' or 'default' (non-physical)
prior_basis = 'standard' #Prior to be used 

k_max = 0.30

#width for EFT and SN paramss
width_EFT = 12.5
width_SN0 = 2.0
width_SN2 = 5.0

pt_model = "folps"  # Change this to "rept_velocileptors" or "pybird" as needed

sampler = 'cobaya'

set_emulator = True

GR_criteria = 0.01  # R - 1 < GR_criteria 


# Argument parser
#parser = argparse.ArgumentParser(description="Run MCMC analysis with different tracers")
#parser.add_argument("--tracers", nargs="+", required=True, help="List of tracers to use")
#args = parser.parse_args()


# List of tracers
# tracers = ['BGS', 'LRG1', 'LRG2', 'LRG3', 'ELG', 'QSO']  # Add more tracers as needed
tracers = ['LRG2']
#tracers = args.tracers
all_tracers = {'BGS', 'LRG1', 'LRG2', 'LRG3', 'ELG', 'QSO'}

if set(tracers) == all_tracers:
    tracers_str = "all"
else:
    tracers_str = "+".join(tracers)

chain_name = f'chains/MCMC-fs_abacus2gen_folpsv2_bispectrum_test'
if not set_emulator:
    chain_name += '_noemu'
#print(chain_name)


# Define file paths for each tracer (in the same order as the tracers list above)
all_tracer_params = {
    'BGS': {
        'data_fn': '/global/cfs/cdirs/desi/survey/catalogs/Y1/LSS/iron/LSScats/v1.5/unblinded/desipipe/forfit_2pt/forfit_power_syst-rotation-hod-photo_klim_0-0.02-0.20_2-0.02-0.20_BGS_BRIGHT-21.5_GCcomb_z0.1-0.4.npy'
    },
    'LRG1': {
        'data_fn': '/global/cfs/cdirs/desi/survey/catalogs/Y1/LSS/iron/LSScats/v1.5/unblinded/desipipe/forfit_2pt/forfit_power_syst-rotation-hod-photo_klim_0-0.02-0.20_2-0.02-0.20_LRG_GCcomb_z0.4-0.6.npy'
    },
    'LRG2': {
        'data_fn': '/global/cfs/cdirs/desi/survey/catalogs/Y1/LSS/iron/LSScats/v1.5/unblinded/desipipe/forfit_2pt/forfit_power_syst-rotation-hod-photo_klim_0-0.02-0.20_2-0.02-0.20_LRG_GCcomb_z0.6-0.8.npy'
    },
    'LRG3': {
        'data_fn': '/global/cfs/cdirs/desi/survey/catalogs/Y1/LSS/iron/LSScats/v1.5/unblinded/desipipe/forfit_2pt/forfit_power_syst-rotation-hod-photo_klim_0-0.02-0.20_2-0.02-0.20_LRG_GCcomb_z0.8-1.1.npy'
    },
    'ELG': {
       'data_fn': '/global/cfs/cdirs/desi/survey/catalogs/Y1/LSS/iron/LSScats/v1.5/unblinded/desipipe/forfit_2pt/forfit_power_syst-rotation-hod-photo_klim_0-0.02-0.20_2-0.02-0.20_ELG_LOPnotqso_GCcomb_z1.1-1.6.npy'
    },
    'QSO': {
        'data_fn': '/global/cfs/cdirs/desi/survey/catalogs/Y1/LSS/iron/LSScats/v1.5/unblinded/desipipe/forfit_2pt/forfit_power_syst-rotation-hod-photo_klim_0-0.02-0.20_2-0.02-0.20_QSO_GCcomb_z0.8-2.1.npy'
    }
}  



#Define a cosmology to get sigma_8, Omega_m and fR0
cosmo = Cosmoprimo(engine='class')
cosmo.init.params['H0'] = dict(derived=True)
cosmo.init.params['Omega_m'] = dict(derived=True)
cosmo.init.params['sigma8_m'] = dict(derived=True) 
#cosmo.init.params['fR0'] = dict(derived=False, latex ='f_{R0}')
fiducial = DESI() #fiducial cosmology

#Update cosmo priors
for param in ['n_s', 'h','omega_cdm', 'omega_b', 'logA', 'tau_reio']:
    cosmo.params[param].update(fixed = False)
    if param == 'tau_reio':
        cosmo.params[param].update(fixed = True)
    if param == 'n_s':
            cosmo.params[param].update(fixed = True)
            # cosmo.params[param].update(prior={'dist': 'norm', 'loc': 0.9649, 'scale': 0.042})
    if param == 'omega_b':
            # cosmo.params[param].update(prior={'dist': 'norm', 'loc': 0.02218, 'scale': 0.00055})
            cosmo.params[param].update(prior={'dist': 'norm', 'loc': 0.02237, 'scale': 0.00037})  #From simulations
    if param == 'h':
            cosmo.params[param].update(prior = {'dist':'uniform','limits': [0.5,0.9]})
    if param == 'omega_cdm':
        cosmo.params[param].update(prior = {'dist':'uniform','limits': [0.05, 0.2]})
    #if param == 'm_ncdm':
        #cosmo.params[param].update(prior = {'dist':'uniform','limits': [0.0, 5]})
    if param == 'logA':
        cosmo.params[param].update(prior = {'dist':'uniform','limits': [2.0, 4.0]})
    #if param == 'fR0':
    #    if model != 'HS':
    #        print('model '+str(model))
    #        cosmo.params[param].update(fixed=True, value=0.0)
    #    else:
    #        print('model HS')
    #        cosmo.params[param].update(
    #        prior={'dist': 'uniform', 'limits': [0, 9e-5]},
    #        fixed=False,
    #        ref={'limits': [0, 9e-5]}
    #        )

#Define tracer types and their corresponding redshifts
all_tracer_redshifts = {
                        'BGS': 0.295,
                        'LRG1': 0.510,
                        'LRG2': 0.8,
                        'LRG3': 0.930,
                        'ELG': 1.317,
                        'QSO': 1.491
                        }

tracer_params = {index: all_tracer_params[tracer] for index, tracer in enumerate(tracers)}
tracer_redshifts = {tracer: all_tracer_redshifts[tracer] for tracer in tracers}

#Initialize an empty list to store the theory objects
theories = []

#Iterate over each tracer and create the corresponding theory object
for tracer in tracers:
    if tracer in tracer_redshifts:
        z = tracer_redshifts[tracer]
    else:
        print(f'Invalid tracer: {tracer}. Skipping.') 
        continue

    #Create the template and theory objects
    template = DirectPowerSpectrumTemplate(fiducial = fiducial,cosmo = cosmo, z=z) #cosmology and fiducial cosmology defined above
    

    # Activate the corresponding model
    if pt_model == "lpt_velocileptors":
        print("LPTVelocileptorsTracerPowerSpectrumMultipoles activated")
        theory = LPTVelocileptorsTracerPowerSpectrumMultipoles(template=template, prior_basis="physical")
    elif pt_model == "rept_velocileptors":
        print("REPTVelocileptorsTracerPowerSpectrumMultipoles activated")
        theory = REPTVelocileptorsTracerPowerSpectrumMultipoles(template=template, prior_basis="physical")
    elif pt_model == "ept_velocileptors":
        print("EPTMomentsVelocileptorsTracerPowerSpectrumMultipoles activated")
        theory = EPTMomentsVelocileptorsTracerPowerSpectrumMultipoles(template=template, prior_basis="physical")
    elif pt_model == "pybird":
        print("PyBirdPowerSpectrumMultipoles activated")
        theory = PyBirdPowerSpectrumMultipoles(template=template, prior_basis="physical")
    else:
        print("No valid pt_model specified, defaulting to FOLPS model")
        theory = FOLPSv2TracerBispectrumMultipoles(template=template, prior_basis="standard") #Add the prior_basis='physical' argument to use physically motivated priors

    #Update bias and EFT priors
    #theory.params['bs'].update(fixed=True)
    if prior_basis == 'physical':
        theory.params['b1p'].update(prior = {'dist':'uniform','limits': [1e-5, 10]})
        theory.params['b2p'].update(prior = {'dist':'uniform','limits': [-50, 50]})
        theory.params['bsp'].update(prior = {'dist': 'norm', 'loc': 0, 'scale': 20})
        theory.params['alpha0p'].update(prior={'dist': 'norm', 'loc': 0, 'scale': width_EFT})
        theory.params['alpha2p'].update(prior={'dist': 'norm', 'loc': 0, 'scale': width_EFT})
        theory.params['alpha4p'].update(prior={'dist': 'norm', 'loc': 0, 'scale': width_EFT})
        theory.params['sn0p'].update(prior={'dist': 'norm', 'loc': 0, 'scale': width_SN0})
        theory.params['sn2p'].update(prior={'dist': 'norm', 'loc': 0, 'scale': width_SN2})
        #theory.params['X_FoG_p'].update(prior = {'dist':'uniform','limits': [0, 10]})
    else:
        theory.params['b1'].update(prior = {'dist':'uniform','limits': [1e-5, 10]})
        theory.params['b2'].update(prior = {'dist':'uniform','limits': [-50, 50]})
        theory.params['bs'].update(prior = {'dist': 'norm', 'loc': 0, 'scale': 20})
        for param in ['c1', 'c2','Pshot', 'Bshot', 'X_FoG_b']:
            theory.params[param].update(fixed = False)
        theory.params['c1'].update(prior={'min': -2000, 'max': 2000})
        theory.params['c2'].update(prior={'min': -2000, 'max': 2000})
        theory.params['Pshot'].update(prior={'min': -50000, 'max': 50000})
        theory.params['Bshot'].update(prior={'min': -50000, 'max': 50000})
        # theory.params['sn2'].update(prior={'dist': 'norm', 'loc': 0, 'scale': width_SN2})
        # theory.params['X_FoG_b'].update(fixed=True)
        theory.params['X_FoG_b'].update(prior={'min': 0, 'max': 10})
    print("X_FoG_b=",theory.params['X_FoG_b'].value)
    #Append the theory object to the list
    theories.append(theory)

#Print used priors
for param in theory.all_params:
    print(param,':',theory.all_params[param].prior)

#Define data vector and covariance using mike data tools

def load_data_vector_and_covariance():
    k_min=0.02
    k_max=0.201
    k_max_b0 = 0.20
    k_max_b2 = 0.14

    isP0, isP2, isP4 =False, False, False
    isB000, isB202 = True, True

    Vol=1

    tracer='LRG'
    z_str='z0.800'
    z_evaluation=0.8

    path_fits='chains/'

    now = datetime.now()
    tiempo=now.strftime("%m-%d-%Y-%H%M")

    name=f"c_FolpsD__{tracer}_z{z_evaluation:.3f}_Pkmax-{k_max:.3f}_B000kmax-{k_max_b0:.3f}_B202kmax-{k_max_b2:.3f}_bsfree"


    chains_filename = path_fits+name+".h5"
    copy_filename = path_fits+name+".py"
    print(chains_filename)
        

    # +
    k_data_2nd,pkl0_2nd_all,pkl2_2nd_all,a,B000_2nd_all,B202_2nd_all = ExtractDataAbacusSummit(tracer,z_str,
                                                                                            subtract_shot=True)

    Pk_0_2nd = np.mean(pkl0_2nd_all,axis = 0)
    Pk_2_2nd = np.mean(pkl2_2nd_all,axis = 0)
    B000_2nd = np.mean(B000_2nd_all,axis = 0)
    B202_2nd = np.mean(B202_2nd_all,axis = 0)

    # Read covariance

    k_eff_all,pkl0ezmocks,pkl2ezmocks,pkl4ezmocks,B000ezmocks,B202ezmocks = ExtractDataEZmock(tracer,z_str)
    k_cov_all, mean_ezmocks_all, cov_array_all = covariance(k_eff_all,pkl0ezmocks,pkl2ezmocks,pkl4ezmocks,B000ezmocks,B202ezmocks, Nscaling = Vol)



    pole_selection=[isP0, isP2, isP4,isB000, isB202]
    print(pole_selection)

    kmin_pk=0.02; kmax_pk=k_max
    kmin_bk=0.02; 
    ranges=[[kmin_pk,kmax_pk],[kmin_pk,kmax_pk],[kmin_pk,kmax_pk],[kmin_bk,k_max_b0],[kmin_bk,k_max_b2]]

    mask=pole_k_selection(k_cov_all,pole_selection,ranges)
    #print(mask.shape)
    #print(mask)
    k_cov=k_cov_all[mask]

    #k_cov.shape
    k_points_pk = np.where((kmin_pk < k_data_2nd) & (k_data_2nd < kmax_pk)  & isP0)
    k_points_b0 = np.where((kmin_bk < k_data_2nd) & (k_data_2nd < k_max_b0) & isB000)
    k_points_b2 = np.where((kmin_bk < k_data_2nd) & (k_data_2nd < k_max_b2) & isB202)

    data = np.concatenate((Pk_0_2nd[k_points_pk],Pk_2_2nd[k_points_pk],
                        B000_2nd[k_points_b0],B202_2nd[k_points_b2]))
    kr_pk=k_data_2nd[k_points_pk]
    kr_b0=k_data_2nd[k_points_b0]
    kr_b2=k_data_2nd[k_points_b2]

    numberofpk0points=len(Pk_0_2nd[k_points_pk])
    numberofbk0points=len(B000_2nd[k_points_b0])
    numberofbk2points=len(B202_2nd[k_points_b2])

    cov_array=cov_array_all[np.ix_(mask, mask)]
    totsim = 2000 #number of sims
    n_data = len(data)
    Hartlap = (totsim - 1.) / (totsim - n_data - 2.)
    Hartlap
    cov_arr = cov_array * Hartlap
    # cov_inv_arr = np.linalg.inv(cov_arr)
    
    # kr_pk = np.load("./desilike_mcmc/kr_pk.npy")
    # data = np.load("./desilike_mcmc/data.npy")
    # cov_arr = np.load("./desilike_mcmc/cov.npy")
    # np.save("./desilike_mcmc/kr_b0.npy",kr_b0)
    # np.save("./desilike_mcmc/data_b0.npy",data)
    # np.save("./desilike_mcmc/cov_b0.npy",cov_array)
    return data, cov_array, kr_b0, kr_b2

def load_data_vector_and_covariance_files():
    # kr_pk = np.load("./desilike_mcmc/kr_pk.npy")
    # data = np.load("./desilike_mcmc/data.npy")
    # cov_arr = np.load("./desilike_mcmc/cov.npy")
    kr_b0 = np.load("./desilike_mcmc/kr_b0.npy")
    kr_b2 = np.load("./desilike_mcmc/kr_b2.npy")
    data = np.load("./desilike_mcmc/data_b02.npy")
    cov_arr = np.load("./desilike_mcmc/cov_b02.npy")
    return data, cov_arr, kr_b0,kr_b2


#Define a function to create an observable
def create_observable( #wmatrix_fn, covariance_fn,
                      theory, tracer_index):
   
    # data, cov_arr, kr_b0 = load_data_vector_and_covariance()
    # data, cov_arr, kr_b0, kr_b2 = load_data_vector_and_covariance_files()
    data, cov_arr, kr_b0, kr_b2 = load_data_vector_and_covariance()
    print(data.shape,cov_arr.shape,kr_b0.shape, kr_b2.shape)
    
    
    k_max = 0.30
    return TracerPowerSpectrumMultipolesObservable(
        data=data,
        covariance=0.2*cov_arr,
        # k={ell: kr_b0 for ell in [0,2]},
        theory=theories[tracer_index],
        ells = [0,2],
        k = [kr_b0,kr_b2]
        # k={(0,0,0): kr_b0, (2,0,2):kr_b2}
    )

    

#Create observables for each tracer
observables = [create_observable(
                                 #params['wmatrix_fn'], params['covariance_fn'],
                                 theories, i) 
                for i, params in tracer_params.items()]


if set_emulator:
    # Create an emulated theory for each tracer
    for i in range(len(theories)):
        emulator_filename = f'Emulator_test_sims_bispectrum/emu_-{tracers_str}_{str(tracers[i])}_0.20_0.14.npy'
        
        if os.path.exists(emulator_filename):
            print(f"FS emulator {i} already exists, loading it now")
            emulator = EmulatedCalculator.load(emulator_filename)  
            theories[i].init.update(pt=emulator)
            print(type(theories[i].pt))
         
        else:
            theories[i] = observables[i].wmatrix.theory
            emulator = Emulator(theories[i].pt,
                                 engine=TaylorEmulatorEngine(method='finite', order=4))
            emulator.set_samples()
            emulator.fit()
            
            emulated_pt = emulator.to_calculator()
            emulated_pt.save(emulator_filename)
            theories[i].init.update(pt=emulated_pt)

            
            

print('All theories have been emulated successfully' if set_emulator else 'EMULATOR NOT ACTIVATED, proceeding without emulation')

# Analytic marginalization over eft and nuisance parameters
# for i in range(len(theories)): 
#     if prior_basis == 'physical':
#         params_list = ['alpha0p', 'alpha2p', 'alpha4p', 'sn0p', 'sn2p']
#     else:
#         params_list = ['c1', 'c2', 'Pshot', 'Bshot']

#     for param in params_list:    
#         theories[i].params[param].update(derived = '.marg')

        
#Rename the eft and nuisance parameters to get a parameter for each tracer (i.e. QSO_alpha0, QSO_alpha2, BGS_alpha0,...)        
for i in range(len(theories)):    
    for param in theories[i].init.params:
        # Update latex just to have better labels
        param.update(namespace='{}'.format(tracers[i]))
# Out:
# No valid pt_model specified, defaulting to FOLPS model
# X_FoG_b= 0.0
# ✅ Using NumPy with CPU.
# Loading matrices from matrices_nfftlog128_Afull_True_remove-DeltaP_False.npy
# /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/code/cosmoprimo/main/lib/python3.10/site-packages/cosmoprimo/eisenstein_hu.py:25: UserWarning: EisensteinHuNoWiggleEngine cannot cope with massive neutrinos
#   warnings.warn('{} cannot cope with massive neutrinos'.format(self.__class__.__name__))
# h : uniform[0.5, 0.9]({})
# omega_cdm : uniform[0.05, 0.2]({})
# omega_b : norm({'loc': 0.02237, 'scale': 0.00037})
# logA : uniform[2.0, 4.0]({})
# n_s : uniform[0.8, 1.2]({})
# tau_reio : uniform[0.01, 0.8]({})
# m_ncdm : uniform[0.0, 5.0]({})
# N_eff : uniform[0.01, 10.0]({})
# w0_fld : uniform[-3.0, 1.0]({})
# wa_fld : uniform[-3.0, 2.0]({})
# Omega_k : uniform[-0.3, 0.3]({})
# H0 : uniform({})
# Omega_m : uniform({})
# sigma8_m : uniform({})
# b1 : uniform[1e-05, 10]({})
# b2 : uniform[-50, 50]({})
# bs : norm({'loc': 0.0, 'scale': 20.0})
# c1 : uniform({'min': -2000, 'max': 2000})
# c2 : uniform({'min': -2000, 'max': 2000})
# Pshot : uniform({'min': -50000, 'max': 50000})
# Bshot : uniform({'min': -50000, 'max': 50000})
# X_FoG_b : uniform({'min': 0, 'max': 10})
# chains/c_FolpsD__LRG_z0.800_Pkmax-0.201_B000kmax-0.200_B202kmax-0.140_bsfree.h5
# [False, False, False, True, True]
# (60,) (60, 60) (36,) (24,)
# FS emulator 0 already exists, loading it now
# <class 'desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles'>
# All theories have been emulated successfully

# %%
cosmo = Cosmoprimo(engine='class')
cosmo.init.params['H0'] = dict(derived=True)
cosmo.init.params['Omega_m'] = dict(derived=True)
cosmo.init.params['sigma8_m'] = dict(derived=True) 
z = 0.8
def load_data_vector_and_covariance_files():
    # kr_pk = np.load("./desilike_mcmc/kr_pk.npy")
    # data = np.load("./desilike_mcmc/data.npy")
    # cov_arr = np.load("./desilike_mcmc/cov.npy")
    kr_pk = np.load("./desilike_mcmc/kr_b0.npy")
    data = np.load("./desilike_mcmc/data_b0.npy")
    cov_arr = np.load("./desilike_mcmc/cov_b0.npy")
    return data, cov_arr, kr_pk


#Define a function to create an observable
def create_observable( #wmatrix_fn, covariance_fn,
                      theory, tracer_index):
   
    # data, cov_arr, kr_b0 = load_data_vector_and_covariance()
    data, cov_arr, kr_b0 = load_data_vector_and_covariance_files()
    print(data.shape,cov_arr.shape,kr_b0.shape)
    
    #Create and return the observable: following  https://desi.lbl.gov/trac/wiki/keyprojects/y1kp3/clusteringproducts#a101:Iwanttowritemychi2
    return TracerPowerSpectrumMultipolesObservable(
        data=data,
        covariance=cov_arr,
        theory=theory,
        k=kr_b0,
        ells=[0,2]
    )
#cosmo.init.params['fR0'] = dict(derived=False, latex ='f_{R0}')
fiducial = DESI() #fiducial cosmology
template = DirectPowerSpectrumTemplate(fiducial = fiducial,cosmo = cosmo, z=z) #cosmology and fiducial cosmology defined above
# theory = FOLPSv2TracerBispectrumMultipoles(template=template, prior_basis="standard") #Add the prior_basis='physical' argument to use physically motivated priors
# theory = FOLPSv2TracerPowerSpectrumMultipoles(template=template, prior_basis="standard") #Add the prior_basis='physical' argument to use physically motivated priors
emulator_filename = '/global/homes/p/prakharb/FOLPSpipe/folps/Emulator_test_sims_bispectrum/emu_-LRG2_LRG2_new.npy'
# emulator_filename = '/global/homes/p/prakharb/FOLPSpipe/folps/Emulator_test_sims/emu_-LRG2_LRG2.npy'
emulator = EmulatedCalculator.load(emulator_filename)  
theory = FOLPSv2TracerBispectrumMultipoles(template=template, pt = emulator,prior_basis="standard")
print(type(theory.pt))
observables = create_observable(theory,1) 
setup_logging()
Likelihoods = []
Likelihoods.append(ObservablesGaussianLikelihood(observables = observables))


#Sum the likelihoods and initialize
likelihood = SumLikelihood(likelihoods = (Likelihoods))

likelihood()
# Out:
# [000053.25] [0/1] 08-17 18:51  Emulator                  INFO     Loading /global/homes/p/prakharb/FOLPSpipe/folps/Emulator_test_sims_bispectrum/emu_-LRG2_LRG2_new.npy.
# <class 'desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles'>
# (48,) (48, 48) (24,)
# /global/u1/p/prakharb/desilike/desilike/base.py:445: UserWarning: Derived parameter loglikelihood of <desilike.likelihoods.base.SumLikelihood object at 0x7f440c41a7a0> is already derived in <desilike.likelihoods.base.ObservablesGaussianLikelihood object at 0x7f440c406cb0>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike/desilike/base.py:445: UserWarning: Derived parameter logprior of <desilike.likelihoods.base.SumLikelihood object at 0x7f440c41a7a0> is already derived in <desilike.likelihoods.base.ObservablesGaussianLikelihood object at 0x7f440c406cb0>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# 0.5509839057922363
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 51
#      48 #Sum the likelihoods and initialize
#      49 likelihood = SumLikelihood(likelihoods = (Likelihoods))
# ---> 51 likelihood()
#
# File /global/u1/p/prakharb/desilike/desilike/base.py:1194, in BaseCalculator.__call__(self, *args, **kwargs)
#    1192 def __call__(self, *args, **kwargs):
#    1193     """Take all parameters as input, calculate, and return the result of :attr:`get`"""
# -> 1194     return self.runtime_info.pipeline.calculate(*args, **kwargs)
#
# File /global/u1/p/prakharb/desilike/desilike/base.py:548, in BasePipeline.calculate(self, force, return_derived, *args, **kwargs)
#     546 derived = Samples()
#     547 try:
# --> 548     result = runtime_info.calculate(params, force=force)
#     549     if self.derived is not None:
#     550         derived = runtime_info.derived
#
# File /global/u1/p/prakharb/desilike/desilike/base.py:1069, in RuntimeInfo.calculate(self, params, force)
#    1067 self._calculation = True
#    1068 self.monitor.start()
# -> 1069 self.calculator.calculate(**self.input_values)
#    1070 self._derived = None
#    1071 self.calculated = True
#
# File /global/u1/p/prakharb/desilike/desilike/observables/galaxy_clustering/window.py:433, in WindowedPowerSpectrumMultipoles.calculate(self)
#     432 def calculate(self):
# --> 433     self.flatpower = self._apply(self.theory.power + self.shotnoisein[:, None]) - self.shotnoiseout
#     434     if self.systematic_templates is not None:
#     435         self.flatpower += self.systematic_templates.flatpower
#
# File /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/jax/_src/numpy/array_methods.py:271, in _defer_to_unrecognized_arg.<locals>.deferring_binary_op(self, other)
#     269 args = (other, self) if swap else (self, other)
#     270 if isinstance(other, _accepted_binop_types):
# --> 271   return binary_op(*args)
#     272 # Note: don't use isinstance here, because we don't want to raise for
#     273 # subclasses, e.g. NamedTuple objects that may override operators.
#     274 if type(other) in _rejected_binop_types:
#
#     [... skipping hidden 12 frame]
#
# File /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/jax/_src/numpy/ufuncs.py:84, in _one_to_one_binop.<locals>.<lambda>(x1, x2)
#      82   fn = lambda x1, x2, /: lax_fn(*promote_args_numeric(numpy_fn.__name__, x1, x2))
#      83 else:
# ---> 84   fn = lambda x1, x2, /: lax_fn(*promote_args(numpy_fn.__name__, x1, x2))
#      85 fn.__qualname__ = f"jax.numpy.{numpy_fn.__name__}"
#      86 fn = jit(fn, inline=True)
#
#     [... skipping hidden 7 frame]
#
# File /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/jax/_src/lax/lax.py:1599, in broadcasting_shape_rule(name, *avals)
#    1597       result_shape.append(non_1s[0])
#    1598     else:
# -> 1599       raise TypeError(f'{name} got incompatible shapes for broadcasting: '
#    1600                       f'{", ".join(map(str, map(tuple, shapes)))}.')
#    1602 return tuple(result_shape)
#
# TypeError: sub got incompatible shapes for broadcasting: (202,), (48,).

# %%
#Create a likelihood per theory object
setup_logging()
Likelihoods = []
for i in range(len(theories)):
    Likelihoods.append(ObservablesGaussianLikelihood(observables = [observables[i]]))


#Sum the likelihoods and initialize
likelihood = SumLikelihood(likelihoods = (Likelihoods))

likelihood()



# from desilike.samplers import EmceeSampler, MCMCSampler
# from desilike.profilers import MinuitProfiler

# sampler = MCMCSampler(likelihood, save_fn = './chains/trial.npy')
# sampler.run(check={'max_eigen_gr': GR_criteria})

# profiler = MinuitProfiler(likelihood, seed=42)
# profiles = profiler.maximize()
# print(profiles.to_stats(tablefmt='pretty'))
# Out:
# /global/u1/p/prakharb/desilike/desilike/base.py:445: UserWarning: Derived parameter loglikelihood of <desilike.likelihoods.base.SumLikelihood object at 0x7f23f83b9f00> is already derived in <desilike.likelihoods.base.ObservablesGaussianLikelihood object at 0x7f241c485480>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike/desilike/base.py:445: UserWarning: Derived parameter logprior of <desilike.likelihoods.base.SumLikelihood object at 0x7f23f83b9f00> is already derived in <desilike.likelihoods.base.ObservablesGaussianLikelihood object at 0x7f241c485480>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# Array(-23920.61443719, dtype=float64)

# %%
# Best-fit plotting
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
from desilike.samples import Chain
from desilike import setup_logging
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
setup_logging()

#funtion to load numpy chains
def load_chain(fi, burnin=0.3):
    from desilike.samples import Chain
    # chains = [Chain.load(ff).remove_burnin(burnin) for ff in fi]
    chains = [Chain.load(fi).remove_burnin(burnin)]
    chain = chains[0].concatenate(chains)
    print(f'chain: {chain}')
    return chain
chain_path = Path('/global/homes/p/prakharb/FOLPSpipe/folps/chains/MCMC-fs_abacus2gen_folpsv2_bispectrum_test_0.20_0.14_var_nuis_uniform_0.2cov.npy')
chain = load_chain(chain_path)
likelihood(**chain.choice(index='argmax', input=True))  # evaluate at the point with maximum logposterior in the chain
# Out:
# [000000.00] [0/1] 08-19 18:38  Chain                     INFO     Loading /global/homes/p/prakharb/FOLPSpipe/folps/chains/MCMC-fs_abacus2gen_folpsv2_bispectrum_test_0.20_0.14_var_nuis_uniform_0.2cov.npy.
# chain: Chain(shape=(8190,), params=ParameterCollection(['h', 'omega_cdm', 'omega_b', 'logA', 'LRG2.b1', 'LRG2.b2', 'LRG2.bs', 'LRG2.c1', 'LRG2.c2', 'LRG2.Pshot', 'LRG2.Bshot', 'LRG2.X_FoG_b', 'fweight', 'logposterior', 'n_s', 'tau_reio', 'm_ncdm', 'N_eff', 'w0_fld', 'wa_fld', 'Omega_k', 'H0', 'Omega_m', 'sigma8_m', 'loglikelihood', 'logprior']))
# Array(-8.52748419, dtype=float64)

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_scaled(observable, scaling='kpk', extra_power=1, kw_theory=None,
                fn=None, kw_save=None, show=False):
    """
    Plot multipoles with an additional scaling by k**extra_power.

    Parameters
    ----------
    observable : TracerPowerSpectrumMultipolesObservable
    scaling : str
        'kpk' or 'loglog', same as in observable.plot
    extra_power : int or float
        Additional power of k to multiply spectra by (default = 1 means multiply by k)
    kw_theory : dict or list of dict
        Line style options for theory curves
    fn : str or Path, optional
        If provided, path where to save figure.
    kw_save : dict, optional
        Extra keyword args passed to fig.savefig.
    show : bool, default=False
        If True, call plt.show() after plotting.
    """
    if kw_theory is None:
        kw_theory = {}
    if isinstance(kw_theory, dict):
        kw_theory = [kw_theory] * len(observable.ells)

    data, theory, std = observable.data, observable.theory, observable.std
    k = observable.k

    # base exponent from scaling mode
    k_exp = 1 if scaling == 'kpk' else 0
    k_exp += extra_power  # add your extra multiplication

    # setup figure (similar to observable.plot)
    height_ratios = [max(len(observable.ells), 3)] + [1] * len(observable.ells)
    figsize = (6, 1.5 * sum(height_ratios))
    fig, lax = plt.subplots(len(height_ratios), sharex=True,
                            gridspec_kw={'height_ratios': height_ratios},
                            figsize=figsize)
    fig.subplots_adjust(hspace=0.1)

    # main spectrum panel
    for ill, ell in enumerate(["000","202"]):
        color = f"C{ill}"
        lax[0].errorbar(k[ill], k[ill]**k_exp * data[ill],
                        yerr=k[ill]**k_exp * std[ill],
                        color=color, linestyle='none', marker='o',
                        label=fr"$\ell = {ell}$")
        lax[0].plot(k[ill], k[ill]**k_exp * theory[ill],
                    color=color, **kw_theory[ill])

    # residual panels
    for ill, ell in enumerate(["000","202"]):
        ax = lax[ill+1]
        ratio = (data[ill] - theory[ill]) / std[ill]
        ax.plot(k[ill], ratio, color=f"C{ill}")
        ax.set_ylim(-4, 4)
        for offset in [-2., 2.]:
            ax.axhline(offset, color='k', linestyle='--')
        ax.set_ylabel(rf"$\Delta B_{{{ell}}} / \sigma_{{B_{{{ell}}}}}$")

    # axis labels / scales
    lax[0].legend()
    if scaling == 'kpk':
        lax[0].set_ylabel(r"$k^2 B_{\ell}(k)$ $[({\rm Mpc}/h)^2]$")
    elif scaling == 'loglog':
        lax[0].set_ylabel(r"$P_{\ell}(k)$ $[({\rm Mpc}/h)^3]$")
        lax[0].set_xscale("log")
        lax[0].set_yscale("log")

    lax[-1].set_xlabel(r"$k$ [$h/{\rm Mpc}$]")
    for ax in lax: ax.grid(True)

    # save if requested
    if fn is not None:
        if kw_save is None:
            kw_save = {}
        fig.savefig(fn, **kw_save)

    if show:
        plt.show()

    return fig


def load_chain(fi, burnin=0.3):
    from desilike.samples import Chain
    # chains = [Chain.load(ff).remove_burnin(burnin) for ff in fi]
    chains = [Chain.load(fi).remove_burnin(burnin)]
    chain = chains[0].concatenate(chains)
    print(f'chain: {chain}')
    return chain
chain_path = Path('/global/homes/p/prakharb/FOLPSpipe/folps/chains/MCMC-fs_abacus2gen_folpsv2_bispectrum_test_0.20_0.14_var_nuis_0.2cov.npy')
chain = load_chain(chain_path)
likelihood(**chain.choice(index='argmax', input=True))
plot_scaled(observables[0], extra_power=1)
# Out:
# [000010.28] [0/1] 08-19 18:38  Chain                     INFO     Loading /global/homes/p/prakharb/FOLPSpipe/folps/chains/MCMC-fs_abacus2gen_folpsv2_bispectrum_test_0.20_0.14_var_nuis_0.2cov.npy.
# chain: Chain(shape=(9240,), params=ParameterCollection(['h', 'omega_cdm', 'omega_b', 'logA', 'LRG2.b1', 'LRG2.b2', 'LRG2.bs', 'LRG2.c1', 'LRG2.c2', 'LRG2.Pshot', 'LRG2.Bshot', 'LRG2.X_FoG_b', 'fweight', 'logposterior', 'n_s', 'tau_reio', 'm_ncdm', 'N_eff', 'w0_fld', 'wa_fld', 'Omega_k', 'H0', 'Omega_m', 'sigma8_m', 'loglikelihood', 'logprior']))

# %%
from desilike.theories.galaxy_clustering import FixedPowerSpectrumTemplate, LPTVelocileptorsTracerPowerSpectrumMultipoles, KaiserTracerPowerSpectrumMultipoles, DirectPowerSpectrumTemplate,FixedPowerSpectrumTemplate
from desilike.theories.galaxy_clustering.full_shape import  FOLPSv2TracerPowerSpectrumMultipoles,FOLPSAXTracerPowerSpectrumMultipoles, PyBirdTracerPowerSpectrumMultipoles, FOLPSv2TracerBispectrumMultipoles, GeoFPTAXTracerBispectrumMultipoles
from desilike.observables import ObservableCovariance
from desilike.observables.galaxy_clustering import TracerPowerSpectrumMultipolesObservable
from desilike.likelihoods import ObservablesGaussianLikelihood
from desilike.profilers import MinuitProfiler
from desilike import setup_logging

setup_logging()

template = DirectPowerSpectrumTemplate(z=1.1)
theory = FOLPSv2TracerBispectrumMultipoles(template=template, tracer='ELG',kernels='fk',prior_basis='standard',damping='lor')
# theory = FOLPSv2TracerPowerSpectrumMultipoles(template=template)
# theory = GeoFPTAXTracerBispectrumMultipoles(template=template)
# from desilike.emulators import Emulator, EmulatedCalculator, TaylorEmulatorEngine
# emulator = Emulator(theory, engine=TaylorEmulatorEngine(order={'*': 2, 'sn0': 1}))  # order 2 except for sn0 (order 1 is enough)
# emulator.set_samples()
# emulator.fit()
# emulator.plot(name='power')

# emulated_pt = emulator.to_calculator()
# emulated_pt.save(emulator_filename)
# theory.init.update(pt=emulated_pt)
theory()
# Out:
# Loading matrices from matrices_nfftlog128_Afull_True_remove-DeltaP_False.npy
# 0.03948068618774414
# (array([9.10835602e+08, 1.03150585e+09, 1.11004705e+09, 1.14921646e+09,
#         1.15464134e+09, 1.13200272e+09, 1.08791642e+09, 1.02940296e+09,
#         9.61744396e+08, 8.89610968e+08, 8.16789869e+08, 7.46296112e+08,
#         6.79927982e+08, 6.18893951e+08, 5.63875375e+08, 5.15041789e+08,
#         4.72263618e+08, 4.35094105e+08, 4.02912198e+08, 3.75015020e+08,
#         3.50728703e+08, 3.29967896e+08, 3.12196149e+08, 2.96315127e+08,
#         2.82078508e+08, 2.69575058e+08, 2.57793215e+08, 2.46808112e+08,
#         2.36240185e+08, 2.26001664e+08, 2.15734358e+08, 2.05668962e+08,
#         1.95340390e+08, 1.85202293e+08, 1.74823071e+08, 1.64706278e+08,
#         1.54500707e+08, 1.44635388e+08, 1.35016832e+08, 1.25738188e+08,
#         1.17036898e+08, 1.08750136e+08, 1.01006636e+08, 9.40473134e+07,
#         8.73432058e+07, 8.16521230e+07, 7.63440216e+07, 7.13818570e+07,
#         6.74599077e+07, 6.36473470e+07, 6.02867421e+07, 5.75813698e+07,
#         5.49488455e+07, 5.26576869e+07, 5.07865876e+07, 4.89604929e+07,
#         4.72896273e+07, 4.58698736e+07, 4.44824304e+07, 4.31302034e+07,
#         4.18363822e+07, 4.05670011e+07, 3.93190530e+07, 3.80138049e+07,
#         3.66745870e+07, 3.53594236e+07, 3.40613084e+07, 3.26571424e+07,
#         3.12734872e+07, 2.99184006e+07, 2.85833397e+07, 2.72655134e+07,
#         2.59780605e+07, 2.47214350e+07, 2.35069460e+07, 2.24376100e+07,
#         2.13940416e+07, 2.03762954e+07, 1.93892506e+07, 1.85974066e+07,
#         1.78519045e+07, 1.71239121e+07, 1.64159872e+07, 1.57948516e+07,
#         1.52920356e+07, 1.47982700e+07, 1.43131222e+07, 1.38437381e+07,
#         1.34442074e+07, 1.30798511e+07, 1.27205878e+07, 1.23663503e+07,
#         1.20216499e+07, 1.16880574e+07, 1.13612675e+07, 1.10391631e+07,
#         1.07217180e+07, 1.04092411e+07, 1.00894666e+07, 9.76164488e+06,
#         9.43947652e+06]),
#  array([5.92078968e+08, 6.73840362e+08, 7.28070045e+08, 7.55993634e+08,
#         7.60959034e+08, 7.46484581e+08, 7.16950887e+08, 6.77195531e+08,
#         6.30831367e+08, 5.81280476e+08, 5.31193417e+08, 4.82776367e+08,
#         4.37349342e+08, 3.95779812e+08, 3.58551480e+08, 3.25767202e+08,
#         2.97304261e+08, 2.72803888e+08, 2.51789424e+08, 2.33746376e+08,
#         2.18183540e+08, 2.05022077e+08, 1.93869428e+08, 1.83962801e+08,
#         1.75120483e+08, 1.67425331e+08, 1.60174272e+08, 1.53415326e+08,
#         1.46910754e+08, 1.40588602e+08, 1.34222794e+08, 1.27965075e+08,
#         1.21502240e+08, 1.15148584e+08, 1.08602005e+08, 1.02218980e+08,
#         9.57437471e+07, 8.94860960e+07, 8.33675696e+07, 7.74614137e+07,
#         7.19298424e+07, 6.66561107e+07, 6.17386133e+07, 5.73292328e+07,
#         5.30823103e+07, 4.95023041e+07, 4.61697364e+07, 4.30556325e+07,
#         4.06271249e+07, 3.82670891e+07, 3.61900139e+07, 3.45432928e+07,
#         3.29390349e+07, 3.15464885e+07, 3.04255728e+07, 2.93293305e+07,
#         2.83239771e+07, 2.74761553e+07, 2.66444379e+07, 2.58310661e+07,
#         2.50452835e+07, 2.42707474e+07, 2.35091331e+07, 2.27040375e+07,
#         2.18702186e+07, 2.10514202e+07, 2.02455427e+07, 1.93646196e+07,
#         1.84961255e+07, 1.76470890e+07, 1.68135818e+07, 1.59904760e+07,
#         1.51871991e+07, 1.44045969e+07, 1.36504668e+07, 1.29939894e+07,
#         1.23534382e+07, 1.17295315e+07, 1.11241808e+07, 1.06491498e+07,
#         1.02038604e+07, 9.76890641e+06, 9.34537998e+06, 8.97754287e+06,
#         8.68832795e+06, 8.40375031e+06, 8.12411811e+06, 7.85223920e+06,
#         7.62604260e+06, 7.42277506e+06, 7.22210222e+06, 7.02418931e+06,
#         6.83081107e+06, 6.64425044e+06, 6.46158002e+06, 6.28134640e+06,
#         6.10367367e+06, 5.92868313e+06, 5.74797087e+06, 5.56073686e+06,
#         5.37646936e+06]))

# %%
b2 = best_fit.copy()
b2['b1']=10
b2['Pshot']=40000
observables[0].plot(b2,scaling='loglog')
b2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 4
#       2 b2['b1']=10
#       3 b2['Pshot']=40000
# ----> 4 observables[0].plot(b2(input=True),scaling='loglog')
#       5 b2
#
# TypeError: 'dict' object is not callable

# %%
#Create a likelihood per theory object
setup_logging()
Likelihoods = []
for i in range(len(theories)):
    Likelihoods.append(ObservablesGaussianLikelihood(observables = [observables[i]]))


#Sum the likelihoods and initialize
likelihood = SumLikelihood(likelihoods = (Likelihoods))

likelihood()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       2 setup_logging()
#       3 Likelihoods = []
# ----> 4 for i in range(len(theories)):
#       5     Likelihoods.append(ObservablesGaussianLikelihood(observables = [observables[i]]))
#       8 #Sum the likelihoods and initialize
#
# NameError: name 'theories' is not defined

# %%
#Create a likelihood per theory object



#Sum the likelihoods and initialize
# likelihood = SumLikelihood(likelihoods = (Likelihoods))

# likelihood()


# In[ ]:


#Run the sampler and save the chain
from desilike.samplers import EmceeSampler, MCMCSampler

if sampler == 'cobaya':
    if restart_chain is False:
        sampler = MCMCSampler(likelihood, save_fn = chain_name,max_tries=10000)
        sampler.run(check={'max_eigen_gr': GR_criteria})
    else:
        sampler = MCMCSampler(likelihood ,save_fn = chain_name, 
                              chains=f'{chain_name}.npy')
        sampler.run(check={'max_eigen_gr': GR_criteria})
    
else:
    if restart_chain is False:
        sampler = EmceeSampler(likelihood ,save_fn = chain_name)
        sampler.run(check={'max_eigen_gr': GR_criteria})
    else:
        sampler = EmceeSampler(likelihood ,save_fn = chain_name, 
                               chains=f'{chain_name}.npy')
        sampler.run(check={'max_eigen_gr': GR_criteria})



# In[ ]:





# In[ ]:
# Out:
# [000019.43] [0/1] 08-15 14:52  MCMCSampler               INFO     Varied parameters: ['h', 'omega_cdm', 'omega_b', 'logA', 'LRG1.b1', 'LRG1.b2', 'LRG1.bs'].
# [None]
# 0.09045052528381348
# 0.09064769744873047
# 0.09070777893066406
# 0.0891425609588623
# 0.09012627601623535
# 0.08730649948120117
# 0.08839583396911621
# 0.08766674995422363
# 0.08786773681640625
# 0.08713173866271973
# 0.08744359016418457
# [000037.53] [0/1] 08-15 14:53  BasePipeline              INFO     Found speeds:
# [000037.53] [0/1] 08-15 14:53  BasePipeline              INFO     - <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7fe2b045b7f0>: 55.57 iterations / second - 0.018 s / iteration
# [000037.53] [0/1] 08-15 14:53  BasePipeline              INFO     - <desilike.theories.primordial_cosmology.Cosmoprimo object at 0x7fe2d02575e0>: 261.70 iterations / second - 0.004 s / iteration
# [000037.53] [0/1] 08-15 14:53  BasePipeline              INFO     - <desilike.theories.galaxy_clustering.base.APEffect object at 0x7fe2b0109d50>: 34.68 iterations / second - 0.029 s / iteration
# [000037.53] [0/1] 08-15 14:53  BasePipeline              INFO     - <desilike.theories.galaxy_clustering.power_template.DirectPowerSpectrumTemplate object at 0x7fe2b053c0a0>: 0.67 iterations / second - 1.503 s / iteration
# [000037.53] [0/1] 08-15 14:53  BasePipeline              INFO     - <desilike.theories.galaxy_clustering.full_shape.FOLPSv2TracerBispectrumMultipoles object at 0x7fe2d024b310>: 11.12 iterations / second - 0.090 s / iteration
# [000037.53] [0/1] 08-15 14:53  BasePipeline              INFO     - <desilike.observables.galaxy_clustering.window.WindowedPowerSpectrumMultipoles object at 0x7fe2b0118130>: 4755.45 iterations / second - 0.000 s / iteration
# [000037.53] [0/1] 08-15 14:53  BasePipeline              INFO     - <desilike.observables.galaxy_clustering.power_spectrum.TracerPowerSpectrumMultipolesObservable object at 0x7fe2b0451510>: 119495.84 iterations / second - 0.000 s / iteration
# [000037.53] [0/1] 08-15 14:53  BasePipeline              INFO     - <desilike.likelihoods.base.ObservablesGaussianLikelihood object at 0x7fe2b010acb0>: 2274.82 iterations / second - 0.000 s / iteration
# [000037.53] [0/1] 08-15 14:53  BasePipeline              INFO     - <desilike.likelihoods.base.SumLikelihood object at 0x7fe2b010b400>: 3845.52 iterations / second - 0.000 s / iteration
# [000037.53] [0/1] 08-15 14:53  BasePipeline              INFO     - total speed: 0.61 iterations / second - 1.6443 s / iteration
# [000037.53] [0/1] 08-15 14:53  MCMCSampler               INFO     Oversampling with factors:
# [000037.53] [0/1] 08-15 14:53  MCMCSampler               INFO     1: ['h', 'omega_cdm', 'omega_b', 'logA']
# [000037.53] [0/1] 08-15 14:53  MCMCSampler               INFO     3: ['LRG1.b1', 'LRG1.b2', 'LRG1.bs']
# [000037.54] [0/1] 08-15 14:53  MCMCSampler               INFO     Using provided covariance matrix.
# [000038.16] [0/1] 08-15 14:53  MCMCSampler               INFO     Could *not* vmap input likelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.
# [000038.19] [0/1] 08-15 14:53  MCMCSampler               INFO     Could *not* jit input likelihood.
# 0.088714599609375
# 0.08762645721435547
# 0.08801794052124023
# 0.08870601654052734
# 0.08857083320617676
# 0.08942079544067383
# 0.08771753311157227
# 0.08842039108276367
# 0.08819699287414551
# 0.08767557144165039
# 0.08789539337158203
# 0.08836507797241211
# 0.0891265869140625
# 0.0878448486328125
# 0.08836507797241211
# 0.08805346488952637
# 0.08756279945373535
# 0.08720993995666504
# 0.09375500679016113
# 0.09554600715637207
# 0.09533405303955078
# 0.09073162078857422
# 0.09156966209411621
# 0.08844685554504395
# 0.08864212036132812
# 0.08852195739746094
# [000057.79] [0/1] 08-15 14:53  Exception                 CRITICAL
# ====================================================================================================
# Traceback (most recent call last):
#   File "/global/u1/p/prakharb/desilike/desilike/samplers/base.py", line 466, in _run_batch
#     chain = self._run_one(start[ichain], niterations=niterations, **kwargs)
#   File "/global/u1/p/prakharb/desilike/desilike/samplers/mcmc.py", line 538, in _run_one
#     for _ in self.sampler.sample(start=np.ravel(start), iterations=niterations, thin_by=thin_by):
#   File "/global/u1/p/prakharb/desilike/desilike/samplers/mcmc.py", line 89, in sample
#     mh_proposal_log_prob = proposal_log_prob = self.log_prob_fn(proposal_coords)
#   File "/global/u1/p/prakharb/desilike/desilike/samplers/base.py", line 61, in wrapper
#     toret[mask] = func(self, values)
#   File "/global/u1/p/prakharb/desilike/desilike/samplers/base.py", line 153, in logposterior
#     results = self._vlikelihood(points.to_dict())
#   File "/global/u1/p/prakharb/desilike/desilike/samplers/base.py", line 266, in _vlikelihood
#     return vlikelihood(*args, **kwargs, mpicomm=self.mpicomm)
#   File "/global/u1/p/prakharb/desilike/desilike/base.py", line 324, in wrapper
#     states = calculate(chunk_params, **kw)
#   File "/global/u1/p/prakharb/desilike/desilike/base.py", line 268, in wrapper
#     states = _calculate_map(params, **kw)
#   File "/global/u1/p/prakharb/desilike/desilike/base.py", line 247, in _calculate_map
#     state[0] = calculate({name: value[ivalue] for name, value in params.items()}, **kw)
#   File "/global/u1/p/prakharb/desilike/desilike/base.py", line 1194, in __call__
#     return self.runtime_info.pipeline.calculate(*args, **kwargs)
#   File "/global/u1/p/prakharb/desilike/desilike/base.py", line 550, in calculate
#     derived = runtime_info.derived
#   File "/global/u1/p/prakharb/desilike/desilike/base.py", line 941, in derived
#     else: value = getattr(self.calculator, name)
#   File "/global/u1/p/prakharb/desilike/desilike/theories/primordial_cosmology.py", line 128, in __getattr__
#     return get_from_cosmo(self.cosmo, name)
#   File "/global/u1/p/prakharb/desilike/desilike/theories/primordial_cosmology.py", line 49, in get_from_cosmo
#     toret = getattr(cosmo, name)
#   File "/global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/code/cosmoprimo/main/lib/python3.10/site-packages/cosmoprimo/cosmology.py", line 1436, in __getattr__
#     section = getattr(self._engine, 'get_{}'.format(section_name))()
#   File "/global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/code/cosmoprimo/main/lib/python3.10/site-packages/cosmoprimo/cosmology.py", line 567, in getter
#     self._sections[name] = self._Sections[name](self)
#   File "/global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/code/cosmoprimo/main/lib/python3.10/site-packages/cosmoprimo/classy.py", line 265, in __init__
#     super(BaseClassFourier, self).__init__(engine.classy)
#   File "pyclass/base/binding.pyx", line 1882, in pyclass.base.binding.Fourier.__init__
#   File "/global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/code/cosmoprimo/main/lib/python3.10/site-packages/cosmoprimo/classy.py", line 78, in compute
#     return super(_ClassEngine, self).compute(tasks)
# KeyboardInterrupt
# ====================================================================================================
# [000057.79] [0/1] 08-15 14:53  Exception                 CRITICAL Interrupted by the user.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 20
#      18 if restart_chain is False:
#      19     sampler = MCMCSampler(likelihood, save_fn = chain_name,max_tries=10000)
# ---> 20     sampler.run(check={'max_eigen_gr': GR_criteria})
#      21 else:
#      22     sampler = MCMCSampler(likelihood ,save_fn = chain_name,
#      23                           chains=f'{chain_name}.npy')
#
# File /global/u1/p/prakharb/desilike/desilike/samplers/mcmc.py:527, in MCMCSampler.run(self, *args, **kwargs)
#     499 def run(self, *args, **kwargs):
#     500     """
#     501     Run chains. Sampling can be interrupted anytime, and resumed by providing the path to the saved chains in ``chains`` argument of :meth:`__init__`.
#     502
#    (...)
#     525         Thin samples by this factor.
#     526     """
# --> 527     return super(MCMCSampler, self).run(*args, **kwargs)
#
# File /global/u1/p/prakharb/desilike/desilike/samplers/base.py:504, in BaseBatchPosteriorSampler.run(self, min_iterations, max_iterations, check_every, check, **kwargs)
#     501         is_converged = self.check(**check)
#     502     return is_converged
# --> 504 batch_iterate(_run_batch, min_iterations=min_iterations, max_iterations=max_iterations, check_every=check_every)
#     505 return self.chains
#
# File /global/u1/p/prakharb/desilike/desilike/samplers/base.py:38, in batch_iterate(func, min_iterations, max_iterations, check_every, **kwargs)
#      36 niter = min(max_iterations - count_iterations, check_every)
#      37 count_iterations += niter
# ---> 38 is_converged = func(niterations=niter, **kwargs)
#      39 if count_iterations < min_iterations:
#      40     is_converged = False
#
# File /global/u1/p/prakharb/desilike/desilike/samplers/base.py:466, in BaseBatchPosteriorSampler.run.<locals>._run_batch(niterations)
#     464 self._set_rng(rng=self.rng)
#     465 self._ichain = ichain
# --> 466 chain = self._run_one(start[ichain], niterations=niterations, **kwargs)
#     467 if self.mpicomm.rank == 0:
#     468     ncalls[ichain] = self.derived[1][self.likelihood._param_loglikelihood].size if self.derived is not None else 0
#
# File /global/u1/p/prakharb/desilike/desilike/samplers/mcmc.py:538, in MCMCSampler._run_one(self, start, niterations, thin_by)
#     536 log_every = 30  # 30 seconds
#     537 t0 = time.time()
# --> 538 for _ in self.sampler.sample(start=np.ravel(start), iterations=niterations, thin_by=thin_by):
#     539     if self.mpicomm.rank == 0 and time.time() - t0 >= log_every:
#     540         total = int(self.sampler.get_weight().sum())
#
# File /global/u1/p/prakharb/desilike/desilike/samplers/mcmc.py:89, in MHSampler.sample(self, start, iterations, thin_by)
#      87     mh_current_log_prob = np.full(self.vectorize, self.state.log_prob, dtype='f8')
#      88     #mh_proposal_log_prob = proposal_log_prob = np.full(self.vectorize, -np.inf, dtype='f8')
# ---> 89     mh_proposal_log_prob = proposal_log_prob = self.log_prob_fn(proposal_coords)
#      90 for i in range(self.vectorize):
#      91     accept = self._mh_accept(mh_proposal_log_prob[i], mh_current_log_prob[i])
#
# File /global/u1/p/prakharb/desilike/desilike/samplers/base.py:61, in bcast_values.<locals>.wrapper(self, values)
#      59 values = values[mask]
#      60 if values.size:
# ---> 61     toret[mask] = func(self, values)
#      62 if isscalar and toret.size:
#      63     toret = toret[0]
#
# File /global/u1/p/prakharb/desilike/desilike/samplers/base.py:153, in BasePosteriorSampler.logposterior(self, values)
#     151     return logprior
#     152 points = Samples(values[mask_finite_prior].T, params=self.varied_params)
# --> 153 results = self._vlikelihood(points.to_dict())
#     154 #print(self.mpicomm.size, self.mpicomm.rank)
#     156 logposterior, raise_error = None, None
#
# File /global/u1/p/prakharb/desilike/desilike/samplers/base.py:266, in BasePosteriorSampler._set_vlikelihood.<locals>._vlikelihood(*args, **kwargs)
#     265 def _vlikelihood(*args, **kwargs):
# --> 266     return vlikelihood(*args, **kwargs, mpicomm=self.mpicomm)
#
# File /global/u1/p/prakharb/desilike/desilike/base.py:324, in vmap.<locals>.wrapper(params, mpicomm, **kw)
#     322     states = _calculate_map(chunk_params, **kw)
#     323 else:  # calculate already vmap
# --> 324     states = calculate(chunk_params, **kw)
#     325     local_chunk_size = len(chunk_params[name])
#     326     if local_chunk_size:
#
# File /global/u1/p/prakharb/desilike/desilike/base.py:268, in vmap.<locals>.wrapper(params, **kw)
#     266 kw = {**kwargs, **kw}
#     267 params, shape = _check_params(params)
# --> 268 states = _calculate_map(params, **kw)
#     269 results, errs = _check_states(states, errors=errors)
#     270 results = _concatenate_results(results, shape, add_dims=True)
#
# File /global/u1/p/prakharb/desilike/desilike/base.py:247, in vmap.<locals>._calculate_map(params, **kw)
#     245 state = [None, None]
#     246 try:
# --> 247     state[0] = calculate({name: value[ivalue] for name, value in params.items()}, **kw)
#     248 except Exception as exc:
#     249     if errors == 'raise':
#
# File /global/u1/p/prakharb/desilike/desilike/base.py:1194, in BaseCalculator.__call__(self, *args, **kwargs)
#    1192 def __call__(self, *args, **kwargs):
#    1193     """Take all parameters as input, calculate, and return the result of :attr:`get`"""
# -> 1194     return self.runtime_info.pipeline.calculate(*args, **kwargs)
#
# File /global/u1/p/prakharb/desilike/desilike/base.py:550, in BasePipeline.calculate(self, force, return_derived, *args, **kwargs)
#     548     result = runtime_info.calculate(params, force=force)
#     549     if self.derived is not None:
# --> 550         derived = runtime_info.derived
#     551 except Exception:  # we want to keep track of the Exception class, so do not raise PipelineError
#     552     self.log_debug('error in method calculate of {} with calculator parameters {} and pipeline parameters {}'.format(calculator, runtime_info.input_values, self.input_values))
#
# File /global/u1/p/prakharb/desilike/desilike/base.py:941, in RuntimeInfo.derived(self)
#     939 name = param.basename
#     940 if name in state: value = state[name]
# --> 941 else: value = getattr(self.calculator, name)
#     942 array = ParameterArray(value, param=param)
#     943 array.param._shape = array.shape  # a bit hacky, but no need to update parameters for this...
#
# File /global/u1/p/prakharb/desilike/desilike/theories/primordial_cosmology.py:128, in Cosmoprimo.__getattr__(self, name)
#     126 def __getattr__(self, name):
#     127     if 'cosmo' in self.__dict__:
# --> 128         return get_from_cosmo(self.cosmo, name)
#     129     raise AttributeError('{} has not attribute {}; try calling it first?'.format(self, name))
#
# File /global/u1/p/prakharb/desilike/desilike/theories/primordial_cosmology.py:49, in get_from_cosmo(cosmo, name)
#      47     return cosmo.k_pivot * cosmo.h
#      48 try:
# ---> 49     toret = getattr(cosmo, name)
#      50 except AttributeError:
#      51     try:
#
# File /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/code/cosmoprimo/main/lib/python3.10/site-packages/cosmoprimo/cosmology.py:1436, in Cosmology.__getattr__(self, name)
#    1434 for section_name, Section in Sections.items():
#    1435     if hasattr(Section, name) and not any(hasattr(OtherSection, name) for OtherSection in Sections.values() if OtherSection is not Section):  # keep only single elements
# -> 1436         section = getattr(self._engine, 'get_{}'.format(section_name))()
#    1437         return getattr(section, name)
#    1438 raise AttributeError("Attribute {} not found in any of {} engine's products (rejecting duplicates)".format(name, self.engine.__class__.__name__))
#
# File /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/code/cosmoprimo/main/lib/python3.10/site-packages/cosmoprimo/cosmology.py:567, in _make_section_getter.<locals>.getter(self)
#     565 name = section.lower()
#     566 if name not in self._sections:
# --> 567     self._sections[name] = self._Sections[name](self)
#     568 return self._sections[name]
#
# File /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/code/cosmoprimo/main/lib/python3.10/site-packages/cosmoprimo/classy.py:265, in BaseClassFourier.__init__(self, engine)
#     264 def __init__(self, engine):
# --> 265     super(BaseClassFourier, self).__init__(engine.classy)
#     266     self._rsigma8 = engine._rescale_sigma8()
#
# File pyclass/base/binding.pyx:1882, in pyclass.base.binding.Fourier.__init__()
#
# File /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/code/cosmoprimo/main/lib/python3.10/site-packages/cosmoprimo/classy.py:78, in ClassEngine._set_classy.<locals>._ClassEngine.compute(self, tasks)
#      76 def compute(self, tasks):
#      77     try:
# ---> 78         return super(_ClassEngine, self).compute(tasks)
#      79     except base.ClassInputError as exc:
#      80         raise CosmologyInputError from exc
#
# KeyboardInterrupt:

# %%
Likelihoods[0]()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /global/u1/p/prakharb/desilike/desilike/base.py:1212, in BaseCalculator.__getattr__(self, name)
#    1211 try:
# -> 1212     return object.__getattribute__(self, name)
#    1213 except AttributeError as exc:
#
# AttributeError: 'FOLPSv2PowerSpectrumMultipoles' object has no attribute 'z'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# File /global/u1/p/prakharb/desilike/desilike/base.py:1010, in RuntimeInfo.initialize(self)
#    1009 try:
# -> 1010     self.calculator.initialize(*self.init.args, **self.init)
#    1011 except Exception as exc:
#
# File /global/u1/p/prakharb/desilike/desilike/theories/galaxy_clustering/full_shape.py:89, in BaseTracerPowerSpectrumMultipoles.initialize(self, pt, template, **kwargs)
#      87 for name in ['z', 'k', 'ells']:
#      88     # print( dir(self.pt),getattr(self.pt, 'z', None))
# ---> 89     setattr(self, name, getattr(self.pt, name))
#      90 self.set_params()
#
# File /global/u1/p/prakharb/desilike/desilike/base.py:1214, in BaseCalculator.__getattr__(self, name)
#    1213 except AttributeError as exc:
# -> 1214     raise AttributeError('calculator {} has no attribute {}; '
#    1215                          'have you run any calculation already by calling this calculator or calculators '
#    1216                          'that depend on it (typically, a likelihood?)'.format(self.__class__.__name__, name)) from exc
#
# AttributeError: calculator FOLPSv2PowerSpectrumMultipoles has no attribute z; have you run any calculation already by calling this calculator or calculators that depend on it (typically, a likelihood?)
#
# The above exception was the direct cause of the following exception:
#
# PipelineError                             Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 Likelihoods[0]()
#
# File /global/u1/p/prakharb/desilike/desilike/base.py:1194, in BaseCalculator.__call__(self, *args, **kwargs)
#    1192 def __call__(self, *args, **kwargs):
#    1193     """Take all parameters as input, calculate, and return the result of :attr:`get`"""
# -> 1194     return self.runtime_info.pipeline.calculate(*args, **kwargs)
#
# File /global/u1/p/prakharb/desilike/desilike/base.py:951, in RuntimeInfo.pipeline(self)
#     949 """Return pipeline for this calculator."""
#     950 if getattr(self, '_pipeline', None) is None or not self.initialized:
# --> 951     self._pipeline = BasePipeline(self.calculator)
#     952 else:
#     953     for calculator in self._pipeline.calculators[:-1]:
#
# File /global/u1/p/prakharb/desilike/desilike/base.py:417, in BasePipeline.__init__(self, calculator)
#     415 if not getattr(calculator.runtime_info, '_calculation', False):
#     416     calculator.runtime_info.initialized = False  # may depend on the whole pipeline
# --> 417 callback(calculator.runtime_info.initialize())
#     419 # To avoid loops created by one calculator, which when updated, requests reinitialization of the calculators which depend on it
#     420 for calculator in self.calculators:
#
# File /global/u1/p/prakharb/desilike/desilike/base.py:413, in BasePipeline.__init__.<locals>.callback(calculator)
#     411 require.runtime_info.initialize()  # can create new calculators, so remove the previous ones above
#     412 require.runtime_info._initialized_for_pipeline.append(id(self))
# --> 413 callback(require)
#
# File /global/u1/p/prakharb/desilike/desilike/base.py:413, in BasePipeline.__init__.<locals>.callback(calculator)
#     411 require.runtime_info.initialize()  # can create new calculators, so remove the previous ones above
#     412 require.runtime_info._initialized_for_pipeline.append(id(self))
# --> 413 callback(require)
#
# File /global/u1/p/prakharb/desilike/desilike/base.py:411, in BasePipeline.__init__.<locals>.callback(calculator)
#     409 for require in calculator.runtime_info.requires:
#     410     callback2(require)
# --> 411     require.runtime_info.initialize()  # can create new calculators, so remove the previous ones above
#     412     require.runtime_info._initialized_for_pipeline.append(id(self))
#     413     callback(require)
#
# File /global/u1/p/prakharb/desilike/desilike/base.py:1012, in RuntimeInfo.initialize(self)
#    1010     self.calculator.initialize(*self.init.args, **self.init)
#    1011 except Exception as exc:
# -> 1012     raise PipelineError('Error in method initialize of {}'.format(self.calculator)) from exc
#    1013 if not self._initialize_with_namespace:
#    1014     for param in self.init.params:
#
# PipelineError: Error in method initialize of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2TracerPowerSpectrumMultipoles object at 0x7f630847be20>

# %% [markdown]
# # Bispectrum Emulator Test

# %%
from desilike.theories.galaxy_clustering import FixedPowerSpectrumTemplate, LPTVelocileptorsTracerPowerSpectrumMultipoles, KaiserTracerPowerSpectrumMultipoles, DirectPowerSpectrumTemplate,FixedPowerSpectrumTemplate
from desilike.theories.galaxy_clustering.full_shape import  FOLPSv2TracerPowerSpectrumMultipoles,FOLPSAXTracerPowerSpectrumMultipoles, PyBirdTracerPowerSpectrumMultipoles, FOLPSv2TracerBispectrumMultipoles, GeoFPTAXTracerBispectrumMultipoles
from desilike.observables import ObservableCovariance
from desilike.observables.galaxy_clustering import TracerPowerSpectrumMultipolesObservable, TracerBispectrumMultipolesObservable
from desilike.likelihoods import ObservablesGaussianLikelihood
from desilike.profilers import MinuitProfiler
from desilike import setup_logging

setup_logging()

template = DirectPowerSpectrumTemplate(z=1.1)
theory =  FOLPSv2TracerPowerSpectrumMultipoles(template=template, tracer='ELG',freedom='max',kernels='fk',prior_basis='standard',damping='lor')
# theory = FOLPSv2TracerPowerSpectrumMultipoles(template=template)
# theory = GeoFPTAXTracerBispectrumMultipoles(template=template)
# from desilike.emulators import Emulator, EmulatedCalculator, TaylorEmulatorEngine
# emulator = Emulator(theory, engine=TaylorEmulatorEngine(order={'*': 2, 'sn0': 1}))  # order 2 except for sn0 (order 1 is enough)
# emulator.set_samples()
# emulator.fit()
# emulator.plot(name='power')

# emulated_pt = emulator.to_calculator()
# emulated_pt.save(emulator_filename)
# theory.init.update(pt=emulated_pt)
# theory()

# %%
cosmo = Cosmoprimo(engine='class')
cosmo.init.params['H0'] = dict(derived=True)
cosmo.init.params['Omega_m'] = dict(derived=True)
cosmo.init.params['sigma8_m'] = dict(derived=True) 
z = 0.8
def load_data_vector_and_covariance_files():
    # kr_pk = np.load("./desilike_mcmc/kr_pk.npy")
    # data = np.load("./desilike_mcmc/data.npy")
    # cov_arr = np.load("./desilike_mcmc/cov.npy")
    kr_pk = np.load("./desilike_mcmc/kr_b0.npy")
    data = np.load("./desilike_mcmc/data_b0.npy")
    cov_arr = np.load("./desilike_mcmc/cov_b0.npy")
    return data, cov_arr, kr_pk


#Define a function to create an observable
def create_observable( #wmatrix_fn, covariance_fn,
                      theory, tracer_index):
   
    # data, cov_arr, kr_b0 = load_data_vector_and_covariance()
    data, cov_arr, kr_b0 = load_data_vector_and_covariance_files()
    print(data.shape,cov_arr.shape,kr_b0.shape)
    
    #Create and return the observable: following  https://desi.lbl.gov/trac/wiki/keyprojects/y1kp3/clusteringproducts#a101:Iwanttowritemychi2
    return TracerBispectrumMultipolesObservable(
        data=data,
        covariance=cov_arr,
        theory=theory,
        k={ell: kr_b0 for ell in [(0,0,0), (2,0,2)]},
        ells=[(0,0,0),(2,0,2)]
    )

    return TracerBispectrumMultipolesObservable (data=data,covariance=cov_arr,theory=theory,k=(kr_b0))
#cosmo.init.params['fR0'] = dict(derived=False, latex ='f_{R0}')
fiducial = DESI() #fiducial cosmology
template = DirectPowerSpectrumTemplate(fiducial = fiducial,cosmo = cosmo, z=z) #cosmology and fiducial cosmology defined above
theory = FOLPSv2TracerBispectrumMultipoles(template=template, prior_basis="standard") #Add the prior_basis='physical' argument to use physically motivated priors
# theory = FOLPSv2TracerPowerSpectrumMultipoles(template=template, prior_basis="standard") #Add the prior_basis='physical' argument to use physically motivated priors

observables = create_observable(theory,1) 
setup_logging()
Likelihoods = []
Likelihoods.append(ObservablesGaussianLikelihood(observables = observables))


#Sum the likelihoods and initialize
likelihood = SumLikelihood(likelihoods = (Likelihoods))

likelihood()
# Out:
# (48,) (48, 48) (24,)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /global/u1/p/prakharb/desilike/desilike/base.py:1010, in RuntimeInfo.initialize(self)
#    1009 try:
# -> 1010     self.calculator.initialize(*self.init.args, **self.init)
#    1011 except Exception as exc:
#
# File /global/u1/p/prakharb/desilike/desilike/theories/galaxy_clustering/full_shape.py:2886, in FOLPSv2TracerBispectrumMultipoles.initialize(self, pt, template, **kwargs)
#    2885     self.options[name] = kwargs.pop(name, value)
# -> 2886 self.nd = 1. / float(shotnoise)
#    2887 if pt is None:
#
# TypeError: float() argument must be a string or a real number, not 'NoneType'
#
# The above exception was the direct cause of the following exception:
#
# PipelineError                             Traceback (most recent call last)
# File /global/u1/p/prakharb/desilike/desilike/base.py:1010, in RuntimeInfo.initialize(self)
#    1009 try:
# -> 1010     self.calculator.initialize(*self.init.args, **self.init)
#    1011 except Exception as exc:
#
# File /global/u1/p/prakharb/desilike/desilike/observables/galaxy_clustering/bispectrum.py:48, in TracerBispectrumMultipolesObservable.initialize(self, data, covariance, k, ells, shotnoise, theory)
#      47 self.wmatrix.init.update(k=k, ells=ells, shotnoise=shotnoise)
# ---> 48 self.wmatrix.runtime_info.initialize()
#      49 for name in ['k', 'ells', 'shotnoise']:
#
# File /global/u1/p/prakharb/desilike/desilike/base.py:1012, in RuntimeInfo.initialize(self)
#    1011 except Exception as exc:
# -> 1012     raise PipelineError('Error in method initialize of {}'.format(self.calculator)) from exc
#    1013 if not self._initialize_with_namespace:
#
# PipelineError: Error in method initialize of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2TracerBispectrumMultipoles object at 0x7f432c526aa0>
#
# The above exception was the direct cause of the following exception:
#
# PipelineError                             Traceback (most recent call last)
# File /global/u1/p/prakharb/desilike/desilike/base.py:1010, in RuntimeInfo.initialize(self)
#    1009 try:
# -> 1010     self.calculator.initialize(*self.init.args, **self.init)
#    1011 except Exception as exc:
#
# File /global/u1/p/prakharb/desilike/desilike/likelihoods/base.py:540, in ObservablesGaussianLikelihood.initialize(self, observables, covariance, scale_covariance, correct_covariance, precision, **kwargs)
#     539 if covariance is None:
# --> 540     nmocks = [self.mpicomm.bcast(len(obs.mocks) if getattr(obs, 'mocks', None) is not None else 0) for obs in self.observables]
#     541     if any(nmocks):
#
# File /global/u1/p/prakharb/desilike/desilike/likelihoods/base.py:540, in <listcomp>(.0)
#     539 if covariance is None:
# --> 540     nmocks = [self.mpicomm.bcast(len(obs.mocks) if getattr(obs, 'mocks', None) is not None else 0) for obs in self.observables]
#     541     if any(nmocks):
#
# File /global/u1/p/prakharb/desilike/desilike/base.py:1210, in BaseCalculator.__getattr__(self, name)
#    1209 if not getattr(self.runtime_info, '_initialization', False):
# -> 1210     self.runtime_info.initialize()
#    1211 try:
#
# File /global/u1/p/prakharb/desilike/desilike/base.py:1012, in RuntimeInfo.initialize(self)
#    1011 except Exception as exc:
# -> 1012     raise PipelineError('Error in method initialize of {}'.format(self.calculator)) from exc
#    1013 if not self._initialize_with_namespace:
#
# PipelineError: Error in method initialize of <desilike.observables.galaxy_clustering.bispectrum.TracerBispectrumMultipolesObservable object at 0x7f432c57d810>
#
# The above exception was the direct cause of the following exception:
#
# PipelineError                             Traceback (most recent call last)
# Cell In[18], line 49
#      46 #Sum the likelihoods and initialize
#      47 likelihood = SumLikelihood(likelihoods = (Likelihoods))
# ---> 49 likelihood()
#
# File /global/u1/p/prakharb/desilike/desilike/base.py:1194, in BaseCalculator.__call__(self, *args, **kwargs)
#    1192 def __call__(self, *args, **kwargs):
#    1193     """Take all parameters as input, calculate, and return the result of :attr:`get`"""
# -> 1194     return self.runtime_info.pipeline.calculate(*args, **kwargs)
#
# File /global/u1/p/prakharb/desilike/desilike/base.py:951, in RuntimeInfo.pipeline(self)
#     949 """Return pipeline for this calculator."""
#     950 if getattr(self, '_pipeline', None) is None or not self.initialized:
# --> 951     self._pipeline = BasePipeline(self.calculator)
#     952 else:
#     953     for calculator in self._pipeline.calculators[:-1]:
#
# File /global/u1/p/prakharb/desilike/desilike/base.py:417, in BasePipeline.__init__(self, calculator)
#     415 if not getattr(calculator.runtime_info, '_calculation', False):
#     416     calculator.runtime_info.initialized = False  # may depend on the whole pipeline
# --> 417 callback(calculator.runtime_info.initialize())
#     419 # To avoid loops created by one calculator, which when updated, requests reinitialization of the calculators which depend on it
#     420 for calculator in self.calculators:
#
# File /global/u1/p/prakharb/desilike/desilike/base.py:410, in BasePipeline.__init__.<locals>.callback(calculator)
#     407         callback2(require)
#     409 for require in calculator.runtime_info.requires:
# --> 410     callback2(require)
#     411     require.runtime_info.initialize()  # can create new calculators, so remove the previous ones above
#     412     require.runtime_info._initialized_for_pipeline.append(id(self))
#
# File /global/u1/p/prakharb/desilike/desilike/base.py:406, in BasePipeline.__init__.<locals>.callback.<locals>.callback2(calculator)
#     404 if calculator in self.calculators:
#     405     del self.calculators[self.calculators.index(calculator)]
# --> 406 for require in calculator.runtime_info.requires:
#     407     callback2(require)
#
# File /global/u1/p/prakharb/desilike/desilike/base.py:969, in RuntimeInfo.requires(self)
#     967     if getattr(self, '_initialization', False): return []
#     968     self.initialized = False
# --> 969     self.initialize()
#     970 return self._requires
#
# File /global/u1/p/prakharb/desilike/desilike/base.py:1012, in RuntimeInfo.initialize(self)
#    1010     self.calculator.initialize(*self.init.args, **self.init)
#    1011 except Exception as exc:
# -> 1012     raise PipelineError('Error in method initialize of {}'.format(self.calculator)) from exc
#    1013 if not self._initialize_with_namespace:
#    1014     for param in self.init.params:
#
# PipelineError: Error in method initialize of <desilike.likelihoods.base.ObservablesGaussianLikelihood object at 0x7f432c57e6b0>

# %%
observables()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /global/u1/p/prakharb/desilike/desilike/base.py:1010, in RuntimeInfo.initialize(self)
#    1009 try:
# -> 1010     self.calculator.initialize(*self.init.args, **self.init)
#    1011 except Exception as exc:
#
# File /global/u1/p/prakharb/desilike/desilike/theories/galaxy_clustering/full_shape.py:2886, in FOLPSv2TracerBispectrumMultipoles.initialize(self, pt, template, **kwargs)
#    2885     self.options[name] = kwargs.pop(name, value)
# -> 2886 self.nd = 1. / float(shotnoise)
#    2887 if pt is None:
#
# TypeError: float() argument must be a string or a real number, not 'NoneType'
#
# The above exception was the direct cause of the following exception:
#
# PipelineError                             Traceback (most recent call last)
# File /global/u1/p/prakharb/desilike/desilike/base.py:1010, in RuntimeInfo.initialize(self)
#    1009 try:
# -> 1010     self.calculator.initialize(*self.init.args, **self.init)
#    1011 except Exception as exc:
#
# File /global/u1/p/prakharb/desilike/desilike/observables/galaxy_clustering/bispectrum.py:48, in TracerBispectrumMultipolesObservable.initialize(self, data, covariance, k, ells, shotnoise, theory)
#      47 self.wmatrix.init.update(k=k, ells=ells, shotnoise=shotnoise)
# ---> 48 self.wmatrix.runtime_info.initialize()
#      49 for name in ['k', 'ells', 'shotnoise']:
#
# File /global/u1/p/prakharb/desilike/desilike/base.py:1012, in RuntimeInfo.initialize(self)
#    1011 except Exception as exc:
# -> 1012     raise PipelineError('Error in method initialize of {}'.format(self.calculator)) from exc
#    1013 if not self._initialize_with_namespace:
#
# PipelineError: Error in method initialize of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2TracerBispectrumMultipoles object at 0x7f432c526aa0>
#
# The above exception was the direct cause of the following exception:
#
# PipelineError                             Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 observables()
#
# File /global/u1/p/prakharb/desilike/desilike/base.py:1194, in BaseCalculator.__call__(self, *args, **kwargs)
#    1192 def __call__(self, *args, **kwargs):
#    1193     """Take all parameters as input, calculate, and return the result of :attr:`get`"""
# -> 1194     return self.runtime_info.pipeline.calculate(*args, **kwargs)
#
# File /global/u1/p/prakharb/desilike/desilike/base.py:951, in RuntimeInfo.pipeline(self)
#     949 """Return pipeline for this calculator."""
#     950 if getattr(self, '_pipeline', None) is None or not self.initialized:
# --> 951     self._pipeline = BasePipeline(self.calculator)
#     952 else:
#     953     for calculator in self._pipeline.calculators[:-1]:
#
# File /global/u1/p/prakharb/desilike/desilike/base.py:417, in BasePipeline.__init__(self, calculator)
#     415 if not getattr(calculator.runtime_info, '_calculation', False):
#     416     calculator.runtime_info.initialized = False  # may depend on the whole pipeline
# --> 417 callback(calculator.runtime_info.initialize())
#     419 # To avoid loops created by one calculator, which when updated, requests reinitialization of the calculators which depend on it
#     420 for calculator in self.calculators:
#
# File /global/u1/p/prakharb/desilike/desilike/base.py:1012, in RuntimeInfo.initialize(self)
#    1010     self.calculator.initialize(*self.init.args, **self.init)
#    1011 except Exception as exc:
# -> 1012     raise PipelineError('Error in method initialize of {}'.format(self.calculator)) from exc
#    1013 if not self._initialize_with_namespace:
#    1014     for param in self.init.params:
#
# PipelineError: Error in method initialize of <desilike.observables.galaxy_clustering.bispectrum.TracerBispectrumMultipolesObservable object at 0x7f432c57d810>

# %%
def load_data_vector_and_covariance():
    k_min=0.02
    k_max=0.301
    k_max_b0 = 0.15
    k_max_b2 = 0.12

    isP0, isP2, isP4 =True, True, False
    isB000, isB202 = True, True

    Vol=1

    tracer='LRG'
    z_str='z0.800'
    z_evaluation=0.8

    path_fits='chains/'

    now = datetime.now()
    tiempo=now.strftime("%m-%d-%Y-%H%M")

    name=f"c_FolpsD__{tracer}_z{z_evaluation:.3f}_Pkmax-{k_max:.3f}_B000kmax-{k_max_b0:.3f}_B202kmax-{k_max_b2:.3f}_bsfree"


    chains_filename = path_fits+name+".h5"
    copy_filename = path_fits+name+".py"
    print(chains_filename)
        

    # +
    k_data_2nd,pkl0_2nd_all,pkl2_2nd_all,a,B000_2nd_all,B202_2nd_all = ExtractDataAbacusSummit(tracer,z_str,
                                                                                            subtract_shot=True)

    Pk_0_2nd = np.mean(pkl0_2nd_all,axis = 0)
    Pk_2_2nd = np.mean(pkl2_2nd_all,axis = 0)
    B000_2nd = np.mean(B000_2nd_all,axis = 0)
    B202_2nd = np.mean(B202_2nd_all,axis = 0)

    # Read covariance

    k_eff_all,pkl0ezmocks,pkl2ezmocks,pkl4ezmocks,B000ezmocks,B202ezmocks = ExtractDataEZmock(tracer,z_str)
    k_cov_all, mean_ezmocks_all, cov_array_all = covariance(k_eff_all,pkl0ezmocks,pkl2ezmocks,pkl4ezmocks,B000ezmocks,B202ezmocks, Nscaling = Vol)



    pole_selection=[isP0, isP2, isP4,isB000, isB202]
    print(pole_selection)

    kmin_pk=0.02; kmax_pk=k_max
    kmin_bk=0.02; 
    ranges=[[kmin_pk,kmax_pk],[kmin_pk,kmax_pk],[kmin_pk,kmax_pk],[kmin_bk,k_max_b0],[kmin_bk,k_max_b2]]

    mask=pole_k_selection(k_cov_all,pole_selection,ranges)
    #print(mask.shape)
    #print(mask)
    k_cov=k_cov_all[mask]

    #k_cov.shape
    k_points_pk = np.where((kmin_pk < k_data_2nd) & (k_data_2nd < kmax_pk)  & isP0)
    k_points_b0 = np.where((kmin_bk < k_data_2nd) & (k_data_2nd < k_max_b0) & isB000)
    k_points_b2 = np.where((kmin_bk < k_data_2nd) & (k_data_2nd < k_max_b2) & isB202)

    data = np.concatenate((Pk_0_2nd[k_points_pk],Pk_2_2nd[k_points_pk],
                        B000_2nd[k_points_b0],B202_2nd[k_points_b2]))
    kr_pk=k_data_2nd[k_points_pk]
    kr_b0=k_data_2nd[k_points_b0]
    kr_b2=k_data_2nd[k_points_b2]

    numberofpk0points=len(Pk_0_2nd[k_points_pk])
    numberofbk0points=len(B000_2nd[k_points_b0])
    numberofbk2points=len(B202_2nd[k_points_b2])

    cov_array=cov_array_all[np.ix_(mask, mask)]
    totsim = 2000 #number of sims
    n_data = len(data)
    Hartlap = (totsim - 1.) / (totsim - n_data - 2.)
    Hartlap
    cov_arr = cov_array * Hartlap
    # cov_inv_arr = np.linalg.inv(cov_arr)
    
    N_ck=25  #kmaxThy = 0.01 * N_ck + 0.0025 + 0.0005
    N_ck = max(int(k_max*100)+2,25)
    print(N_ck)
    
    k_thy_2nd_ext = np.linspace(0.0, 0.01*N_ck, 2 * N_ck * 5,endpoint=False) + 0.0025+0.0005 #+ 0.0025(move to first data bin) + 0.0005(move to center of bin)
    
    ko_2nd_ext=k_data_2nd[0: 2 * N_ck]
    
    m_bin_2nd_ext = np.zeros((len(ko_2nd_ext),len(k_thy_2nd_ext)))
    m_bin_k_2nd_ext = np.zeros((len(ko_2nd_ext),len(k_thy_2nd_ext)))
    
    for i,ki in enumerate(ko_2nd_ext):
        norm_2nd_ext = (1./3.)* ( (k_thy_2nd_ext[5*i + (5-1)])**3 - (k_thy_2nd_ext[5*i])**3 )
        for j in range(5):
            ff=((5-1)/5)
            m_bin_2nd_ext[i,5*i + j] = (k_thy_2nd_ext[5*i + j]**2)*0.001 / norm_2nd_ext * ff
            m_bin_k_2nd_ext[i,5*i + j] = k_thy_2nd_ext[5*i + j]
    
    
    k_thy=k_thy_2nd_ext
    m_bin=m_bin_2nd_ext

    kb_all=np.linspace(0.5*k_thy_2nd_ext[0], 0.28, 60)
    k_ev_bk=np.vstack([kb_all,kb_all]).T
    
    
    # np.save("./desilike_mcmc/kr_b0.npy",kr_b0)
    # np.save("./desilike_mcmc/data_b0.npy",data)
    # np.save("./desilike_mcmc/cov_b0.npy",cov_array)
    return data, cov_array, kr_pk,kr_b0, kr_b2, k_thy, kb_all,m_bin, k_data_2nd

# %%
def load_data_vector_and_covariance_files():
    # kr_pk = np.load("./desilike_mcmc/kr_pk.npy")
    # data = np.load("./desilike_mcmc/data.npy")
    # cov_arr = np.load("./desilike_mcmc/cov.npy")
    kr_b0 = np.load("./desilike_mcmc/kr_b0.npy")
    kr_b2 = np.load("./desilike_mcmc/kr_b2.npy")
    data = np.load("./desilike_mcmc/data_b02.npy")
    cov_arr = np.load("./desilike_mcmc/cov_b02.npy")
    return data, cov_arr, kr_b0,kr_b2

data, cov_arr, kr_b0,kr_b2 = load_data_vector_and_covariance_files()

# %%
from desilike import ParameterCollection
def make_params(prior_basis='standard, width_EFT=12.5, width_SN0=2, width_SN2=5):
    params = ParameterCollection()

    if prior_basis == 'physical':
        # Shared params
        params['b1p'] = {'prior': {'dist':'uniform','limits': [1e-5, 10]}}
        params['b2p'] = {'prior': {'dist':'uniform','limits': [-50, 50]}}
        params['bsp'] = {'prior': {'dist': 'norm', 'loc': 0, 'scale': 20}}

        # PS-only
        params['alpha0p'] = {'prior': {'dist': 'norm', 'loc': 0, 'scale': width_EFT}}
        params['alpha2p'] = {'prior': {'dist': 'norm', 'loc': 0, 'scale': width_EFT}}
        params['alpha4p'] = {'prior': {'dist': 'norm', 'loc': 0, 'scale': width_EFT}}
        params['sn0p'] = {'prior': {'dist': 'norm', 'loc': 0, 'scale': width_SN0}}
        params['sn2p'] = {'prior': {'dist': 'norm', 'loc': 0, 'scale': width_SN2}}

        # BS-only → if physical, no c1,c2,Pshot,Bshot,X_FoG_b

    else:
        # Shared params
        params['b1'] = {'prior': {'dist':'uniform','limits': [1e-5, 10]}}
        params['b2'] = {'prior': {'dist':'uniform','limits': [-50, 50]}}
        params['bs'] = {'prior': {'dist': 'norm', 'loc': 0, 'scale': 20}}

        # PS-only
        params['alpha0'] = {'prior': {'dist': 'norm', 'loc': 0, 'scale': width_EFT}}
        params['alpha2'] = {'prior': {'dist': 'norm', 'loc': 0, 'scale': width_EFT}}
        params['alpha4'] = {'prior': {'dist': 'norm', 'loc': 0, 'scale': width_EFT}}
        params['sn0'] = {'prior': {'dist': 'norm', 'loc': 0, 'scale': width_SN0}}
        params['sn2'] = {'prior': {'dist': 'norm', 'loc': 0, 'scale': width_SN2}}
        params['X_FoG_p'] = {'fixed': True}  # fixed in your snippet

        # BS-only
        params['c1'] = {'prior': {'dist':'uniform','limits': [-2000, 2000]}}
        params['c2'] = {'prior': {'dist':'uniform','limits': [-2000, 2000]}}
        params['Pshot'] = {'prior': {'dist':'uniform','limits': [-50000, 50000]}}
        params['Bshot'] = {'prior': {'dist':'uniform','limits': [-50000, 50000]}}
        params['X_FoG_b'] = {'prior': {'dist':'uniform','limits': [0, 15]}}

    return params

# %%
print(data.shape, cov_array.shape, kr_pk.shape,kr_b0.shape, kr_b2.shape, k_thy.shape, kb_all.shape,m_bin.shape,k_data_2nd.shape)
# Out:
# (160,) (160, 160) (57,) (26,) (20,) (320,) (60,) (64, 320) (80,)

# %%
data, cov_array, kr_pk,kr_b0, kr_b2, k_thy, kb_all,m_bin, k_data_2nd = load_data_vector_and_covariance()
# Out:
# chains/c_FolpsD__LRG_z0.800_Pkmax-0.301_B000kmax-0.150_B202kmax-0.120_bsfree.h5
# [True, True, False, True, True]
# 32

# %%
params = make_params()
# theory = SomeTheoryClass()

for name, p in params.items():
    if name in theory.params:
        theory.params[name].update(p)   # update prior/limits/etc
# theory.params  = params()
# theory.all_params.update(params)
# theory= theory(params=params)
# theory()
for param in theory.all_params:
    print(1)
    print(param,':',theory.all_params[param].prior)
# Out:
# Loading matrices from matrices_nfftlog128_Afull_True_remove-DeltaP_False.npy
# Loading matrices from matrices_nfftlog128_Afull_True_remove-DeltaP_False.npy
# 1
# h : uniform[0.1, 1.0]({})
# 1
# omega_cdm : uniform[0.01, 0.99]({})
# 1
# omega_b : norm({'loc': 0.02237, 'scale': 0.00037})
# 1
# logA : uniform[2.0, 4.0]({})
# 1
# n_s : uniform[0.8, 1.2]({})
# 1
# tau_reio : uniform[0.01, 0.8]({})
# 1
# m_ncdm : uniform[0.0, 5.0]({})
# 1
# N_eff : uniform[0.01, 10.0]({})
# 1
# w0_fld : uniform[-3.0, 1.0]({})
# 1
# wa_fld : uniform[-3.0, 2.0]({})
# 1
# Omega_k : uniform[-0.3, 0.3]({})
# 1
# b1 : uniform[1e-05, 10]({})
# 1
# b2 : uniform[-50, 50]({})
# 1
# bs : norm({'loc': 0.0, 'scale': 20.0})
# 1
# b3 : uniform({})
# 1
# alpha0 : norm({'loc': 0.0, 'scale': 12.5})
# 1
# alpha2 : norm({'loc': 0.0, 'scale': 12.5})
# 1
# alpha4 : norm({'loc': 0.0, 'scale': 12.5})
# 1
# ct : uniform({})
# 1
# sn0 : norm({'loc': 0.0, 'scale': 2.0})
# 1
# sn2 : norm({'loc': 0.0, 'scale': 5.0})
# 1
# X_FoG_p : uniform({})

# %%
data, cov_array, kr_pk,kr_b0, kr_b2, k_thy, kb_all,m_bin = output
print(data.shape,k_thy.shape,kb_all.shape, m_bin.shape)
# Out:
# (160,) (320,) (60,) (64, 320)

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_block_correlations(cov, sizes=[57, 57, 26, 20], labels=['P0', 'P2', 'B000', 'B202']):
    """
    Plot correlation matrix with block outlines.

    Parameters
    ----------
    cov : (N, N) array
        Covariance matrix.
    sizes : list of int
        Sizes of each block (e.g. [57, 57, 26, 20]).
    labels : list of str
        Names of each block (e.g. ['P0', 'P2', 'B000', 'B202']).
    """
    # correlation matrix
    d = np.sqrt(np.diag(cov))
    corr = cov / np.outer(d, d)
    
    fig, ax = plt.subplots(figsize=(8, 8))
    im = ax.imshow(corr, cmap="coolwarm", vmin=-1, vmax=1, origin="lower")
    plt.colorbar(im, ax=ax, label="Correlation")
    
    # Draw block boundaries
    idx = np.cumsum(sizes)
    for i in idx[:-1]:
        ax.axhline(i - 0.5, color="k", lw=1)
        ax.axvline(i - 0.5, color="k", lw=1)
    
    # Tick labels at block centers
    centers = [sum(sizes[:i]) + sizes[i] / 2 for i in range(len(sizes))]
    ax.set_xticks(centers)
    ax.set_yticks(centers)
    ax.set_xticklabels(labels, rotation=45, ha="right")
    ax.set_yticklabels(labels)
    
    ax.set_title("Correlation Matrix (block structure)")
    plt.tight_layout()
    plt.show()
    
    return corr


# Example usage:
# corr = plot_block_correlations(cov_matrix, [57, 57, 26, 20], ["P0", "P2", "B000", "B202"])
