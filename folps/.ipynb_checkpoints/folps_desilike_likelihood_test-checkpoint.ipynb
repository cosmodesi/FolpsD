# %%
import sys
sys.path.insert(0, "/global/u1/p/prakharb/desilike")
import sys
sys.path.insert(0, "/global/u1/p/prakharb/cosmoprimo")
import desilike, inspect
print(inspect.getfile(desilike))
import cosmoprimo, inspect
print(inspect.getfile(cosmoprimo))
# Out:
# /global/u1/p/prakharb/desilike/desilike/__init__.py
# /global/u1/p/prakharb/cosmoprimo/cosmoprimo/__init__.py

# %% [markdown]
# # Emulator Test

# %%
from pathlib import Path

tracer, zrange = 'LRG', (0.4, 0.6)
data_dir = Path('/global/cfs/cdirs/desi/survey/catalogs/Y1/LSS/iron/LSScats/v1.5/unblinded/desipipe/baseline_2pt/pk')

from pypower import PowerSpectrumMultipoles
raw = PowerSpectrumMultipoles.load(data_dir / f'pkpoles_{tracer}_GCcomb_z{zrange[0]:.1f}-{zrange[1]:.1f}.npy')
thetacut = PowerSpectrumMultipoles.load(data_dir / f'pkpoles_{tracer}_GCcomb_z{zrange[0]:.1f}-{zrange[1]:.1f}_thetacut0.05.npy')
corrected = PowerSpectrumMultipoles.load(data_dir / 'corrected' / f'pkpoles_corrected_{tracer}_GCcomb_z{zrange[0]:.1f}-{zrange[1]:.1f}_thetacut0.05.npy')
rotated = PowerSpectrumMultipoles.load(data_dir / 'rotated_corrected' / f'pkpoles_rotated_corrected_{tracer}_GCcomb_z{zrange[0]:.1f}-{zrange[1]:.1f}_thetacut0.05.npy')

klim = (0.02, 0.2, 0.005)
raw = raw.select(klim)
thetacut = thetacut.select(klim)
corrected = corrected.select(klim)
rotated = rotated.select(klim)

from matplotlib import pyplot as plt

ax = plt.gca()
linestyles = {0: '-', 2: '--', 4: ':'}
for ill, ell in enumerate([0, 2]):
    ax.plot([], [], linestyle=linestyles[ell], color='k', label=r'$\ell = {:d}$'.format(ell))
for ill, ell in enumerate([0, 2]):
    linestyle = linestyles[ell]
    ax.plot(raw.k, raw.k * raw(ell=ell, complex=False), color='C0', label='raw' if ill == 0 else None, linestyle=linestyle)
    ax.plot(thetacut.k, thetacut.k * thetacut(ell=ell, complex=False), color='C1', label=r'$\theta$-cut' if ill == 0 else None, linestyle=linestyle)
    ax.plot(corrected.k, corrected.k * corrected(ell=ell, complex=False), color='C2', label=r'corrected' if ill == 0 else None, linestyle=linestyle)
    ax.plot(rotated.k, rotated.k * rotated(ell=ell, complex=False), color='C3', label=r'rotated' if ill == 0 else None, linestyle=linestyle)
ax.legend(loc=1)
ax.set_xlabel(r'$k$ [$h/\mathrm{Mpc}$]')
ax.set_ylabel(r'$k P(k)$ [$(\mathrm{Mpc}/h)^2$]')
plt.show()
# Out:
# [000011.29] [0/1] 08-12 21:40  PowerSpectrumMultipoles   INFO     Loading /global/cfs/cdirs/desi/survey/catalogs/Y1/LSS/iron/LSScats/v1.5/unblinded/desipipe/baseline_2pt/pk/pkpoles_LRG_GCcomb_z0.4-0.6.npy.
# [000011.57] [0/1] 08-12 21:40  PowerSpectrumMultipoles   INFO     Loading /global/cfs/cdirs/desi/survey/catalogs/Y1/LSS/iron/LSScats/v1.5/unblinded/desipipe/baseline_2pt/pk/pkpoles_LRG_GCcomb_z0.4-0.6_thetacut0.05.npy.
# [000011.69] [0/1] 08-12 21:40  PowerSpectrumMultipoles   INFO     Loading /global/cfs/cdirs/desi/survey/catalogs/Y1/LSS/iron/LSScats/v1.5/unblinded/desipipe/baseline_2pt/pk/corrected/pkpoles_corrected_LRG_GCcomb_z0.4-0.6_thetacut0.05.npy.
# [000011.83] [0/1] 08-12 21:40  PowerSpectrumMultipoles   INFO     Loading /global/cfs/cdirs/desi/survey/catalogs/Y1/LSS/iron/LSScats/v1.5/unblinded/desipipe/baseline_2pt/pk/rotated_corrected/pkpoles_rotated_corrected_LRG_GCcomb_z0.4-0.6_thetacut0.05.npy.

# %%
from pathlib import Path

import numpy as np
from desilike.observables import ObservableCovariance

tracer, zrange = 'LRG', (0.8, 1.1)

forfit_dir = Path('/global/cfs/cdirs/desi//survey/catalogs/Y1/LSS/iron/LSScats/v1.5/unblinded/desipipe/forfit_2pt/')
ref_fn = forfit_dir / f'forfit_power+bao-recon_syst-rotation-hod-photo_klim_0-0.02-0.20_2-0.02-0.20_{tracer}_GCcomb_z{zrange[0]:.1f}-{zrange[1]:.1f}.npy'
covariance = ObservableCovariance.load(ref_fn)

# P(k)
observable_power = covariance.observables('power')
ells_power = observable_power.projs  # (0, 2)
data_power = observable_power.view(projs=ells_power)
zeff_power = observable_power.attrs['zeff']
wmatrix_power = observable_power.attrs['wmatrix']
kin_power = observable_power.attrs['kin']

# BAO
observable_bao = covariance.observables('bao-recon')
params_bao = observable_bao.projs # qpar, qper
data_bao = observable_bao.view(projs=params_bao)
zeff_bao = observable_bao.attrs['zeff']

# Inverse covariance matrix, with all systematic corrections
invcov = covariance.inv()
# To select a part only
invcov_power = covariance.select(observables='power', select_observables=True).inv()

# Define chi2 = (d - W t)^T C^(-1) (d - W t)
def chi2(theory_power, theory_bao):
    diff = data_power - wmatrix_power.dot(theory_power)
    diff = np.append(diff, data_bao - theory_bao)
    return diff.dot(invcov).dot(diff)
# Out:
# [000016.47] [0/1] 08-12 21:40  ObservableCovariance      INFO     Loading /global/cfs/cdirs/desi/survey/catalogs/Y1/LSS/iron/LSScats/v1.5/unblinded/desipipe/forfit_2pt/forfit_power+bao-recon_syst-rotation-hod-photo_klim_0-0.02-0.20_2-0.02-0.20_LRG_GCcomb_z0.8-1.1.npy.

# %%
from desilike.theories.galaxy_clustering import FixedPowerSpectrumTemplate, LPTVelocileptorsTracerPowerSpectrumMultipoles, KaiserTracerPowerSpectrumMultipoles, DirectPowerSpectrumTemplate,FixedPowerSpectrumTemplate
from desilike.theories.galaxy_clustering.full_shape import  FOLPSv2TracerPowerSpectrumMultipoles,FOLPSAXTracerPowerSpectrumMultipoles, PyBirdTracerPowerSpectrumMultipoles, FOLPSv2TracerBispectrumMultipoles
from desilike.observables import ObservableCovariance
from desilike.observables.galaxy_clustering import TracerPowerSpectrumMultipolesObservable
from desilike.likelihoods import ObservablesGaussianLikelihood
from desilike.profilers import MinuitProfiler
from desilike import setup_logging

setup_logging()

template = DirectPowerSpectrumTemplate(z=zeff_power)
# theory = LPTVelocileptorsTracerPowerSpectrumMultipoles(template=template, tracer='ELG', prior_basis='physical')
# theory = FOLPSv2TracerPowerSpectrumMultipoles(template=template, tracer='ELG',freedom='max',kernels='fk',prior_basis='standard',damping='lor')
theory = FOLPSv2TracerBispectrumMultipoles(template=template, tracer='ELG',freedom='max',kernels='fk',prior_basis='standard',damping='lor')
# theory = KaiserTracerPowerSpectrumMultipoles(template=template)
# covariance = ObservableCovariance.load(ref_fn)
# data = covariance.observables('power')
# observable = TracerPowerSpectrumMultipolesObservable(data=data, covariance=covariance.select(observables=data, select_observables=True), wmatrix=data.attrs['wmatrix'], theory=theory, kin=data.attrs['kin'], ellsin=data.attrs['ellsin'], wshotnoise=data.attrs['wshotnoise'])
# likelihood = ObservablesGaussianLikelihood(observables=[observable])
# likelihood()

# %%
# import desilike, inspect
# print(inspect.getfile(desilike))
# sys.path.insert(0, "/global/u1/p/prakharb/desilike")
from desilike.emulators import Emulator, EmulatedCalculator, TaylorEmulatorEngine
emulator = Emulator(theory, engine=TaylorEmulatorEngine(order={'*': 2, 'sn0': 1}))  # order 2 except for sn0 (order 1 is enough)
emulator.set_samples()
emulator.fit()
emulator.plot(name='power')
# Out:
# ✅ Using NumPy with CPU.
# Loading matrices from matrices_nfftlog128_Afull_True_remove-DeltaP_False.npy
# /global/u1/p/prakharb/cosmoprimo/cosmoprimo/eisenstein_hu.py:25: UserWarning: EisensteinHuNoWiggleEngine cannot cope with massive neutrinos
#   warnings.warn('{} cannot cope with massive neutrinos'.format(self.__class__.__name__))
# [000031.22] [0/1] 08-12 21:40  Emulator                  INFO     Varied parameters: ['h', 'omega_cdm', 'omega_b', 'logA', 'b1', 'b2', 'bs', 'c1', 'c2', 'Pshot', 'Bshot', 'X_FoG_b'].
# [000031.22] [0/1] 08-12 21:40  Emulator                  INFO     Found varying ['power'] and fixed ['k', 'z', 'ells'] outputs.
# [000034.45] [0/1] 08-12 21:40  Differentiation           INFO     Varied parameters: ['h', 'omega_cdm', 'omega_b', 'logA', 'b1', 'b2', 'bs', 'c1', 'c2', 'Pshot', 'Bshot', 'X_FoG_b'].
# [000049.61] [0/1] 08-12 21:41  Differentiation           INFO     Using finite-differentiation for parameter h.
# /global/u1/p/prakharb/cosmoprimo/cosmoprimo/eisenstein_hu.py:25: UserWarning: EisensteinHuNoWiggleEngine cannot cope with massive neutrinos
#   warnings.warn('{} cannot cope with massive neutrinos'.format(self.__class__.__name__))
# [000051.31] [0/1] 08-12 21:41  Differentiation           INFO     Using finite-differentiation for parameter omega_cdm.
# [000053.00] [0/1] 08-12 21:41  Differentiation           INFO     Using finite-differentiation for parameter omega_b.
# [000054.73] [0/1] 08-12 21:41  Differentiation           INFO     Using finite-differentiation for parameter logA.
# [000055.18] [0/1] 08-12 21:41  Differentiation           INFO     Using finite-differentiation for parameter b1.
# [000055.33] [0/1] 08-12 21:41  Differentiation           INFO     Using finite-differentiation for parameter b2.
# [000055.46] [0/1] 08-12 21:41  Differentiation           INFO     Using finite-differentiation for parameter bs.
# [000055.59] [0/1] 08-12 21:41  Differentiation           INFO     Using finite-differentiation for parameter c1.
# [000055.71] [0/1] 08-12 21:41  Differentiation           INFO     Using finite-differentiation for parameter c2.
# [000055.84] [0/1] 08-12 21:41  Differentiation           INFO     Using finite-differentiation for parameter Pshot.
# [000056.02] [0/1] 08-12 21:41  Differentiation           INFO     Using finite-differentiation for parameter Bshot.
# [000056.22] [0/1] 08-12 21:41  Differentiation           INFO     Using finite-differentiation for parameter X_FoG_b.
# [000056.22] [0/1] 08-12 21:41  Differentiation           INFO     h grid is [0.6436 0.6736 0.7036].
# [000056.22] [0/1] 08-12 21:41  Differentiation           INFO     omega_cdm grid is [0.11 0.12 0.13].
# [000056.22] [0/1] 08-12 21:41  Differentiation           INFO     omega_b grid is [0.02087 0.02237 0.02387].
# [000056.22] [0/1] 08-12 21:41  Differentiation           INFO     logA grid is [2.98639426 3.03639426 3.08639426].
# [000056.22] [0/1] 08-12 21:41  Differentiation           INFO     b1 grid is [1.4942265 1.5       1.5057735].
# [000056.23] [0/1] 08-12 21:41  Differentiation           INFO     b2 grid is [-0.05773503  0.          0.05773503].
# [000056.23] [0/1] 08-12 21:41  Differentiation           INFO     bs grid is [-0.05773503  0.          0.05773503].
# [000056.23] [0/1] 08-12 21:41  Differentiation           INFO     c1 grid is [-0.1  0.   0.1].
# [000056.23] [0/1] 08-12 21:41  Differentiation           INFO     c2 grid is [-0.1  0.   0.1].
# [000056.23] [0/1] 08-12 21:41  Differentiation           INFO     Pshot grid is [-1000.     0.  1000.].
# [000056.23] [0/1] 08-12 21:41  Differentiation           INFO     Bshot grid is [-1000.     0.  1000.].
# [000056.23] [0/1] 08-12 21:41  Differentiation           INFO     X_FoG_b grid is [-0.01  0.    0.01].
# [000056.24] [0/1] 08-12 21:41  Differentiation           INFO     Differentiation will evaluate 289 points.
# [000408.98] [0/1] 08-12 21:47  Emulator                  INFO     Fitting power.
# [<Figure size 600x600 with 2 Axes>]

# %%
import os
base_dir = '_tests'
folps_emulator_fn = os.path.join(base_dir, 'folpsv2_emulator.npy')
emulator.save(folps_emulator_fn)
# Out:
# [000169.59] [0/1] 08-01 07:03  Emulator                  INFO     Saving _tests/folpsv2_emulator.npy.
# [000169.59] [0/1] 08-01 07:03  BaseConfig                INFO     Saving _tests/folpsv2_emulator.yaml.

# %%
from desilike.samplers import ZeusSampler

# Let's just update the observable's theory, no need to redefine the observable & likelihood
# (Internally the code will reinitialize all calculators that depend on observable)
observable.init.update(theory=emulator.to_calculator())

sampler = ZeusSampler(likelihood, save_fn='_tests/chain_fs_direct_*.npy', seed=42)
sampler.run(check={'max_eigen_gr': 0.1})
# Out:
# [000171.79] [0/1] 08-01 07:03  ZeusSampler               INFO     Varied parameters: ['h', 'omega_cdm', 'omega_b', 'logA', 'b1', 'b2', 'bs', 'b3', 'alpha0', 'alpha2', 'alpha4', 'sn0', 'sn2', 'X_FoG_p'].
# [000173.10] [0/1] 08-01 07:03  ZeusSampler               INFO     Successfully vmap input likelihood.
# [000173.57] [0/1] 08-01 07:03  ZeusSampler               INFO     Successfully jit input likelihood.
# [000174.04] [0/1] 08-01 07:03  root                      INFO     Initialising ensemble of 36 walkers...
# [000231.25] [0/1] 08-01 07:04  Chain                     INFO     Saving _tests/chain_fs_direct_0.npy.
# [000231.26] [0/1] 08-01 07:04  ZeusSampler               INFO     Diagnostics:
# [000231.32] [0/1] 08-01 07:04  Diagnostics               INFO     - max eigen Gelman-Rubin - 1 is 0.341; not < 0.1.
# [000231.47] [0/1] 08-01 07:04  Diagnostics               INFO     - max diag Gelman-Rubin - 1 is 0.084.
# [000232.04] [0/1] 08-01 07:04  Diagnostics               INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.345.
# [000232.10] [0/1] 08-01 07:04  Diagnostics               INFO     - max Geweke is 0.243.
# [000232.11] [0/1] 08-01 07:04  Diagnostics               INFO     - Geweke p-value is 4.71e-06.
# [000232.48] [0/1] 08-01 07:04  Diagnostics               INFO     - effective sample size = (150 iterations / integrated autocorrelation time) is 8.65.
# [000232.49] [0/1] 08-01 07:04  root                      INFO     Initialising ensemble of 36 walkers...
# [000274.74] [0/1] 08-01 07:05  Chain                     INFO     Saving _tests/chain_fs_direct_0.npy.
# [000274.76] [0/1] 08-01 07:05  ZeusSampler               INFO     Diagnostics:
# [000274.80] [0/1] 08-01 07:05  Diagnostics               INFO     - max eigen Gelman-Rubin - 1 is 0.526; not < 0.1.
# [000274.90] [0/1] 08-01 07:05  Diagnostics               INFO     - max diag Gelman-Rubin - 1 is 0.163.
# [000275.28] [0/1] 08-01 07:05  Diagnostics               INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.904.
# [000275.31] [0/1] 08-01 07:05  Diagnostics               INFO     - max Geweke is 0.259.
# [000275.37] [0/1] 08-01 07:05  Diagnostics               INFO     - Geweke p-value is 0.00413.
# [000275.61] [0/1] 08-01 07:05  Diagnostics               INFO     - effective sample size = (300 iterations / integrated autocorrelation time) is 9.02.
# [000275.61] [0/1] 08-01 07:05  Diagnostics               INFO     - max variation of integrated autocorrelation time is 0.556.
# [000275.62] [0/1] 08-01 07:05  root                      INFO     Initialising ensemble of 36 walkers...
# [000318.75] [0/1] 08-01 07:06  Chain                     INFO     Saving _tests/chain_fs_direct_0.npy.
# [000318.77] [0/1] 08-01 07:06  ZeusSampler               INFO     Diagnostics:
# [000318.83] [0/1] 08-01 07:06  Diagnostics               INFO     - max eigen Gelman-Rubin - 1 is 0.59; not < 0.1.
# [000318.98] [0/1] 08-01 07:06  Diagnostics               INFO     - max diag Gelman-Rubin - 1 is 0.05.
# [000319.47] [0/1] 08-01 07:06  Diagnostics               INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.367.
# [000319.50] [0/1] 08-01 07:06  Diagnostics               INFO     - max Geweke is 0.289.
# [000319.50] [0/1] 08-01 07:06  Diagnostics               INFO     - Geweke p-value is 4.14e-05.
# [000319.78] [0/1] 08-01 07:06  Diagnostics               INFO     - effective sample size = (450 iterations / integrated autocorrelation time) is 9.86.
# [000319.78] [0/1] 08-01 07:06  Diagnostics               INFO     - max variation of integrated autocorrelation time is 0.394.
# [000319.79] [0/1] 08-01 07:06  root                      INFO     Initialising ensemble of 36 walkers...
# zeus: Exception while calling your likelihood function:
#   params: [[ 6.82165792e-01  1.21016242e-01  2.28454109e-02  3.15990001e+00
#    1.87727820e+00 -8.58774701e+00  4.88714618e-01 -4.67845866e+00
#    2.60125835e+02  1.80952759e+02 -1.14907152e+02  1.01165600e+00
#    1.42556508e+01 -3.29003594e+00]
#  [ 7.14271530e-01  9.28798034e-02  2.25971600e-02  3.25576956e+00
#    1.99240417e+00 -1.77066992e+00 -3.52975485e-01  2.59879380e+00
#   -3.48118567e+01 -2.41848464e+02  4.71248332e+01  1.75217718e-02
#    1.51884001e+01 -1.64637472e+00]
#  [ 6.56009477e-01  8.97405317e-02  2.30169733e-02  3.78333112e+00
#    1.35771399e+00  4.80377987e-01 -1.24828343e+01  2.05705478e-01
#    3.63831062e+01 -4.13603081e+01 -9.31075607e+01  1.42434162e+00
#    8.71887638e+00 -1.11767812e+00]
#  [ 6.79737340e-01  9.78047137e-02  2.29455734e-02  3.18129749e+00
#    2.13063130e+00 -1.21934826e+00 -2.29266746e+00  1.01508088e+00
#   -1.69331543e+01  8.98388302e+02 -1.23147859e+03 -1.65772395e-01
#    4.37562285e+00  1.28630162e+00]]
#   args: []
#   kwargs: {}
#   exception:
# [000354.15] [0/1] 08-01 07:06  Exception                 CRITICAL
# ====================================================================================================
# Traceback (most recent call last):
#   File "/global/u1/p/prakharb/desilike/desilike/parameter.py", line 2341, in __setitem__
#     self.data[name] = item  # list index
# TypeError: list indices must be integers or slices, not Parameter
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/global/u1/p/prakharb/desilike/desilike/samplers/base.py", line 463, in _run_batch
#     chain = self._run_one(start[ichain], niterations=niterations, **kwargs)
#   File "/global/u1/p/prakharb/desilike/desilike/samplers/zeus.py", line 120, in _run_one
#     for _ in self.sampler.sample(start=start, iterations=niterations, progress=progress, thin_by=thin_by):
#   File "/global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/zeus/ensemble.py", line 653, in sample
#     Z_prime[mask], _ = self.compute_log_prob(X_prime[mask])
#   File "/global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/zeus/ensemble.py", line 353, in compute_log_prob
#     results = self.logprob_fn(p)
#   File "/global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/zeus/fwrapper.py", line 24, in __call__
#     return self.f(x, *self.args, **self.kwargs)
#   File "/global/u1/p/prakharb/desilike/desilike/samplers/base.py", line 61, in wrapper
#     toret[mask] = func(self, values)
#   File "/global/u1/p/prakharb/desilike/desilike/samplers/base.py", line 150, in logposterior
#     points = Samples(values[mask_finite_prior].T, params=self.varied_params)
#   File "/global/u1/p/prakharb/desilike/desilike/parameter.py", line 2157, in __init__
#     self[param] = value
#   File "/global/u1/p/prakharb/desilike/desilike/parameter.py", line 2353, in __setitem__
#     self.set(item)
#   File "/global/u1/p/prakharb/desilike/desilike/parameter.py", line 2310, in set
#     item = _reshape(item, shape)
#   File "/global/u1/p/prakharb/desilike/desilike/parameter.py", line 2118, in _reshape
#     return array.reshape(shape + array.pshape)
#   File "/global/u1/p/prakharb/desilike/desilike/parameter.py", line 640, in wrapper
#     new = self.__class__(getattr(self.value, func)(*args, **kwargs))
#   File "/global/u1/p/prakharb/desilike/desilike/parameter.py", line 407, in __init__
#     def __init__(self, value, param=None, derivs=None, copy=False, dtype=None, **kwargs):
# KeyboardInterrupt
# ====================================================================================================
# [000354.15] [0/1] 08-01 07:06  Exception                 CRITICAL Interrupted by the user.
# Traceback (most recent call last):
#   File "/global/u1/p/prakharb/desilike/desilike/parameter.py", line 2341, in __setitem__
#     self.data[name] = item  # list index
# TypeError: list indices must be integers or slices, not Parameter
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/zeus/fwrapper.py", line 24, in __call__
#     return self.f(x, *self.args, **self.kwargs)
#   File "/global/u1/p/prakharb/desilike/desilike/samplers/base.py", line 61, in wrapper
#     toret[mask] = func(self, values)
#   File "/global/u1/p/prakharb/desilike/desilike/samplers/base.py", line 150, in logposterior
#     points = Samples(values[mask_finite_prior].T, params=self.varied_params)
#   File "/global/u1/p/prakharb/desilike/desilike/parameter.py", line 2157, in __init__
#     self[param] = value
#   File "/global/u1/p/prakharb/desilike/desilike/parameter.py", line 2353, in __setitem__
#     self.set(item)
#   File "/global/u1/p/prakharb/desilike/desilike/parameter.py", line 2310, in set
#     item = _reshape(item, shape)
#   File "/global/u1/p/prakharb/desilike/desilike/parameter.py", line 2118, in _reshape
#     return array.reshape(shape + array.pshape)
#   File "/global/u1/p/prakharb/desilike/desilike/parameter.py", line 640, in wrapper
#     new = self.__class__(getattr(self.value, func)(*args, **kwargs))
#   File "/global/u1/p/prakharb/desilike/desilike/parameter.py", line 407, in __init__
#     def __init__(self, value, param=None, derivs=None, copy=False, dtype=None, **kwargs):
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /global/u1/p/prakharb/desilike/desilike/parameter.py:2341, in Samples.__setitem__(self, name, item)
#    2340 try:
# -> 2341     self.data[name] = item  # list index
#    2342 except TypeError:
#
# TypeError: list indices must be integers or slices, not Parameter
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 8
#       5 observable.init.update(theory=emulator.to_calculator())
#       7 sampler = ZeusSampler(likelihood, save_fn='_tests/chain_fs_direct_*.npy', seed=42)
# ----> 8 sampler.run(check={'max_eigen_gr': 0.1})
#
# File /global/u1/p/prakharb/desilike/desilike/samplers/zeus.py:113, in ZeusSampler.run(self, *args, **kwargs)
#      85 def run(self, *args, **kwargs):
#      86     """
#      87     Run chains. Sampling can be interrupted anytime, and resumed by providing the path to the saved chains in ``chains`` argument of :meth:`__init__`.
#      88
#    (...)
#     111         Thin samples by this factor.
#     112     """
# --> 113     return super(ZeusSampler, self).run(*args, **kwargs)
#
# File /global/u1/p/prakharb/desilike/desilike/samplers/base.py:501, in BaseBatchPosteriorSampler.run(self, min_iterations, max_iterations, check_every, check, **kwargs)
#     498         is_converged = self.check(**check)
#     499     return is_converged
# --> 501 batch_iterate(_run_batch, min_iterations=min_iterations, max_iterations=max_iterations, check_every=check_every)
#     502 return self.chains
#
# File /global/u1/p/prakharb/desilike/desilike/samplers/base.py:38, in batch_iterate(func, min_iterations, max_iterations, check_every, **kwargs)
#      36 niter = min(max_iterations - count_iterations, check_every)
#      37 count_iterations += niter
# ---> 38 is_converged = func(niterations=niter, **kwargs)
#      39 if count_iterations < min_iterations:
#      40     is_converged = False
#
# File /global/u1/p/prakharb/desilike/desilike/samplers/base.py:463, in BaseBatchPosteriorSampler.run.<locals>._run_batch(niterations)
#     461 self._set_rng(rng=self.rng)
#     462 self._ichain = ichain
# --> 463 chain = self._run_one(start[ichain], niterations=niterations, **kwargs)
#     464 if self.mpicomm.rank == 0:
#     465     ncalls[ichain] = self.derived[1][self.likelihood._param_loglikelihood].size if self.derived is not None else 0
#
# File /global/u1/p/prakharb/desilike/desilike/samplers/zeus.py:120, in ZeusSampler._run_one(self, start, niterations, thin_by, progress)
#     118 np.random.set_state(self.rng.get_state())
#     119 #self.sampler.__dict__.update(getattr(self, '_state', {}))
# --> 120 for _ in self.sampler.sample(start=start, iterations=niterations, progress=progress, thin_by=thin_by):
#     121     pass
#     122 chain = self.sampler.get_chain()
#
# File /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/zeus/ensemble.py:653, in EnsembleSampler.sample(self, start, log_prob0, blobs0, iterations, thin, thin_by, progress)
#     651 # Calculate LogP of New Positions
#     652 if blobs is None:
# --> 653     Z_prime[mask], _ = self.compute_log_prob(X_prime[mask])
#     654     #Z_prime[mask] = np.array(list(self.distribute(self.logprob_fn, X_prime[mask])))
#     655 else:
#     656     Z_prime[mask], blobs_prime[mask] = self.compute_log_prob(X_prime[mask])
#
# File /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/zeus/ensemble.py:353, in EnsembleSampler.compute_log_prob(self, coords)
#     351 # Run the log-probability calculations (optionally in parallel).
#     352 if self.vectorize:
# --> 353     results = self.logprob_fn(p)
#     354 else:
#     355     results = list(self.distribute(self.logprob_fn, (p[i] for i in range(len(p)))))
#
# File /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/zeus/fwrapper.py:24, in _FunctionWrapper.__call__(self, x)
#      22 def __call__(self, x):
#      23     try:
# ---> 24         return self.f(x, *self.args, **self.kwargs)
#      25     except:
#      26         import traceback
#
# File /global/u1/p/prakharb/desilike/desilike/samplers/base.py:61, in bcast_values.<locals>.wrapper(self, values)
#      59 values = values[mask]
#      60 if values.size:
# ---> 61     toret[mask] = func(self, values)
#      62 if isscalar and toret.size:
#      63     toret = toret[0]
#
# File /global/u1/p/prakharb/desilike/desilike/samplers/base.py:150, in BasePosteriorSampler.logposterior(self, values)
#     148 if not mask_finite_prior.any():
#     149     return logprior
# --> 150 points = Samples(values[mask_finite_prior].T, params=self.varied_params)
#     151 results = self._vlikelihood(points.to_dict())
#     152 #print(self.mpicomm.size, self.mpicomm.rank)
#
# File /global/u1/p/prakharb/desilike/desilike/parameter.py:2157, in Samples.__init__(self, data, params, attrs)
#    2155         raise ValueError('Provide as many parameters as arrays')
#    2156     for param, value in zip(params, data):
# -> 2157         self[param] = value
#    2158 else:
#    2159     super(Samples, self).__init__(data=data, attrs=attrs)
#
# File /global/u1/p/prakharb/desilike/desilike/parameter.py:2353, in Samples.__setitem__(self, name, item)
#    2351         item.param = item.param.clone(name=name)
#    2352     #raise KeyError('Parameter {} must be indexed by name (incorrect {})'.format(item_name, name))
# -> 2353 self.set(item)
#
# File /global/u1/p/prakharb/desilike/desilike/parameter.py:2310, in Samples.set(self, item)
#    2308     shape = item.ashape
#    2309     #if not shape: shape = (1,)
# -> 2310 item = _reshape(item, shape)
#    2311 super(Samples, self).set(item)
#
# File /global/u1/p/prakharb/desilike/desilike/parameter.py:2118, in _reshape(array, shape)
#    2116 shape = tuple(shape)
#    2117 try:
# -> 2118     return array.reshape(shape + array.pshape)
#    2119 except ValueError as exc:
#    2120     raise ValueError('Error with array {}'.format(repr(array))) from exc
#
# File /global/u1/p/prakharb/desilike/desilike/parameter.py:640, in get_wrapper.<locals>.wrapper(self, *args, **kwargs)
#     639 def wrapper(self, *args, **kwargs):
# --> 640     new = self.__class__(getattr(self.value, func)(*args, **kwargs))
#     641     new.__array_finalize__(self, copy=True)
#     642     return new
#
# File /global/u1/p/prakharb/desilike/desilike/parameter.py:407, in ParameterArray.__init__(self, value, param, derivs, copy, dtype, **kwargs)
#     404 @register_pytree_node_class
#     405 class ParameterArray(numpy.lib.mixins.NDArrayOperatorsMixin):
# --> 407     def __init__(self, value, param=None, derivs=None, copy=False, dtype=None, **kwargs):
#     408         """
#     409         Initalize :class:`ParameterArray`.
#     410
#    (...)
#     429             Optional arguments for :func:`np.array`.
#     430         """
#     431         if isinstance(value, ParameterArray):
#
# KeyboardInterrupt:

# %% [markdown]
# # Profiler Test

# %%
import numpy as np
from matplotlib import pyplot as plt

from desilike.theories.galaxy_clustering import DirectPowerSpectrumTemplate
from desilike.observables import ObservableCovariance
from desilike.observables.galaxy_clustering import TracerPowerSpectrumMultipolesObservable
from desilike.likelihoods import ObservablesGaussianLikelihood
from desilike.profilers import MinuitProfiler
from desilike import setup_logging

setup_logging()

template = DirectPowerSpectrumTemplate(z=zeff_power)
theory = FOLPSv2TracerPowerSpectrumMultipoles(template=template, tracer='ELG', prior_basis='physical')
covariance = ObservableCovariance.load(ref_fn)
data = covariance.observables('power')
observable = TracerPowerSpectrumMultipolesObservable(data=data, covariance=covariance.select(observables=data, select_observables=True), wmatrix=data.attrs['wmatrix'], theory=theory, kin=data.attrs['kin'], ellsin=data.attrs['ellsin'], wshotnoise=data.attrs['wshotnoise'])
likelihood = ObservablesGaussianLikelihood(observables=[observable])

profiler = MinuitProfiler(likelihood, seed=42)
profiles = profiler.maximize()
print(profiles.to_stats(tablefmt='pretty'))
# Out:
# [000000.32] [0/1] 08-01 07:09  ObservableCovariance      INFO     Loading /global/cfs/cdirs/desi/survey/catalogs/Y1/LSS/iron/LSScats/v1.5/unblinded/desipipe/forfit_2pt/forfit_power+bao-recon_syst-rotation-hod-photo_klim_0-0.02-0.20_2-0.02-0.20_LRG_GCcomb_z0.8-1.1.npy.
# Loading matrices from matrices_nfftlog128_Afull_True_remove-DeltaP_False.npy
# /global/u1/p/prakharb/cosmoprimo/cosmoprimo/eisenstein_hu.py:25: UserWarning: EisensteinHuNoWiggleEngine cannot cope with massive neutrinos
#   warnings.warn('{} cannot cope with massive neutrinos'.format(self.__class__.__name__))
# Loading matrices from matrices_nfftlog128_Afull_True_remove-DeltaP_False.npy
# [000006.26] [0/1] 08-01 07:09  MinuitProfiler            INFO     Varied parameters: ['h', 'omega_cdm', 'omega_b', 'logA', 'b1p', 'b2p', 'bsp', 'alpha0p', 'alpha2p', 'alpha4p', 'sn0p', 'sn2p', 'X_FoG_pp'].
# [000012.29] [0/1] 08-01 07:09  MinuitProfiler            INFO     Could *not* jit input likelihood.
# [000012.29] [0/1] 08-01 07:09  MinuitProfiler            INFO     Could *not* vmap input likelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.
# /global/u1/p/prakharb/desilike/desilike/profilers/base.py:254: UserWarning: Error "CosmologyComputationError()" raised with parameters {'h': 0.8079874813466813, 'omega_cdm': 0.2121607814730017, 'omega_b': 89330.06242595213, 'logA': 3.619595816276879, 'b1p': 2.872446419987303, 'b2p': 0.5416130459787156, 'bsp': 14.920700024984479, 'alpha0p': 10.669618617924385, 'alpha2p': -5.08114485073089, 'alpha4p': 0.20831730096549306, 'sn0p': -13.801875049633075, 'sn2p': -1.792588208373066, 'X_FoG_pp': 5.2967278946807115} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.
#   warnings.warn('Error "{}" raised with parameters {} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.'.format(repr(error[0]), points))
# /global/u1/p/prakharb/desilike/desilike/profilers/base.py:254: UserWarning: Error "CosmologyComputationError()" raised with parameters {'h': 0.4289953790072228, 'omega_cdm': 0.9722224577607063, 'omega_b': 4466.524118475725, 'logA': 2.071685950906578, 'b1p': 1.698633900533427, 'b2p': -0.746577286624127, 'bsp': 1.412038040001604, 'alpha0p': 7.938683229324487, 'alpha2p': -1.049877040369637, 'alpha4p': -0.8098381585008979, 'sn0p': -0.663119535033308, 'sn2p': 0.39227999480166675, 'X_FoG_pp': 7.499459189308452} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.
#   warnings.warn('Error "{}" raised with parameters {} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.'.format(repr(error[0]), points))
# /global/u1/p/prakharb/desilike/desilike/profilers/base.py:254: UserWarning: Error "CosmologyComputationError()" raised with parameters {'h': 0.5489965604696537, 'omega_cdm': 0.41528084648282004, 'omega_b': 223.34720310190437, 'logA': 2.8035037657695154, 'b1p': 0.7202752224363456, 'b2p': -0.8109868032542691, 'bsp': 0.7366049407524602, 'alpha0p': 7.802136459894492, 'alpha2p': -0.8483136498515744, 'alpha4p': -0.8607459314742174, 'sn0p': -0.006181759303319628, 'sn2p': 0.5015234049604034, 'X_FoG_pp': 7.609595754039839} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.
#   warnings.warn('Error "{}" raised with parameters {} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.'.format(repr(error[0]), points))
# /global/u1/p/prakharb/desilike/desilike/profilers/base.py:254: UserWarning: Error "CosmologyComputationError()" raised with parameters {'h': 0.41577485187252256, 'omega_cdm': 0.31787112609977863, 'omega_b': 11.188357333213336, 'logA': 2.8901368734102415, 'b1p': 1.1050383979499285, 'b2p': -0.8142072790857763, 'bsp': 0.7028332857900029, 'alpha0p': 7.795309121422992, 'alpha2p': -0.8382354803256712, 'alpha4p': -0.8632913201228835, 'sn0p': 0.026665129483179797, 'sn2p': 0.5069855754683402, 'X_FoG_pp': 7.615102582276409} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.
#   warnings.warn('Error "{}" raised with parameters {} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.'.format(repr(error[0]), points))
# /global/u1/p/prakharb/desilike/desilike/profilers/base.py:254: UserWarning: Error "CosmologyComputationError()" raised with parameters {'h': 0.6874467185891121, 'omega_cdm': 0.12240059312639828, 'omega_b': 0.5804150447787828, 'logA': 2.8944962656403788, 'b1p': 1.1253489590802066, 'b2p': -0.8143683028773516, 'bsp': 0.70114470304188, 'alpha0p': 7.794967754499417, 'alpha2p': -0.8377315718493761, 'alpha4p': -0.8634185895553167, 'sn0p': 0.028307473922504767, 'sn2p': 0.5072586839937371, 'X_FoG_pp': 7.615377923688237} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.
#   warnings.warn('Error "{}" raised with parameters {} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.'.format(repr(error[0]), points))
# /global/u1/p/prakharb/desilike/desilike/profilers/base.py:254: UserWarning: Error "CosmologyComputationError()" raised with parameters {'h': 0.7005195507106913, 'omega_cdm': 0.11472801295725879, 'omega_b': 0.050017930357055124, 'logA': 2.8947142891981668, 'b1p': 1.126366450455254, 'b2p': -0.8143763540669303, 'bsp': 0.7010602739044739, 'alpha0p': 7.794950686153239, 'alpha2p': -0.8377063764255613, 'alpha4p': -0.8634249530269383, 'sn0p': 0.028389591144471017, 'sn2p': 0.5072723394200069, 'X_FoG_pp': 7.615391690758829} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.
#   warnings.warn('Error "{}" raised with parameters {} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.'.format(repr(error[0]), points))
# /global/u1/p/prakharb/desilike/desilike/profilers/base.py:254: UserWarning: Error "CosmologyComputationError()" raised with parameters {'h': 0.7195085944895794, 'omega_cdm': 0.7409513918315657, 'omega_b': 2159.6695112105467, 'logA': 2.5127851534947467, 'b1p': 2.0413807245919666, 'b2p': 4.827207182753164, 'bsp': 9.838252175413539, 'alpha0p': 6.343223162793092, 'alpha2p': 4.057318398789253, 'alpha4p': 2.1036635335275142, 'sn0p': 0.7537537636462189, 'sn2p': 1.6007500562715127, 'X_FoG_pp': 8.61873400224302} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.
#   warnings.warn('Error "{}" raised with parameters {} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.'.format(repr(error[0]), points))
# /global/u1/p/prakharb/desilike/desilike/profilers/base.py:254: UserWarning: Error "CosmologyComputationError()" raised with parameters {'h': 0.2744550594291509, 'omega_cdm': 0.9871746782370657, 'omega_b': 108.00477715833215, 'logA': 2.0775768474957323, 'b1p': 1.3599481791606736, 'b2p': -0.5322975751644508, 'bsp': 1.1579156959808838, 'alpha0p': 7.722363466364244, 'alpha2p': -0.5929538923544608, 'alpha4p': -0.7150708432205031, 'sn0p': 0.06466185849974612, 'sn2p': 0.5619469001964086, 'X_FoG_pp': 7.6655594867850025} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.
#   warnings.warn('Error "{}" raised with parameters {} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.'.format(repr(error[0]), points))
# /global/u1/p/prakharb/desilike/desilike/profilers/base.py:254: UserWarning: Error "CosmologyComputationError()" raised with parameters {'h': 0.24621058660028128, 'omega_cdm': 0.15649845025786221, 'omega_b': 5.42154045572143, 'logA': 2.8417562371001477, 'b1p': 0.11350619186606827, 'b2p': -0.8002728130603315, 'bsp': 0.7238988720092511, 'alpha0p': 7.791320481542802, 'alpha2p': -0.8254675069116466, 'alpha4p': -0.856007562057904, 'sn0p': 0.03020726324242248, 'sn2p': 0.5100067423926533, 'X_FoG_pp': 7.617900761012102} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.
#   warnings.warn('Error "{}" raised with parameters {} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.'.format(repr(error[0]), points))
# /global/u1/p/prakharb/desilike/desilike/profilers/base.py:254: UserWarning: Error "CosmologyComputationError()" raised with parameters {'h': 0.999851523456259, 'omega_cdm': 0.010450677390978652, 'omega_b': 0.2923786205908933, 'logA': 2.892068762164671, 'b1p': 1.0036829531204432, 'b2p': -0.8136715749551254, 'bsp': 0.7021980308106694, 'alpha0p': 7.79476833230173, 'alpha2p': -0.8370931876395059, 'alpha4p': -0.863054397999774, 'sn0p': 0.028484533479556297, 'sn2p': 0.5074097345024656, 'X_FoG_pp': 7.615517824723457} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.
#   warnings.warn('Error "{}" raised with parameters {} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.'.format(repr(error[0]), points))
# /global/u1/p/prakharb/desilike/desilike/profilers/base.py:254: UserWarning: Error "CosmologyComputationError()" raised with parameters {'h': 0.9472090961264727, 'omega_cdm': 0.843762607917159, 'omega_b': 2283.19385549065, 'logA': 2.9323744146316946, 'b1p': 1.6570524770328245, 'b2p': -2.0944376497391706, 'bsp': 1.6878830604012713, 'alpha0p': 6.568508763860931, 'alpha2p': -0.45073012312045524, 'alpha4p': -0.3585996258683285, 'sn0p': -1.1833835078089923, 'sn2p': 0.7304331391882378, 'X_FoG_pp': 4.4052609636460724} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.
#   warnings.warn('Error "{}" raised with parameters {} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.'.format(repr(error[0]), points))
# /global/u1/p/prakharb/desilike/desilike/profilers/base.py:254: UserWarning: Error "CosmologyComputationError()" raised with parameters {'h': 0.43150165765303145, 'omega_cdm': 0.9865541107809295, 'omega_b': 114.18097677128851, 'logA': 2.9291014044484274, 'b1p': 1.8319525206688185, 'b2p': -1.2960898484184806, 'bsp': 1.1427839299652196, 'alpha0p': 6.931964888255524, 'alpha2p': -0.6574229181651051, 'alpha4p': -0.6347745353968849, 'sn0p': -0.02267341952343295, 'sn2p': 0.777640204001736, 'X_FoG_pp': 3.157530480227336} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.
#   warnings.warn('Error "{}" raised with parameters {} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.'.format(repr(error[0]), points))
# /global/u1/p/prakharb/desilike/desilike/profilers/base.py:254: UserWarning: Error "CosmologyComputationError()" raised with parameters {'h': 0.40253287888750894, 'omega_cdm': 0.15601412818740248, 'omega_b': 5.730332835320436, 'logA': 2.928937773679626, 'b1p': 1.1555693083877034, 'b2p': -1.256172458352446, 'bsp': 1.1155289734434168, 'alpha0p': 6.950137694475254, 'alpha2p': -0.6677575579173376, 'alpha4p': -0.6485832808733126, 'sn0p': 0.03536208489084502, 'sn2p': 0.7800005572424108, 'X_FoG_pp': 3.095143956056399} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.
#   warnings.warn('Error "{}" raised with parameters {} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.'.format(repr(error[0]), points))
# /global/u1/p/prakharb/desilike/desilike/profilers/base.py:254: UserWarning: Error "CosmologyComputationError()" raised with parameters {'h': 0.6791421364647859, 'omega_cdm': 0.115682130020137, 'omega_b': 0.3078006385220318, 'logA': 2.928929592191348, 'b1p': 1.1224599626584568, 'b2p': -1.2541765888491443, 'bsp': 1.1141662256173268, 'alpha0p': 6.95104633478624, 'alpha2p': -0.6682742899049492, 'alpha4p': -0.6492737181471341, 'sn0p': 0.03826386011155892, 'sn2p': 0.7801185749044446, 'X_FoG_pp': 3.0920246298478524} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.
#   warnings.warn('Error "{}" raised with parameters {} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.'.format(repr(error[0]), points))
# /global/u1/p/prakharb/desilike/desilike/profilers/base.py:254: UserWarning: Error "CosmologyComputationError()" raised with parameters {'h': 0.13495954908286587, 'omega_cdm': 0.9778443489715664, 'omega_b': 1.911174778794225, 'logA': 2.941277204230797, 'b1p': 2.5811739735927888, 'b2p': -2.105638453908493, 'bsp': 1.776499450765093, 'alpha0p': 6.534332129898873, 'alpha2p': -0.631231949260209, 'alpha4p': -0.4308139473791629, 'sn0p': -1.1537314048748255, 'sn2p': 0.8728900539733628, 'X_FoG_pp': 4.74397372586055} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.
#   warnings.warn('Error "{}" raised with parameters {} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.'.format(repr(error[0]), points))
# /global/u1/p/prakharb/desilike/desilike/profilers/base.py:254: UserWarning: Error "CosmologyComputationError()" raised with parameters {'h': 0.2623758676239133, 'omega_cdm': 0.5814470030576134, 'omega_b': 0.11685891971494602, 'logA': 2.9295463209991754, 'b1p': 1.7805587738461577, 'b2p': -1.296649894583793, 'bsp': 1.14721475355065, 'alpha0p': 6.930256053845506, 'alpha2p': -0.6664480079298613, 'alpha4p': -0.6383852494117565, 'sn0p': -0.02119082303732528, 'sn2p': 0.7847630493887582, 'X_FoG_pp': 3.17446612764796} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.
#   warnings.warn('Error "{}" raised with parameters {} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.'.format(repr(error[0]), points))
# /global/u1/p/prakharb/desilike/desilike/profilers/base.py:254: UserWarning: Error "CosmologyInputError('Parameter Omega_b should be positive, found -1.3405701388361004')" raised with parameters {'h': 0.6684872173386373, 'omega_cdm': 0.29267871027963976, 'omega_b': -0.5990674949419663, 'logA': 2.77211053240228, 'b1p': 1.3558565573975436, 'b2p': -0.7430483091553848, 'bsp': 1.8203447432139426, 'alpha0p': 5.924616631985785, 'alpha2p': -0.25157951949372115, 'alpha4p': -0.39444359967849096, 'sn0p': 0.34039167829790756, 'sn2p': 0.4894693336763639, 'X_FoG_pp': 3.0453619664286884} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.
#   warnings.warn('Error "{}" raised with parameters {} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.'.format(repr(error[0]), points))
# /global/u1/p/prakharb/desilike/desilike/profilers/base.py:254: UserWarning: Error "CosmologyInputError('Parameter Omega_b should be positive, found -0.07687818005879633')" raised with parameters {'h': 0.33428207033555085, 'omega_cdm': 0.6265746526342844, 'omega_b': -0.008590713987452099, 'logA': 2.9210130300437402, 'b1p': 1.1327268661325487, 'b2p': -1.2285485571872052, 'bsp': 1.1494289305347727, 'alpha0p': 6.8997564924582075, 'alpha2p': -0.647464160180962, 'alpha4p': -0.6365595041734718, 'sn0p': 0.05347589485509298, 'sn2p': 0.76559508204983, 'X_FoG_pp': 3.089590191598309} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.
#   warnings.warn('Error "{}" raised with parameters {} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.'.format(repr(error[0]), points))
# /global/u1/p/prakharb/desilike/desilike/profilers/base.py:254: UserWarning: Error "CosmologyInputError('Parameter Omega_b should be positive, found -23140.710648299068')" raised with parameters {'h': 0.37815327468088245, 'omega_cdm': 0.08353927646055163, 'omega_b': -3309.119289009485, 'logA': 3.0533058900546077, 'b1p': 2.6287701100742704, 'b2p': -1.383263717377609, 'bsp': 1.4014115299663241, 'alpha0p': 2.8044322543338076, 'alpha2p': 0.0564806112435072, 'alpha4p': 0.043934105927248016, 'sn0p': -0.2197744361060956, 'sn2p': 1.2007877276610055, 'X_FoG_pp': 4.17792285085215} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.
#   warnings.warn('Error "{}" raised with parameters {} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.'.format(repr(error[0]), points))
# /global/u1/p/prakharb/desilike/desilike/profilers/base.py:254: UserWarning: Error "CosmologyInputError('Parameter Omega_b should be positive, found -428.59637149544716')" raised with parameters {'h': 0.6212822749164917, 'omega_cdm': 0.9898024729452287, 'omega_b': -165.43462710023695, 'logA': 3.006462363463508, 'b1p': 1.302201027123055, 'b2p': -1.3027286439221228, 'bsp': 1.4190264323373882, 'alpha0p': 3.017834961091291, 'alpha2p': -0.0667845219181686, 'alpha4p': -0.056870073260939076, 'sn0p': 0.021240611910813785, 'sn2p': 1.2097327307395915, 'X_FoG_pp': 4.17187598536688} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.
#   warnings.warn('Error "{}" raised with parameters {} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.'.format(repr(error[0]), points))
# /global/u1/p/prakharb/desilike/desilike/profilers/base.py:254: UserWarning: Error "CosmologyInputError('Parameter Omega_b should be positive, found -73.9792744402279')" raised with parameters {'h': 0.3339506635823396, 'omega_cdm': 0.27664278223501454, 'omega_b': -8.250394004774519, 'logA': 3.0041189588534434, 'b1p': 1.1240275927756163, 'b2p': -1.2987018902493486, 'bsp': 1.4199071774559413, 'alpha0p': 3.0285050964291655, 'alpha2p': -0.07294777857625238, 'alpha4p': -0.06191028222034843, 'sn0p': 0.03329136431165926, 'sn2p': 1.2101799808935207, 'X_FoG_pp': 4.171573642092616} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.
#   warnings.warn('Error "{}" raised with parameters {} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.'.format(repr(error[0]), points))
# /global/u1/p/prakharb/desilike/desilike/profilers/base.py:254: UserWarning: Error "CosmologyInputError('Parameter Omega_b should be positive, found -0.8741386133982897')" raised with parameters {'h': 0.6689589573133572, 'omega_cdm': 0.1197750546531958, 'omega_b': -0.3911823500013973, 'logA': 3.0040017879221868, 'b1p': 1.1152420638784133, 'b2p': -1.2985005525657098, 'bsp': 1.4199512147118691, 'alpha0p': 3.029038603196059, 'alpha2p': -0.07325594140915657, 'alpha4p': -0.0621622926683189, 'sn0p': 0.03389390193170153, 'sn2p': 1.2102023434012172, 'X_FoG_pp': 4.171558524928903} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.
#   warnings.warn('Error "{}" raised with parameters {} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.'.format(repr(error[0]), points))
# /global/u1/p/prakharb/desilike/desilike/profilers/base.py:254: UserWarning: Error "CosmologyComputationError()" raised with parameters {'h': 0.685539160719001, 'omega_cdm': 0.11344484009897361, 'omega_b': 0.001778232737258842, 'logA': 3.0039959293741685, 'b1p': 1.1148031550418411, 'b2p': -1.2984904856815278, 'bsp': 1.4199534165746655, 'alpha0p': 3.0290652785344037, 'alpha2p': -0.07327134955080178, 'alpha4p': -0.06217489319071742, 'sn0p': 0.03392402881270364, 'sn2p': 1.2102034615266022, 'X_FoG_pp': 4.171557769070717} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.
#   warnings.warn('Error "{}" raised with parameters {} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.'.format(repr(error[0]), points))
# /global/u1/p/prakharb/desilike/desilike/profilers/base.py:254: UserWarning: Error "CosmologyInputError('Parameter Omega_b should be positive, found -3918.9937581978566')" raised with parameters {'h': 0.12620729159631972, 'omega_cdm': 0.5426941683376326, 'omega_b': -62.42283167052046, 'logA': 2.919567425647329, 'b1p': 1.7586600036497186, 'b2p': -1.549782073695451, 'bsp': 1.3847621616515808, 'alpha0p': 3.120879463967547, 'alpha2p': -0.10236781842564582, 'alpha4p': -0.08841408036506744, 'sn0p': -0.37390504656473844, 'sn2p': 1.218386461495033, 'X_FoG_pp': 4.265893182821819} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.
#   warnings.warn('Error "{}" raised with parameters {} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.'.format(repr(error[0]), points))
# /global/u1/p/prakharb/desilike/desilike/profilers/base.py:254: UserWarning: Error "CosmologyInputError('Parameter Omega_b should be positive, found -64.4014585902512')" raised with parameters {'h': 0.21939366915141276, 'omega_cdm': 0.5408895940624386, 'omega_b': -3.0998728920770926, 'logA': 2.999769873460104, 'b1p': 1.6140209246861776, 'b2p': -1.3110545634969193, 'bsp': 1.4181939635369374, 'alpha0p': 3.0336573169122145, 'alpha2p': -0.07472694070948768, 'alpha4p': -0.06348748037396865, 'sn0p': 0.013534076124058148, 'sn2p': 1.2106126672359319, 'X_FoG_pp': 4.176274502097428} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.
#   warnings.warn('Error "{}" raised with parameters {} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.'.format(repr(error[0]), points))
# /global/u1/p/prakharb/desilike/desilike/profilers/base.py:254: UserWarning: Error "CosmologyInputError('Parameter Omega_b should be positive, found -0.14665713146565804')" raised with parameters {'h': 0.9548928338669446, 'omega_cdm': 0.17997798237011084, 'omega_b': -0.13372495315492378, 'logA': 3.0037843357419844, 'b1p': 1.1391743928608973, 'b2p': -1.2991181879869926, 'bsp': 1.4198655536312053, 'alpha0p': 3.0292962095594476, 'alpha2p': -0.07334489682367978, 'alpha4p': -0.062241150374413697, 'sn0p': 0.03290603225849798, 'sn2p': 1.2102239775229768, 'X_FoG_pp': 4.171793568061209} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.
#   warnings.warn('Error "{}" raised with parameters {} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.'.format(repr(error[0]), points))
# /global/u1/p/prakharb/desilike/desilike/profilers/base.py:254: UserWarning: Error "CosmologyComputationError()" raised with parameters {'h': 0.15300309040683363, 'omega_cdm': 0.18408795857483828, 'omega_b': 2067.401237467838, 'logA': 3.0801354784080575, 'b1p': 1.8082591642759847, 'b2p': -1.218990366843765, 'bsp': 1.435534155033491, 'alpha0p': 2.9628437854449343, 'alpha2p': -0.16911138533842718, 'alpha4p': -0.12535084527054577, 'sn0p': -0.010434289919692447, 'sn2p': 1.2947612486120852, 'X_FoG_pp': 4.439415874059134} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.
#   warnings.warn('Error "{}" raised with parameters {} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.'.format(repr(error[0]), points))
# /global/u1/p/prakharb/desilike/desilike/profilers/base.py:254: UserWarning: Error "CosmologyComputationError()" raised with parameters {'h': 0.10774895467515279, 'omega_cdm': 0.09109475522942408, 'omega_b': 103.39129651987838, 'logA': 2.9943295349114503, 'b1p': 1.1519901034649693, 'b2p': -1.2457047706752062, 'bsp': 1.4421298732236614, 'alpha0p': 3.073010765966072, 'alpha2p': -0.20062833608715352, 'alpha4p': -0.14322568699536015, 'sn0p': 0.02607739924905268, 'sn2p': 1.2805056591947808, 'X_FoG_pp': 4.4526628250440385} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.
#   warnings.warn('Error "{}" raised with parameters {} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.'.format(repr(error[0]), points))
# /global/u1/p/prakharb/desilike/desilike/profilers/base.py:254: UserWarning: Error "CosmologyComputationError()" raised with parameters {'h': 0.5075349206309643, 'omega_cdm': 0.20102401931366426, 'omega_b': 5.190799472480373, 'logA': 2.990035069935325, 'b1p': 1.1198960153509063, 'b2p': -1.2470404908667783, 'bsp': 1.4424596591331698, 'alpha0p': 3.0785191149921287, 'alpha2p': -0.20220418362458983, 'alpha4p': -0.14411942908160086, 'sn0p': 0.027902983707489934, 'sn2p': 1.2797928797239155, 'X_FoG_pp': 4.453325172593284} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.
#   warnings.warn('Error "{}" raised with parameters {} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.'.format(repr(error[0]), points))
# /global/u1/p/prakharb/desilike/desilike/profilers/base.py:254: UserWarning: Error "CosmologyComputationError()" raised with parameters {'h': 0.6761640583285281, 'omega_cdm': 0.11754127608851737, 'omega_b': 0.2807746201104728, 'logA': 2.9898203508525922, 'b1p': 1.1182960352001492, 'b2p': -1.247107276876357, 'bsp': 1.4424761484286452, 'alpha0p': 3.078794532443432, 'alpha2p': -0.20228297600146167, 'alpha4p': -0.1441641161859129, 'sn0p': 0.0279942629304118, 'sn2p': 1.2797572407503723, 'X_FoG_pp': 4.453358289970747} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.
#   warnings.warn('Error "{}" raised with parameters {} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.'.format(repr(error[0]), points))
# /global/u1/p/prakharb/desilike/desilike/profilers/base.py:254: UserWarning: Error "CosmologyInputError('Parameter Omega_b should be positive, found -4.094129776462931')" raised with parameters {'h': 0.9952200371996434, 'omega_cdm': 0.9719256190818178, 'omega_b': -4.055083743259081, 'logA': 3.0890290762470265, 'b1p': 1.3620969772203355, 'b2p': -1.204377953599806, 'bsp': 1.4363262181251952, 'alpha0p': 2.958412491988215, 'alpha2p': -0.17238716092904166, 'alpha4p': -0.12720427030117293, 'sn0p': 0.000333336203207836, 'sn2p': 1.2962400282540278, 'X_FoG_pp': 4.438585192424871} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.
#   warnings.warn('Error "{}" raised with parameters {} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.'.format(repr(error[0]), points))
# /global/u1/p/prakharb/desilike/desilike/profilers/base.py:254: UserWarning: Error "CosmologyInputError('Parameter Omega_b should be positive, found -0.18179659412131752')" raised with parameters {'h': 0.999174728510286, 'omega_cdm': 0.9393138404028317, 'omega_b': -0.18149665484596417, 'logA': 2.9947758099345667, 'b1p': 1.1302133406004549, 'b2p': -1.244974149701716, 'bsp': 1.4421694763013893, 'alpha0p': 3.0727892000095034, 'alpha2p': -0.2007921244994297, 'alpha4p': -0.14331835803860304, 'sn0p': 0.026615780129741428, 'sn2p': 1.2805795983429928, 'X_FoG_pp': 4.452621290807964} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.
#   warnings.warn('Error "{}" raised with parameters {} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.'.format(repr(error[0]), points))
# /global/u1/p/prakharb/desilike/desilike/profilers/base.py:254: UserWarning: Error "CosmologyComputationError()" raised with parameters {'h': 0.14999671158537836, 'omega_cdm': 0.3130748356241135, 'omega_b': 11.151665449155598, 'logA': 2.899181126162478, 'b1p': 2.5023966199665515, 'b2p': -1.4944412775387648, 'bsp': 1.4189293152035924, 'alpha0p': 2.9816438042985545, 'alpha2p': -0.17283448342456556, 'alpha4p': -0.12746917959398163, 'sn0p': -0.12070757119922594, 'sn2p': 1.2519089347697845, 'X_FoG_pp': 4.433738145796906} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.
#   warnings.warn('Error "{}" raised with parameters {} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.'.format(repr(error[0]), points))
# /global/u1/p/prakharb/desilike/desilike/profilers/base.py:254: UserWarning: Error "CosmologyComputationError()" raised with parameters {'h': 0.956536391913126, 'omega_cdm': 0.678622603519398, 'omega_b': 0.5788260395972376, 'logA': 2.991733060834382, 'b1p': 1.1891336094455898, 'b2p': -1.2629795564131074, 'bsp': 1.4392941846891136, 'alpha0p': 3.066211052085439, 'alpha2p': -0.1980357404461424, 'alpha4p': -0.14169276778446804, 'sn0p': 0.018101140219076505, 'sn2p': 1.2763356113850783, 'X_FoG_pp': 4.449805236934637} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.
#   warnings.warn('Error "{}" raised with parameters {} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.'.format(repr(error[0]), points))
# /global/u1/p/prakharb/desilike/desilike/profilers/base.py:254: UserWarning: Error "CosmologyComputationError()" raised with parameters {'h': 0.42373259529408885, 'omega_cdm': 0.13340436803278807, 'omega_b': 0.05018406911931947, 'logA': 2.9963691457023462, 'b1p': 1.1204871450716378, 'b2p': -1.2514064703568246, 'bsp': 1.4403124281633897, 'alpha0p': 3.0704394144747833, 'alpha2p': -0.1992958032972212, 'alpha4p': -0.14240394719399235, 'sn0p': 0.025041575789991628, 'sn2p': 1.277556945215843, 'X_FoG_pp': 4.450608591491524} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.
#   warnings.warn('Error "{}" raised with parameters {} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.'.format(repr(error[0]), points))
# /global/u1/p/prakharb/desilike/desilike/profilers/base.py:254: UserWarning: Error "CosmologyComputationError()" raised with parameters {'h': 0.12811529492692175, 'omega_cdm': 0.8349756310299672, 'omega_b': 6.328938114109447, 'logA': 3.3388125412646046, 'b1p': 0.623420808440216, 'b2p': -0.3820757424895245, 'bsp': 1.4841708515507024, 'alpha0p': 2.789611312731439, 'alpha2p': -0.19419325551298477, 'alpha4p': -0.13663677073109481, 'sn0p': 2.307657442594717, 'sn2p': 1.3571808795825406, 'X_FoG_pp': 4.304422850534019} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.
#   warnings.warn('Error "{}" raised with parameters {} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.'.format(repr(error[0]), points))
# /global/u1/p/prakharb/desilike/desilike/profilers/base.py:254: UserWarning: Error "CosmologyComputationError()" raised with parameters {'h': 0.9918390976479405, 'omega_cdm': 0.1679966706108944, 'omega_b': 0.33771226245171365, 'logA': 3.0140645526901224, 'b1p': 0.6645683570832726, 'b2p': -1.2073617741947118, 'bsp': 1.4425562179955091, 'alpha0p': 3.056609246823276, 'alpha2p': -0.19910362520632488, 'alpha4p': -0.1421511169516382, 'sn0p': 0.13951909433430698, 'sn2p': 1.2815991564364224, 'X_FoG_pp': 4.4433394378430355} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.
#   warnings.warn('Error "{}" raised with parameters {} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.'.format(repr(error[0]), points))
# /global/u1/p/prakharb/desilike/desilike/profilers/base.py:254: UserWarning: Error "CosmologyComputationError()" raised with parameters {'h': 0.5262830579872391, 'omega_cdm': 0.23323516806821978, 'omega_b': 0.04324833463027207, 'logA': 3.0802264955111927, 'b1p': 0.17041576039774725, 'b2p': -1.164167545668375, 'bsp': 1.4214873996265784, 'alpha0p': 2.9095198186749744, 'alpha2p': -0.1659091621647873, 'alpha4p': -0.12189642570896168, 'sn0p': 0.6548450762414355, 'sn2p': 1.2600702389897376, 'X_FoG_pp': 4.373853927823485} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.
#   warnings.warn('Error "{}" raised with parameters {} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.'.format(repr(error[0]), points))
# /global/u1/p/prakharb/desilike/desilike/profilers/base.py:254: UserWarning: Error "CosmologyComputationError()" raised with parameters {'h': 0.9876014405825312, 'omega_cdm': 0.7625585455401817, 'omega_b': 28.35240250752552, 'logA': 2.794051889792309, 'b1p': 2.2408573935584593, 'b2p': -1.3042149197084651, 'bsp': 1.4058369922578102, 'alpha0p': 2.8725304910916174, 'alpha2p': -0.1707610819586805, 'alpha4p': -0.12448017932121382, 'sn0p': -0.020377367313252653, 'sn2p': 1.2384281863095106, 'X_FoG_pp': 4.3716128013256785} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.
#   warnings.warn('Error "{}" raised with parameters {} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.'.format(repr(error[0]), points))
# /global/u1/p/prakharb/desilike/desilike/profilers/base.py:254: UserWarning: Error "CosmologyComputationError()" raised with parameters {'h': 0.11409981845110562, 'omega_cdm': 0.9472302331547026, 'omega_b': 1.4388863252493107, 'logA': 2.988164181133232, 'b1p': 1.173119106012359, 'b2p': -1.2564855317510062, 'bsp': 1.4370729176429875, 'alpha0p': 3.0559214217602277, 'alpha2p': -0.19677669545983725, 'alpha4p': -0.1408467520158806, 'sn0p': 0.025873337850494955, 'sn2p': 1.2743584693894119, 'X_FoG_pp': 4.444719972230872} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.
#   warnings.warn('Error "{}" raised with parameters {} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.'.format(repr(error[0]), points))
# /global/u1/p/prakharb/desilike/desilike/profilers/base.py:254: UserWarning: Error "CosmologyComputationError()" raised with parameters {'h': 0.36143385247318116, 'omega_cdm': 0.014530582183541084, 'omega_b': 0.09321051613550015, 'logA': 2.9979437259050328, 'b1p': 1.1194604855608414, 'b2p': -1.2540990623531332, 'bsp': 1.4386347139122464, 'alpha0p': 3.0650909682936582, 'alpha2p': -0.1980774761348951, 'alpha4p': -0.14166508065061395, 'sn0p': 0.028185873108682338, 'sn2p': 1.276154983543407, 'X_FoG_pp': 4.448375330776131} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.
#   warnings.warn('Error "{}" raised with parameters {} is caught up with -inf loglikelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.'.format(repr(error[0]), points))
# +--------------------------------------+--------+---------+--------+
# | chi2 / (72 - 13) = 44.34 / 59 = 0.75 | varied | bestfit | error  |
# +--------------------------------------+--------+---------+--------+
# |                  h                   |  True  |  0.684  | 0.016  |
# |              omega_cdm               |  True  | 0.1133  | 0.0094 |
# |               omega_b                |  True  | 0.02239 | 3.7e-4 |
# |                 logA                 |  True  |  3.00   |  0.23  |
# |                 b1p                  |  True  |  1.117  | 0.051  |
# |                 b2p                  |  True  |  -1.25  |  0.59  |
# |                 bsp                  |  True  |   1.4   |  1.1   |
# |               alpha0p                |  True  |    3    |  10.   |
# |               alpha2p                |  True  |   0.    |   12   |
# |               alpha4p                |  True  |   0.    |   12   |
# |                 sn0p                 |  True  |  0.03   |  0.18  |
# |                 sn2p                 |  True  |   1.3   |  3.0   |
# |               X_FoG_pp               |  True  |   4.4   |  4.1   |
# +--------------------------------------+--------+---------+--------+
