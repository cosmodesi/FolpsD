# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import FOLPSD as FOLPS
import time

import sys, os
sys.path.append(os.path.abspath("../.."))
from cosmo_class import *

# %%
#omega_i = Omega_i h² 
omega_b = 0.0224;        #baryons
omega_cdm = 0.12;       #CDM
omega_ncdm = 0.00;    #massive neutrinos 
h = 0.67;                 #h = H0/100
z_pk = 0.01;                 #evaluation redshift
CosmoParams = [z_pk, omega_b, omega_cdm, omega_ncdm, h]

# %% [markdown]
# Linear power spectrum at redshift z_pk:

# %%
ps = run_class(h = h, ombh2 = omega_b, omch2 = omega_cdm, omnuh2 = omega_ncdm,
                 As = np.exp(3)/(10**10), ns = 0.9649, z = z_pk)

inputpkT = ps['k'], ps['pk']

# %% [markdown]
# Nuisance parameters for the linear power spectrum:
#
# Define a vector with the nuisances parameters, NuisanParams = [b1, b2, bs2, b3nl, alpha0, alpha2, alpha4, ctilde, alphashot0, alphashot2, PshotP]

# %%
#bias parameters
b1 = 1;                 
b2 = 2;                 
bs2 = -4/7*(b1 - 1);        
b3nl = 32/315*(b1 - 1);  

#EFT parameters
alpha0, alpha2, alpha4 = -10,-3,2#-10,-3,2    # PEFT(k) = (alpha0 + alpha2*mu^2+ alpha4*mu^4)  k^2 Plin(k)
ctilde = 0               #NLO counterterm
X_FoG = 1  # uses a Lorentzian Damping 1/(1+x^2), with x = X_FoG f sigma_v mu. 

#Stochatics parameters
# Noise is Pshot = PshotP * ( alphashot0 + alphashot2*(k*mu)**2 )
alphashot0 = 2;          
alphashot2 = 1;            
PshotP = 1/0.002    # =1/barn.  Poissonian shot noise
NuisanParams = [b1, b2, bs2, b3nl, alpha0, alpha2, alpha4, ctilde, alphashot0, alphashot2, PshotP,X_FoG]

# %% [markdown]
# #### Computation of $M$ matrices
# **They do not depend on the cosmology**, so they are **computed only one time**. That is, the first time the code is called, it computes the $M$ matrices and stores them for the rest of the runs, which can be of the order of thousands in parameter estimations.

# %%
matrices = FOLPS.Matrices()
# Out:
# N = 128 sampling points
# M matrices have been computed

# %%
Omfid = 0.31519186799  # for AP set > 0

# %%
# output k_ev
k_ev = np.logspace(np.log10(0.01), np.log10(0.3), num = 100) # array of k_ev in [h/Mpc]

# %%
# Compute 1loop integrals
nonlinear = FOLPS.NonLinear(inputpkT, CosmoParams, EdSkernels=False)

# %%
kh, pkl0, pkl2, pkl4 = FOLPS.RSDmultipoles(k_ev, NuisanParams, Omfid = Omfid, AP=True)

# %%
pkl0_c, pkl2_c = FOLPS.RSDmultipoles_marginalized_const(k_ev, NuisanParams, Omfid = Omfid, AP=True)

# %%
pkl0_i, pkl2_i = FOLPS.RSDmultipoles_marginalized_derivatives(k_ev, NuisanParams, Omfid = Omfid, AP=True)

# %%
pkl0_marg = pkl0_c + (pkl0_i[0] * alpha0 + pkl0_i[1] * alpha2 + pkl0_i[2] * alpha4 + pkl0_i[3] * alphashot0 + pkl0_i[4] * alphashot2)
pkl2_marg = pkl2_c + (pkl2_i[0] * alpha0 + pkl2_i[1] * alpha2 + pkl2_i[2] * alpha4 + pkl2_i[3] * alphashot0 + pkl2_i[4] * alphashot2)

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 5), sharex=True)

axs[0].set_xlabel(r'$k \, [h\, Mpc^{-1}]$', fontsize=14)
axs[0].set_ylabel(r'$ k  P_{\ell}(k)$', fontsize=14)

axs[0].plot(kh, kh*pkl0_marg, label=r'$\ell = 0$')
axs[0].plot(kh, kh*pkl2_marg, label=r'$\ell = 2$')

axs[0].plot(kh, kh*pkl0, lw=3, ls=':', color='k')
axs[0].plot(kh, kh*pkl2, lw=3, ls=':', color='k')

axs[0].set_xlim([0, 0.3])
axs[0].legend()

axs[1].set_xlabel(r'$k \, [h\, Mpc^{-1}]$', fontsize=14)
axs[1].set_ylabel(r'$\% \, \mathrm{diff}$', fontsize=14)

diff0 = 100 * (pkl0_marg - pkl0) / (pkl0)
diff2 = 100 * (pkl2_marg - pkl2) / (pkl2)

axs[1].plot(kh, diff0, label=r'$\ell = 0$')
axs[1].plot(kh, diff2, label=r'$\ell = 2$')

axs[1].set_xlim([0, 0.3])
axs[1].legend()

plt.tight_layout()
plt.show()

# %%
abs(1-pkl4/np.array([1333.8481965 , 1350.43248294, 1366.16329582, 1380.94536492,
       1394.67512268, 1407.28258657, 1418.69843976, 1428.84250157,
       1437.6155004 , 1444.92580631, 1450.69608093, 1454.85435988,
       1457.31829286, 1457.99417427, 1456.79873355, 1453.67401988,
       1448.58604167, 1441.47927143, 1432.29058598, 1420.96567613,
       1407.50654251, 1391.92923164, 1374.23579686, 1354.43079664,
       1332.56221701, 1308.74397258, 1283.07155198, 1255.63311267,
       1226.52595979, 1195.90849307, 1163.99209569, 1131.02103955,
       1097.23382937, 1062.86557025, 1028.1451847 ,  993.28173342,
        958.50742254,  924.13989113,  890.48174024,  857.79275423,
        826.26261988,  796.05515427,  767.31620626,  740.16714145,
        714.67137459,  690.84293548,  668.69626771,  648.1892866 ,
        629.20704804,  611.57807403,  595.1100769 ,  579.60268532,
        564.84811002,  550.63311857,  536.75481217,  523.0704608 ,
        509.47910756,  495.92809332,  482.45527722,  469.1658154 ,
        456.22310709,  443.82569933,  432.19219737,  421.54537995,
        412.05861557,  403.83323647,  396.86979247,  391.04704664,
        386.14732339,  381.88644688,  377.96392481,  374.09878841,
        370.08189558,  365.84155703,  361.42820086,  356.94045637,
        352.47807563,  348.13182455,  343.95933161,  339.87222952,
        335.56847397,  330.52634027,  324.24502805,  316.44842693,
        307.25985098,  296.99017508,  286.07996535,  274.92576506,
        263.53703346,  251.43454106,  238.10717731,  223.12901625,
        206.27685185,  187.54168024,  167.12109483,  145.33721128,
        122.39459962,   98.26250798,   72.67211817,   45.24132986])
   ) *100
# Out:
# array([0.09812497, 0.09312792, 0.08824551, 0.08347132, 0.07881132,
#        0.07426842, 0.06984123, 0.06552752, 0.06132497, 0.05723606,
#        0.05325976, 0.04939594, 0.04563896, 0.04198821, 0.0384425 ,
#        0.03500508, 0.03167224, 0.02843864, 0.02530057, 0.02225857,
#        0.01931862, 0.01647198, 0.0137173 , 0.01105   , 0.00847946,
#        0.0060057 , 0.00362105, 0.00132211, 0.00088894, 0.00300151,
#        0.00501224, 0.00691466, 0.00871235, 0.01040605, 0.0119904 ,
#        0.01347296, 0.01482952, 0.0160418 , 0.01711324, 0.01805162,
#        0.01885792, 0.01953408, 0.02008018, 0.02049617, 0.02080985,
#        0.02102099, 0.02113438, 0.02119158, 0.02121934, 0.02125469,
#        0.02131108, 0.02141363, 0.02158667, 0.02185072, 0.02221461,
#        0.02267221, 0.02320453, 0.02379604, 0.02439614, 0.02493569,
#        0.0253718 , 0.02563081, 0.02564624, 0.02538007, 0.02482145,
#        0.02402612, 0.02304025, 0.02199919, 0.02107491, 0.02038958,
#        0.02008543, 0.02025235, 0.02093831, 0.02208313, 0.02351569,
#        0.0250365 , 0.02635172, 0.02715785, 0.02732695, 0.0269315 ,
#        0.0262929 , 0.02583692, 0.02599657, 0.02701574, 0.02892509,
#        0.03152207, 0.03424003, 0.03631225, 0.03741919, 0.0374937 ,
#        0.03724257, 0.0376651 , 0.04006595, 0.04505549, 0.05255461,
#        0.06175579, 0.07228188, 0.08565019, 0.10856817, 0.16491864])
