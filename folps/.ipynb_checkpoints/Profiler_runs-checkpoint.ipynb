# %%
#!/usr/bin/env python
# coding: utf-8

# In[2]:

import sys
sys.path.insert(0, "/global/u1/p/prakharb/desilike-folps-jax-dev")
#sys.path.insert(0, "/global/u1/p/prakharb/desilike")
#sys.path.insert(0, "/global/u1/p/prakharb/cosmoprimo")
import desilike, inspect
print(inspect.getfile(desilike))
import os
os.environ["FOLPS_BACKEND"] = "jax" 
import folps, inspect
print(inspect.getfile(folps))
import desilike, inspect
print(inspect.getfile(desilike))

import matplotlib.pyplot as plt
import numpy as np
from desilike.theories.galaxy_clustering import LPTVelocileptorsTracerPowerSpectrumMultipoles, REPTVelocileptorsTracerPowerSpectrumMultipoles, DirectPowerSpectrumTemplate, ShapeFitPowerSpectrumTemplate, BAOPowerSpectrumTemplate, DampedBAOWigglesTracerPowerSpectrumMultipoles
from desilike.theories.galaxy_clustering.full_shape import FOLPSv2TracerPowerSpectrumMultipoles
from desilike.observables.galaxy_clustering import TracerPowerSpectrumMultipolesObservable, BAOCompressionObservable 
from desilike.observables import ObservableCovariance
from desilike.emulators import EmulatedCalculator, Emulator, TaylorEmulatorEngine
from desilike.likelihoods import ObservablesGaussianLikelihood, SumLikelihood
from desilike.theories import Cosmoprimo
from cosmoprimo.fiducial import DESI
from desilike import setup_logging
from desilike.parameter import Parameter, ParameterPrior


# In[2]:


######### Settings ######### 

#model: LCDM or HS
model = 'LCDM'

#Put 'True' to resume chain. 'False' to start from 0 steps
restart_chain = False
#Biasing and EFT parametrization: 'physical' or 'default' (non-physical)
prior_basis = 'physical' 

#max. wavenumber 
k_max = 0.301

#width for EFT and SN paramss
width_EFT = 12.5
width_SN0 = 2.0
width_SN2 = 5.0

#PT models: 'folps', 'pybird', 'lpt_velocileptors', 'rept_velocileptors'
pt_model = "folpsD" 

#samplers: 'cobaya', 'emcee'
sampler = 'cobaya'

# Set to 'True' to use emulators, or 'False' to disable them.
set_emulator = True

# R - 1 < GR_criteria 
GR_criteria = 0.05 


# In[3]:


# List of tracers
tracers = ['BGS', 'LRG1', 'LRG2', 'LRG3', 'ELG', 'QSO']  # Add more tracers as needed
all_tracers = {'BGS', 'LRG1', 'LRG2', 'LRG3', 'ELG', 'QSO'}

if set(tracers) == all_tracers:
    tracers_str = "all"
else:
    tracers_str = "-".join(tracers)

chain_name = f'/global/cfs/cdirs/desicollab/users/prakharb/folpsD_paper_chains/y1_chains/base/MCMC-fs+bao_klim_0-0.02-{k_max}_2-0.02-{k_max}-{tracers_str}-GCcomb_schoneberg2024-bbn_planck2018-ns10_{prior_basis}-prior_{model}_{pt_model}_Ano_tight_eft_Jeffreys'

if not set_emulator:
    chain_name += '_noemu'
#print(chain_name)


# Define file paths for each tracer (in the same order as the tracers list above)
all_tracer_params =  {
    'BGS': {
        'data_fn':'/global/cfs/cdirs/desi/survey/catalogs/Y1/LSS/iron/LSScats/v1.5/unblinded/desipipe/forfit_2pt/forfit_power+bao-recon_syst-rotation-hod-photo_klim_0-0.02-0.20_2-0.02-0.20_BGS_BRIGHT-21.5_GCcomb_z0.1-0.4.npy'
    },
    'LRG1': {
        'data_fn':'/global/cfs/cdirs/desi/survey/catalogs/Y1/LSS/iron/LSScats/v1.5/unblinded/desipipe/forfit_2pt/forfit_power+bao-recon_syst-rotation-hod-photo_klim_0-0.02-0.20_2-0.02-0.20_LRG_GCcomb_z0.4-0.6.npy'
    },
    'LRG2': {
        'data_fn':'/global/cfs/cdirs/desi/survey/catalogs/Y1/LSS/iron/LSScats/v1.5/unblinded/desipipe/forfit_2pt/forfit_power+bao-recon_syst-rotation-hod-photo_klim_0-0.02-0.20_2-0.02-0.20_LRG_GCcomb_z0.6-0.8.npy'
    },
    'LRG3': {
        'data_fn':'/global/cfs/cdirs/desi/survey/catalogs/Y1/LSS/iron/LSScats/v1.5/unblinded/desipipe/forfit_2pt/forfit_power+bao-recon_syst-rotation-hod-photo_klim_0-0.02-0.20_2-0.02-0.20_LRG_GCcomb_z0.8-1.1.npy'
    },
    'ELG': {
        'data_fn':'/global/cfs/cdirs/desi/survey/catalogs/Y1/LSS/iron/LSScats/v1.5/unblinded/desipipe/forfit_2pt/forfit_power+bao-recon_syst-rotation-hod-photo_klim_0-0.02-0.20_2-0.02-0.20_ELG_LOPnotqso_GCcomb_z1.1-1.6.npy'
    },
    'QSO': {
        'data_fn':'/global/cfs/cdirs/desi/survey/catalogs/Y1/LSS/iron/LSScats/v1.5/unblinded/desipipe/forfit_2pt/forfit_power+bao-recon_syst-rotation-hod-photo_klim_0-0.02-0.20_2-0.02-0.20_QSO_GCcomb_z0.8-2.1.npy'
    }
}


#Define tracer types and their corresponding redshifts
all_tracer_redshifts = {
                        'BGS': 0.295,
                        'LRG1': 0.510,
                        'LRG2': 0.706,
                        'LRG3': 0.930,
                        'ELG': 1.317,
                        'QSO': 1.491
                        }


tracer_params = {index: all_tracer_params[tracer] for index, tracer in enumerate(tracers)}
tracer_redshifts = {tracer: all_tracer_redshifts[tracer] for tracer in tracers}


# In[4]:


cosmo = Cosmoprimo(engine='class')
cosmo.init.params['H0'] = dict(derived=True)
cosmo.init.params['Omega_m'] = dict(derived=True)
cosmo.init.params['sigma8_m'] = dict(derived=True) 
# cosmo.init.params['fR0'] = dict(derived=False, latex ='f_{R0}')
#cosmo.init.params['theta_star'] = dict(derived=True)
fiducial = DESI() #fiducial cosmologyy


#Update cosmo priors
for param in ['n_s', 'h', 'omega_cdm', 'omega_b', 'logA', 'tau_reio']:
    cosmo.params[param].update(fixed = False)
    if param == 'tau_reio':
        cosmo.params[param].update(fixed = True)
    if param == 'n_s':
            #cosmo.params[param].update(fixed = True)
            cosmo.params[param].update(prior={'dist': 'norm', 'loc': 0.9649, 'scale': 0.042}) #ns10 planck
    if param == 'omega_b': 
            cosmo.params[param].update(prior={'dist': 'norm', 'loc': 0.02218, 'scale': 0.00055}) #bbn prior
    if param == 'h':
            cosmo.params[param].update(prior = {'dist':'uniform','limits': [0.2, 1.]})
    if param == 'omega_cdm':
        cosmo.params[param].update(prior = {'dist':'uniform','limits': [0.01, 0.99]})
    if param == 'm_ncdm':
        cosmo.params[param].update(prior = {'dist':'uniform','limits': [0.0, 5]})
    if param == 'logA':
        cosmo.params[param].update(prior = {'dist':'uniform','limits': [1.61, 3.91]})
    # if param == 'w0_fld':
    #     cosmo.params[param].update(prior = {'dist':'uniform','limits': [-3, 1]})
    #     # cosmo.params[param].update(fixed=True)
    # if param == 'wa_fld':
    #     cosmo.params[param].update(prior = {'dist':'uniform','limits': [-3, 2]})    
        # cosmo.params[param].update(fixed=True)    
    if param == 'theta_star':
        cosmo.params[param].update(prior={'dist': 'norm', 'loc': 0.0104110, 'scale': 0.0000031})
        cosmo.params[param].update(fixed = False)
        cosmo.params[param].update(ref={'limits': [0.010407899999999999, 0.0104141]})
    # if param == 'fR0':
    #     if model != 'HS':
    #         print('model LCDM')
    #         cosmo.params[param].update(fixed=True, value=0.0)
    #     else:
    #         print('model HS')
    #         cosmo.params[param].update(
    #         prior={'dist': 'uniform', 'limits': [0, 9e-5]},
    #         fixed=False,
    #         ref={'limits': [0, 9e-5]}
    #         )


# In[ ]:


#Initialize an empty list to store the theory objects
theories = []

#Iterate over each tracer and create the corresponding theory object
for tracer in tracers:
    if tracer in tracer_redshifts:
        z = tracer_redshifts[tracer]
    else:
        print(f'Invalid tracer: {tracer}. Skipping.') 
        continue

    #Create the template and theory objects
    template = DirectPowerSpectrumTemplate(fiducial = fiducial,cosmo = cosmo, z=z) #cosmology and fiducial cosmology defined above

    
    # Activate the corresponding model
    if pt_model == "lpt_velocileptors":
        print("LPTVelocileptorsTracerPowerSpectrumMultipoles activated")
        theory = LPTVelocileptorsTracerPowerSpectrumMultipoles(template=template, prior_basis=prior_basis)
    elif pt_model == "rept_velocileptors":
        print("REPTVelocileptorsTracerPowerSpectrumMultipoles activated")
        theory = REPTVelocileptorsTracerPowerSpectrumMultipoles(template=template, prior_basis=prior_basis)
    elif pt_model == "ept_velocileptors":
        print("EPTMomentsVelocileptorsTracerPowerSpectrumMultipoles activated")
        theory = EPTMomentsVelocileptorsTracerPowerSpectrumMultipoles(template=template, prior_basis=prior_basis)
    elif pt_model == "pybird":
        print("PyBirdPowerSpectrumMultipoles activated")
        theory = PyBirdPowerSpectrumMultipoles(template=template, prior_basis=prior_basis)
    else:
        print("No valid pt_model specified, defaulting to FOLPS model")
        theory = FOLPSv2TracerPowerSpectrumMultipoles(template=template, prior_basis=prior_basis,A_full=False, b3_coev=True) #Add the prior_basis='physical' argument to use physically motivated priors

    
    #Update bias and EFT priors
    #theory.params['bs'].update(fixed=True)
    if prior_basis == 'physical':
        theory.params['b1p'].update(prior = {'dist':'uniform','limits': [0, 3]})
        theory.params['b2p'].update(prior = {'dist':'norm','loc': 0, 'scale': 5 })
        theory.params['bsp'].update(prior = {'dist': 'norm', 'loc': 0, 'scale': 5})
        theory.params['alpha0p'].update(prior={'dist': 'norm', 'loc': 0, 'scale': width_EFT})
        theory.params['alpha2p'].update(prior={'dist': 'norm', 'loc': 0, 'scale': width_EFT})
        theory.params['alpha4p'].update(prior={'dist': 'norm', 'loc': 0, 'scale': width_EFT})
        theory.params['sn0p'].update(prior={'dist': 'norm', 'loc': 0, 'scale': width_SN0})
        theory.params['sn2p'].update(prior={'dist': 'norm', 'loc': 0, 'scale': width_SN2})
        # theory.params['X_FoG_pp'].update(fixed=True)
        theory.params['X_FoG_pp'].update(prior = {'dist':'uniform','limits': [0, 10]})
    else:
        theory.params['b1'].update(prior = {'dist':'uniform','limits': [1e-5, 10]})
        theory.params['b2'].update(prior = {'dist':'uniform','limits': [-50, 50]})
        theory.params['bs'].update(prior = {'dist': 'norm', 'loc': 0, 'scale': 20})
        theory.params['alpha0'].update(prior={'dist': 'norm', 'loc': 0, 'scale': width_EFT})
        theory.params['alpha2'].update(prior={'dist': 'norm', 'loc': 0, 'scale': width_EFT})
        theory.params['alpha4'].update(prior={'dist': 'norm', 'loc': 0, 'scale': width_EFT})
        theory.params['sn0'].update(prior={'dist': 'norm', 'loc': 0, 'scale': width_SN0})
        theory.params['sn2'].update(prior={'dist': 'norm', 'loc': 0, 'scale': width_SN2})
        # theory.params['X_FoG_p'].update(fixed=True)
        theory.params['X_FoG_p'].update(prior = {'dist':'uniform','limits': [0, 10]})
    
    #Append the theory object to the list
    theories.append(theory)


# In[ ]:


#Define a function to create an observable
def create_observable(data_fn, theory, tracer_index):
    #Load and process covariance
    covariance = ObservableCovariance.load(data_fn)
    #covariance = covariance.select(xlim=(0.02, k_max), projs=[0, 2])
    
    #power spectrum
    data = covariance.observables('power')

    indices = np.where((data.flatx > 0.02) & (data.flatx < k_max))[0]  #new-line
    
    #Create and return the observable: following  https://desi.lbl.gov/trac/wiki/keyprojects/y1kp3/clusteringproducts#a101:Iwanttowritemychi2
    return TracerPowerSpectrumMultipolesObservable(
        data=data,
        covariance=covariance.select(observables=data, select_observables=True),
        klim={ell: [0.02, k_max, 0.005] for ell in [0, 2]},
        theory=theories[tracer_index],
        kin=data.attrs['kin'],
        wmatrix=data.attrs['wmatrix'][indices, :],
        ellsin=data.attrs['ellsin'],
        wshotnoise=data.attrs['wshotnoise'][indices]
    )

#Create observables for each tracer
observables = [create_observable(params['data_fn'], theories, i) 
                for i, params in tracer_params.items()]


# In[ ]:


if set_emulator:
    #Create an emulated theory for each tracer
    for i in range(len(theories)):
        emulator_filename = f'/global/cfs/cdirs/desicollab/users/prakharb/folpsD_paper_chains/Emulator_y1/emu_-{tracers_str}_{str(tracers[i])}.npy'
        
        if os.path.exists(emulator_filename):
            print(f"FS emulator {i} already exists, loading it now")
            emulator = EmulatedCalculator.load(emulator_filename)  
            theories[i].init.update(pt=emulator)
        else:
            print(f" Computing FS emulator {i}")
            theories[i] = observables[i].wmatrix.theory
            emulator = Emulator(theories[i].pt, engine=TaylorEmulatorEngine(method='finite', order=4))
            emulator.set_samples()
            emulator.fit()
            emulator.save(emulator_filename)
            theories[i].init.update(pt=emulator.to_calculator())
print('FS theories have been emulated successfully' if set_emulator else 'EMULATOR NOT ACTIVATED for FS; proceeding without emulation')


# In[ ]:


#Analytic marginalization over eft and nuisance parameters
for i in range(len(theories)): 
    if prior_basis == 'physical':
        params_list = ['alpha0p', 'alpha2p', 'alpha4p', 'sn0p', 'sn2p']
    else:
        params_list = ['alpha0', 'alpha2', 'alpha4', 'sn0', 'sn2']

    for param in params_list:    
        # theories[i].params[param].update(derived = '.marg')
        theories[i].params[param].update(derived = '.best') #Jeffrey   
        
#Rename the eft and nuisance parameters to get a parameter for each tracer (i.e. QSO_alpha0, QSO_alpha2, BGS_alpha0,...)        
for i in range(len(theories)):    
    for param in theories[i].init.params:
        # Update latex just to have better labels
        param.update(namespace='{}'.format(tracers[i]))   
        
# for i in range(len(theories)): 
#     params_list = ['w0_fld','wa_fld']
#     for param in params_list:    
#         theories[i].pt.params[param].update(fixed=True) 

# In[ ]:


flatdatas=[]

def create_bao_observable(data_fn, tracer_index):
    # Create and return the observable
    forfit = ObservableCovariance.load(data_fn)
    covariance, data = forfit.view(observables='bao-recon'), forfit.observables(observables='bao-recon')   
    observable = BAOCompressionObservable(data=data.view(), covariance=covariance, cosmo=cosmo, quantities=data.projs, fiducial=fiducial, z=data.attrs['zeff'])
    flatdata = observable.flatdata
    flatdatas.append(flatdata)
    #observable.init.update(cosmo=cosmo)
    return observable
    
bao_observables = [create_bao_observable(params['data_fn'], i) 
                for i, params in tracer_params.items()]


# In[ ]:


if set_emulator:
    for i in range(len(bao_observables)):
        emulator_filename = f'/global/cfs/cdirs/desicollab/users/prakharb/folpsD_paper_chains/Emulator_y1_bao/emu-bao_klim_0-0.02-{k_max}_2-0.02-{k_max}-{tracers_str}-GCcomb_schoneberg2024-bbn_planck2018-ns10_{prior_basis}-prior_{model}_{pt_model}_{str(tracers[i])}.npy'
        
        if os.path.exists(emulator_filename):
            print(f"BAO emulator {i} already exists, loading it now")
            emulator = EmulatedCalculator.load(emulator_filename)  
            bao_observables[i] = emulator
        else:
            print(f" Computing BAO emulator {i}")
            emulator = Emulator(bao_observables[i], engine=TaylorEmulatorEngine(method='finite', order=4))
            emulator.set_samples()
            emulator.fit()
            emulator.save(emulator_filename)
            bao_observables[i] = emulator.to_calculator()   
        # for p in ['w0_fld', 'wa_fld']:
        #     bao_observables[i].params[p].update(fixed=True, value={'w0_fld': -1.0, 'wa_fld': 0.0}[p])
print('BAO has been emulated successfully' if set_emulator else 'EMULATOR NOT ACTIVATED for BAO; proceeding without emulation')


# In[ ]:

setup_logging()
Likelihoods = []
for i in range(len(observables)):
    forfit = ObservableCovariance.load(tracer_params[i]['data_fn'])
    
    data = forfit.observables('power')
    
    indices = np.where((data.flatx > 0.02) & (data.flatx < k_max))[0]
    size_pk = 72
    size_baoxbao = forfit.view().shape[0] - size_pk
    new_indices = indices.tolist() + list(range(size_pk, size_pk + size_baoxbao))
    
    covariance = forfit.view()
    cov = covariance[np.ix_(new_indices, new_indices)]

    #print(size_pk)
    #print(cov.shape)
    likely = ObservablesGaussianLikelihood(observables = [observables[i],bao_observables[i]], covariance = cov)
    likely()
    Likelihoods.append(likely)

likelihood = SumLikelihood(Likelihoods)
print("likelihood: ",likelihood())
print("Test Successful!")
# Out:
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/__init__.py
# ⚠️ No GPU found. Using JAX with CPU.
#    If you have an NVIDIA GPU, install: pip install -U 'jax[cuda12]'
# /global/u1/p/prakharb/FOLPS_JAX/folps/folps.py
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/__init__.py
# No valid pt_model specified, defaulting to FOLPS model
# No valid pt_model specified, defaulting to FOLPS model
# No valid pt_model specified, defaulting to FOLPS model
# No valid pt_model specified, defaulting to FOLPS model
# No valid pt_model specified, defaulting to FOLPS model
# No valid pt_model specified, defaulting to FOLPS model
# FS emulator 0 already exists, loading it now
# FS emulator 1 already exists, loading it now
# FS emulator 2 already exists, loading it now
# FS emulator 3 already exists, loading it now
# FS emulator 4 already exists, loading it now
# FS emulator 5 already exists, loading it now
# FS theories have been emulated successfully
# BAO emulator 0 already exists, loading it now
# BAO emulator 1 already exists, loading it now
# BAO emulator 2 already exists, loading it now
# BAO emulator 3 already exists, loading it now
# BAO emulator 4 already exists, loading it now
# BAO emulator 5 already exists, loading it now
# BAO has been emulated successfully
# [000000.00] [0/1] 10-26 13:49  ObservableCovariance      INFO     Loading /global/cfs/cdirs/desi/survey/catalogs/Y1/LSS/iron/LSScats/v1.5/unblinded/desipipe/forfit_2pt/forfit_power+bao-recon_syst-rotation-hod-photo_klim_0-0.02-0.20_2-0.02-0.20_BGS_BRIGHT-21.5_GCcomb_z0.1-0.4.npy.
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter h of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c3d3580> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c1d40a0>: {'prior': (uniform[0.5, 0.9]({}), uniform[0.2, 1.0]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter omega_cdm of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c3d3580> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c1d40a0>: {'prior': (uniform[0.05, 0.2]({}), uniform[0.01, 0.99]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter logA of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c3d3580> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c1d40a0>: {'prior': (uniform[2.0, 4.0]({}), uniform[1.61, 3.91]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter H0 of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c3d3580> is already derived in <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c1d40a0>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter Omega_m of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c3d3580> is already derived in <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c1d40a0>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter sigma8_m of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c3d3580> is already derived in <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c1d40a0>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter h of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c3d3580> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c1d40a0>: {'prior': (uniform[0.5, 0.9]({}), uniform[0.2, 1.0]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter omega_cdm of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c3d3580> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c1d40a0>: {'prior': (uniform[0.05, 0.2]({}), uniform[0.01, 0.99]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter logA of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c3d3580> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c1d40a0>: {'prior': (uniform[2.0, 4.0]({}), uniform[1.61, 3.91]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# [000011.33] [0/1] 10-26 13:49  ObservableCovariance      INFO     Loading /global/cfs/cdirs/desi/survey/catalogs/Y1/LSS/iron/LSScats/v1.5/unblinded/desipipe/forfit_2pt/forfit_power+bao-recon_syst-rotation-hod-photo_klim_0-0.02-0.20_2-0.02-0.20_LRG_GCcomb_z0.4-0.6.npy.
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter h of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c286530> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c1fa0e0>: {'prior': (uniform[0.5, 0.9]({}), uniform[0.2, 1.0]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter omega_cdm of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c286530> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c1fa0e0>: {'prior': (uniform[0.05, 0.2]({}), uniform[0.01, 0.99]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter logA of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c286530> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c1fa0e0>: {'prior': (uniform[2.0, 4.0]({}), uniform[1.61, 3.91]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter H0 of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c286530> is already derived in <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c1fa0e0>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter Omega_m of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c286530> is already derived in <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c1fa0e0>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter sigma8_m of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c286530> is already derived in <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c1fa0e0>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter h of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c286530> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c1fa0e0>: {'prior': (uniform[0.5, 0.9]({}), uniform[0.2, 1.0]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter omega_cdm of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c286530> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c1fa0e0>: {'prior': (uniform[0.05, 0.2]({}), uniform[0.01, 0.99]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter logA of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c286530> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c1fa0e0>: {'prior': (uniform[2.0, 4.0]({}), uniform[1.61, 3.91]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# [000020.93] [0/1] 10-26 13:49  ObservableCovariance      INFO     Loading /global/cfs/cdirs/desi/survey/catalogs/Y1/LSS/iron/LSScats/v1.5/unblinded/desipipe/forfit_2pt/forfit_power+bao-recon_syst-rotation-hod-photo_klim_0-0.02-0.20_2-0.02-0.20_LRG_GCcomb_z0.6-0.8.npy.
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter h of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2ccdf0> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c01aa70>: {'prior': (uniform[0.5, 0.9]({}), uniform[0.2, 1.0]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter omega_cdm of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2ccdf0> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c01aa70>: {'prior': (uniform[0.05, 0.2]({}), uniform[0.01, 0.99]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter logA of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2ccdf0> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c01aa70>: {'prior': (uniform[2.0, 4.0]({}), uniform[1.61, 3.91]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter H0 of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2ccdf0> is already derived in <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c01aa70>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter Omega_m of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2ccdf0> is already derived in <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c01aa70>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter sigma8_m of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2ccdf0> is already derived in <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c01aa70>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter h of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2ccdf0> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c01aa70>: {'prior': (uniform[0.5, 0.9]({}), uniform[0.2, 1.0]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter omega_cdm of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2ccdf0> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c01aa70>: {'prior': (uniform[0.05, 0.2]({}), uniform[0.01, 0.99]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter logA of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2ccdf0> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c01aa70>: {'prior': (uniform[2.0, 4.0]({}), uniform[1.61, 3.91]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# [000030.64] [0/1] 10-26 13:49  ObservableCovariance      INFO     Loading /global/cfs/cdirs/desi/survey/catalogs/Y1/LSS/iron/LSScats/v1.5/unblinded/desipipe/forfit_2pt/forfit_power+bao-recon_syst-rotation-hod-photo_klim_0-0.02-0.20_2-0.02-0.20_LRG_GCcomb_z0.8-1.1.npy.
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter h of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2eb670> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c03f400>: {'prior': (uniform[0.5, 0.9]({}), uniform[0.2, 1.0]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter omega_cdm of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2eb670> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c03f400>: {'prior': (uniform[0.05, 0.2]({}), uniform[0.01, 0.99]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter logA of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2eb670> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c03f400>: {'prior': (uniform[2.0, 4.0]({}), uniform[1.61, 3.91]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter H0 of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2eb670> is already derived in <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c03f400>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter Omega_m of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2eb670> is already derived in <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c03f400>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter sigma8_m of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2eb670> is already derived in <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c03f400>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter h of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2eb670> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c03f400>: {'prior': (uniform[0.5, 0.9]({}), uniform[0.2, 1.0]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter omega_cdm of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2eb670> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c03f400>: {'prior': (uniform[0.05, 0.2]({}), uniform[0.01, 0.99]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter logA of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2eb670> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c03f400>: {'prior': (uniform[2.0, 4.0]({}), uniform[1.61, 3.91]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# [000040.38] [0/1] 10-26 13:50  ObservableCovariance      INFO     Loading /global/cfs/cdirs/desi/survey/catalogs/Y1/LSS/iron/LSScats/v1.5/unblinded/desipipe/forfit_2pt/forfit_power+bao-recon_syst-rotation-hod-photo_klim_0-0.02-0.20_2-0.02-0.20_ELG_LOPnotqso_GCcomb_z1.1-1.6.npy.
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter h of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c12df00> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c067d90>: {'prior': (uniform[0.5, 0.9]({}), uniform[0.2, 1.0]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter omega_cdm of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c12df00> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c067d90>: {'prior': (uniform[0.05, 0.2]({}), uniform[0.01, 0.99]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter logA of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c12df00> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c067d90>: {'prior': (uniform[2.0, 4.0]({}), uniform[1.61, 3.91]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter H0 of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c12df00> is already derived in <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c067d90>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter Omega_m of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c12df00> is already derived in <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c067d90>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter sigma8_m of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c12df00> is already derived in <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c067d90>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter h of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c12df00> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c067d90>: {'prior': (uniform[0.5, 0.9]({}), uniform[0.2, 1.0]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter omega_cdm of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c12df00> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c067d90>: {'prior': (uniform[0.05, 0.2]({}), uniform[0.01, 0.99]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter logA of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c12df00> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c067d90>: {'prior': (uniform[2.0, 4.0]({}), uniform[1.61, 3.91]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# [000050.56] [0/1] 10-26 13:50  ObservableCovariance      INFO     Loading /global/cfs/cdirs/desi/survey/catalogs/Y1/LSS/iron/LSScats/v1.5/unblinded/desipipe/forfit_2pt/forfit_power+bao-recon_syst-rotation-hod-photo_klim_0-0.02-0.20_2-0.02-0.20_QSO_GCcomb_z0.8-2.1.npy.
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter h of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c16c7c0> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c09c790>: {'prior': (uniform[0.5, 0.9]({}), uniform[0.2, 1.0]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter omega_cdm of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c16c7c0> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c09c790>: {'prior': (uniform[0.05, 0.2]({}), uniform[0.01, 0.99]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter logA of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c16c7c0> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c09c790>: {'prior': (uniform[2.0, 4.0]({}), uniform[1.61, 3.91]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter H0 of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c16c7c0> is already derived in <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c09c790>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter Omega_m of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c16c7c0> is already derived in <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c09c790>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter sigma8_m of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c16c7c0> is already derived in <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c09c790>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter h of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c16c7c0> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c09c790>: {'prior': (uniform[0.5, 0.9]({}), uniform[0.2, 1.0]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter omega_cdm of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c16c7c0> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c09c790>: {'prior': (uniform[0.05, 0.2]({}), uniform[0.01, 0.99]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter logA of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c16c7c0> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c09c790>: {'prior': (uniform[2.0, 4.0]({}), uniform[1.61, 3.91]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter h of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c16c7c0> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c09c790>: {'prior': (uniform[0.5, 0.9]({}), uniform[0.2, 1.0]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter omega_cdm of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c16c7c0> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c09c790>: {'prior': (uniform[0.05, 0.2]({}), uniform[0.01, 0.99]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter logA of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c16c7c0> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c09c790>: {'prior': (uniform[2.0, 4.0]({}), uniform[1.61, 3.91]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter H0 of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c16c7c0> is already derived in <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c09c790>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter Omega_m of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c16c7c0> is already derived in <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c09c790>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter sigma8_m of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c16c7c0> is already derived in <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c09c790>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter h of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c067d90> is different from that of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c16c7c0>: {'prior': (uniform[0.2, 1.0]({}), uniform[0.5, 0.9]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter omega_cdm of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c067d90> is different from that of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c16c7c0>: {'prior': (uniform[0.01, 0.99]({}), uniform[0.05, 0.2]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter logA of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c067d90> is different from that of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c16c7c0>: {'prior': (uniform[1.61, 3.91]({}), uniform[2.0, 4.0]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter H0 of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c067d90> is already derived in <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c16c7c0>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter Omega_m of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c067d90> is already derived in <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c16c7c0>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter sigma8_m of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c067d90> is already derived in <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c16c7c0>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter h of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c12df00> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c067d90>: {'prior': (uniform[0.5, 0.9]({}), uniform[0.2, 1.0]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter omega_cdm of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c12df00> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c067d90>: {'prior': (uniform[0.05, 0.2]({}), uniform[0.01, 0.99]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter logA of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c12df00> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c067d90>: {'prior': (uniform[2.0, 4.0]({}), uniform[1.61, 3.91]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter H0 of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c12df00> is already derived in <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c067d90>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter Omega_m of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c12df00> is already derived in <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c067d90>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter sigma8_m of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c12df00> is already derived in <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c067d90>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter loglikelihood of <desilike.likelihoods.base.ObservablesGaussianLikelihood object at 0x7f300c0e4e50> is already derived in <desilike.likelihoods.base.ObservablesGaussianLikelihood object at 0x7f2fec090340>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter logprior of <desilike.likelihoods.base.ObservablesGaussianLikelihood object at 0x7f300c0e4e50> is already derived in <desilike.likelihoods.base.ObservablesGaussianLikelihood object at 0x7f2fec090340>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter h of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c03f400> is different from that of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c12df00>: {'prior': (uniform[0.2, 1.0]({}), uniform[0.5, 0.9]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter omega_cdm of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c03f400> is different from that of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c12df00>: {'prior': (uniform[0.01, 0.99]({}), uniform[0.05, 0.2]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter logA of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c03f400> is different from that of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c12df00>: {'prior': (uniform[1.61, 3.91]({}), uniform[2.0, 4.0]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter H0 of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c03f400> is already derived in <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c12df00>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter Omega_m of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c03f400> is already derived in <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c12df00>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter sigma8_m of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c03f400> is already derived in <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c12df00>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter h of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2eb670> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c03f400>: {'prior': (uniform[0.5, 0.9]({}), uniform[0.2, 1.0]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter omega_cdm of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2eb670> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c03f400>: {'prior': (uniform[0.05, 0.2]({}), uniform[0.01, 0.99]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter logA of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2eb670> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c03f400>: {'prior': (uniform[2.0, 4.0]({}), uniform[1.61, 3.91]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter H0 of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2eb670> is already derived in <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c03f400>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter Omega_m of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2eb670> is already derived in <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c03f400>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter sigma8_m of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2eb670> is already derived in <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c03f400>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter loglikelihood of <desilike.likelihoods.base.ObservablesGaussianLikelihood object at 0x7f2fec7258a0> is already derived in <desilike.likelihoods.base.ObservablesGaussianLikelihood object at 0x7f300c0e4e50>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter logprior of <desilike.likelihoods.base.ObservablesGaussianLikelihood object at 0x7f2fec7258a0> is already derived in <desilike.likelihoods.base.ObservablesGaussianLikelihood object at 0x7f300c0e4e50>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter h of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c01aa70> is different from that of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2eb670>: {'prior': (uniform[0.2, 1.0]({}), uniform[0.5, 0.9]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter omega_cdm of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c01aa70> is different from that of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2eb670>: {'prior': (uniform[0.01, 0.99]({}), uniform[0.05, 0.2]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter logA of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c01aa70> is different from that of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2eb670>: {'prior': (uniform[1.61, 3.91]({}), uniform[2.0, 4.0]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter H0 of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c01aa70> is already derived in <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2eb670>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter Omega_m of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c01aa70> is already derived in <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2eb670>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter sigma8_m of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c01aa70> is already derived in <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2eb670>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter h of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2ccdf0> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c01aa70>: {'prior': (uniform[0.5, 0.9]({}), uniform[0.2, 1.0]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter omega_cdm of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2ccdf0> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c01aa70>: {'prior': (uniform[0.05, 0.2]({}), uniform[0.01, 0.99]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter logA of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2ccdf0> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c01aa70>: {'prior': (uniform[2.0, 4.0]({}), uniform[1.61, 3.91]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter H0 of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2ccdf0> is already derived in <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c01aa70>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter Omega_m of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2ccdf0> is already derived in <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c01aa70>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter sigma8_m of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2ccdf0> is already derived in <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c01aa70>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter loglikelihood of <desilike.likelihoods.base.ObservablesGaussianLikelihood object at 0x7f300c08ce80> is already derived in <desilike.likelihoods.base.ObservablesGaussianLikelihood object at 0x7f2fec7258a0>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter logprior of <desilike.likelihoods.base.ObservablesGaussianLikelihood object at 0x7f300c08ce80> is already derived in <desilike.likelihoods.base.ObservablesGaussianLikelihood object at 0x7f2fec7258a0>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter h of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c1fa0e0> is different from that of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2ccdf0>: {'prior': (uniform[0.2, 1.0]({}), uniform[0.5, 0.9]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter omega_cdm of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c1fa0e0> is different from that of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2ccdf0>: {'prior': (uniform[0.01, 0.99]({}), uniform[0.05, 0.2]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter logA of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c1fa0e0> is different from that of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2ccdf0>: {'prior': (uniform[1.61, 3.91]({}), uniform[2.0, 4.0]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter H0 of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c1fa0e0> is already derived in <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2ccdf0>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter Omega_m of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c1fa0e0> is already derived in <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2ccdf0>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter sigma8_m of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c1fa0e0> is already derived in <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2ccdf0>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# ...
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter Omega_m of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c286530> is already derived in <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c1fa0e0>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter sigma8_m of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c286530> is already derived in <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c1fa0e0>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter loglikelihood of <desilike.likelihoods.base.ObservablesGaussianLikelihood object at 0x7f300c6a4160> is already derived in <desilike.likelihoods.base.ObservablesGaussianLikelihood object at 0x7f300c08ce80>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter logprior of <desilike.likelihoods.base.ObservablesGaussianLikelihood object at 0x7f300c6a4160> is already derived in <desilike.likelihoods.base.ObservablesGaussianLikelihood object at 0x7f300c08ce80>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter h of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c1d40a0> is different from that of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c286530>: {'prior': (uniform[0.2, 1.0]({}), uniform[0.5, 0.9]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter omega_cdm of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c1d40a0> is different from that of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c286530>: {'prior': (uniform[0.01, 0.99]({}), uniform[0.05, 0.2]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter logA of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c1d40a0> is different from that of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c286530>: {'prior': (uniform[1.61, 3.91]({}), uniform[2.0, 4.0]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter H0 of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c1d40a0> is already derived in <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c286530>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter Omega_m of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c1d40a0> is already derived in <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c286530>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter sigma8_m of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c1d40a0> is already derived in <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c286530>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter h of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c3d3580> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c1d40a0>: {'prior': (uniform[0.5, 0.9]({}), uniform[0.2, 1.0]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter omega_cdm of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c3d3580> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c1d40a0>: {'prior': (uniform[0.05, 0.2]({}), uniform[0.01, 0.99]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter logA of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c3d3580> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c1d40a0>: {'prior': (uniform[2.0, 4.0]({}), uniform[1.61, 3.91]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter H0 of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c3d3580> is already derived in <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c1d40a0>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter Omega_m of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c3d3580> is already derived in <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c1d40a0>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter sigma8_m of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c3d3580> is already derived in <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c1d40a0>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter loglikelihood of <desilike.likelihoods.base.ObservablesGaussianLikelihood object at 0x7f304c0b0700> is already derived in <desilike.likelihoods.base.ObservablesGaussianLikelihood object at 0x7f300c6a4160>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter logprior of <desilike.likelihoods.base.ObservablesGaussianLikelihood object at 0x7f304c0b0700> is already derived in <desilike.likelihoods.base.ObservablesGaussianLikelihood object at 0x7f300c6a4160>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter loglikelihood of <desilike.likelihoods.base.SumLikelihood object at 0x7f2fcc5fcc70> is already derived in <desilike.likelihoods.base.ObservablesGaussianLikelihood object at 0x7f304c0b0700>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:447: UserWarning: Derived parameter logprior of <desilike.likelihoods.base.SumLikelihood object at 0x7f2fcc5fcc70> is already derived in <desilike.likelihoods.base.ObservablesGaussianLikelihood object at 0x7f304c0b0700>.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter h of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c16c7c0> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c09c790>: {'prior': (uniform[0.5, 0.9]({}), uniform[0.2, 1.0]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter omega_cdm of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c16c7c0> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c09c790>: {'prior': (uniform[0.05, 0.2]({}), uniform[0.01, 0.99]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter logA of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c16c7c0> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c09c790>: {'prior': (uniform[2.0, 4.0]({}), uniform[1.61, 3.91]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter h of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c12df00> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c067d90>: {'prior': (uniform[0.5, 0.9]({}), uniform[0.2, 1.0]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter omega_cdm of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c12df00> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c067d90>: {'prior': (uniform[0.05, 0.2]({}), uniform[0.01, 0.99]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter logA of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c12df00> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c067d90>: {'prior': (uniform[2.0, 4.0]({}), uniform[1.61, 3.91]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter h of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2eb670> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c03f400>: {'prior': (uniform[0.5, 0.9]({}), uniform[0.2, 1.0]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter omega_cdm of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2eb670> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c03f400>: {'prior': (uniform[0.05, 0.2]({}), uniform[0.01, 0.99]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter logA of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2eb670> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c03f400>: {'prior': (uniform[2.0, 4.0]({}), uniform[1.61, 3.91]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter h of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2ccdf0> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c01aa70>: {'prior': (uniform[0.5, 0.9]({}), uniform[0.2, 1.0]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter omega_cdm of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2ccdf0> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c01aa70>: {'prior': (uniform[0.05, 0.2]({}), uniform[0.01, 0.99]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter logA of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c2ccdf0> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c01aa70>: {'prior': (uniform[2.0, 4.0]({}), uniform[1.61, 3.91]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter h of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c286530> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c1fa0e0>: {'prior': (uniform[0.5, 0.9]({}), uniform[0.2, 1.0]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter omega_cdm of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c286530> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c1fa0e0>: {'prior': (uniform[0.05, 0.2]({}), uniform[0.01, 0.99]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter logA of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c286530> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c1fa0e0>: {'prior': (uniform[2.0, 4.0]({}), uniform[1.61, 3.91]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter h of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c3d3580> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c1d40a0>: {'prior': (uniform[0.5, 0.9]({}), uniform[0.2, 1.0]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter omega_cdm of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c3d3580> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c1d40a0>: {'prior': (uniform[0.05, 0.2]({}), uniform[0.01, 0.99]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter logA of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7f304c3d3580> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7f304c1d40a0>: {'prior': (uniform[2.0, 4.0]({}), uniform[1.61, 3.91]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# likelihood:  -689.0270918979799
# Test Successful!

# %%
# Run the sampler and save the chain
from desilike.samplers import EmceeSampler, MCMCSampler

from pathlib import Path
def load_chain(fi, burnin=0.3):
    from desilike.samples import Chain
    # chains = [Chain.load(ff).remove_burnin(burnin) for ff in fi]
    chains = [Chain.load(fi).remove_burnin(burnin)]
    chain = chains[0].concatenate(chains)
    print(f'chain: {chain}')
    return chain

cov_chain_path = Path('/global/cfs/cdirs/desicollab/users/prakharb/folpsD_paper_chains/y1_chains/EFT/folps_chains/MCMC-fs+bao_klim_0-0.02-0.2_2-0.02-0.2-all-GCcomb_schoneberg2024-bbn_planck2018-ns10_physical-prior_LCDM_folps.npy')
cov_chain = load_chain(cov_chain_path,burnin=0.3)
if sampler == 'cobaya':
    if restart_chain is False:
        sampler = MCMCSampler(sum(Likelihoods), save_fn = chain_name)
        sampler.run(check={'max_eigen_gr': GR_criteria})
    else:
        sampler = MCMCSampler(sum(Likelihoods) ,save_fn = chain_name,
                              chains=f'{chain_name}.npy')
        sampler.run(check={'max_eigen_gr': GR_criteria})
    
else:
    if restart_chain is False:
        sampler = EmceeSampler(sum(Likelihoods) ,save_fn = chain_name)
        sampler.run(check={'max_eigen_gr': GR_criteria})
    else:
        sampler = EmceeSampler(sum(Likelihoods) ,save_fn = chain_name, 
                               chains=f'{chain_name}.npy')
        sampler.run(check={'max_eigen_gr': GR_criteria})

# %%
from desilike.profilers import MinuitProfiler
chain_name= f'chains/test_profiler'
profiler = MinuitProfiler(likelihood, seed=42,save_fn=chain_name)
# profiler.config.update({'derived': True})
profiles = profiler.maximize(niterations=5,)
print(profiles.to_stats(tablefmt='pretty'))
# Out:
# [000481.86] [0/1] 10-26 13:44  MinuitProfiler            INFO     Varied parameters: ['h', 'omega_cdm', 'omega_b', 'logA', 'n_s', 'QSO.b1p', 'QSO.b2p', 'QSO.bsp', 'QSO.X_FoG_pp', 'ELG.b1p', 'ELG.b2p', 'ELG.bsp', 'ELG.X_FoG_pp', 'LRG3.b1p', 'LRG3.b2p', 'LRG3.bsp', 'LRG3.X_FoG_pp', 'LRG2.b1p', 'LRG2.b2p', 'LRG2.bsp', 'LRG2.X_FoG_pp', 'LRG1.b1p', 'LRG1.b2p', 'LRG1.bsp', 'LRG1.X_FoG_pp', 'BGS.b1p', 'BGS.b2p', 'BGS.bsp', 'BGS.X_FoG_pp'].
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter h of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7fe56c6649d0> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7fe56c5949d0>: {'prior': (uniform[0.5, 0.9]({}), uniform[0.2, 1.0]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter omega_cdm of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7fe56c6649d0> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7fe56c5949d0>: {'prior': (uniform[0.05, 0.2]({}), uniform[0.01, 0.99]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter logA of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7fe56c6649d0> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7fe56c5949d0>: {'prior': (uniform[2.0, 4.0]({}), uniform[1.61, 3.91]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter h of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7fe56c626110> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7fe56c563fd0>: {'prior': (uniform[0.5, 0.9]({}), uniform[0.2, 1.0]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter omega_cdm of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7fe56c626110> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7fe56c563fd0>: {'prior': (uniform[0.05, 0.2]({}), uniform[0.01, 0.99]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter logA of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7fe56c626110> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7fe56c563fd0>: {'prior': (uniform[2.0, 4.0]({}), uniform[1.61, 3.91]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter h of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7fe56c7e3880> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7fe56c53f640>: {'prior': (uniform[0.5, 0.9]({}), uniform[0.2, 1.0]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter omega_cdm of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7fe56c7e3880> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7fe56c53f640>: {'prior': (uniform[0.05, 0.2]({}), uniform[0.01, 0.99]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter logA of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7fe56c7e3880> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7fe56c53f640>: {'prior': (uniform[2.0, 4.0]({}), uniform[1.61, 3.91]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter h of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7fe56c7c5000> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7fe56c516cb0>: {'prior': (uniform[0.5, 0.9]({}), uniform[0.2, 1.0]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter omega_cdm of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7fe56c7c5000> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7fe56c516cb0>: {'prior': (uniform[0.05, 0.2]({}), uniform[0.01, 0.99]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter logA of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7fe56c7c5000> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7fe56c516cb0>: {'prior': (uniform[2.0, 4.0]({}), uniform[1.61, 3.91]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter h of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7fe56c77a740> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7fe56c6e2320>: {'prior': (uniform[0.5, 0.9]({}), uniform[0.2, 1.0]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter omega_cdm of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7fe56c77a740> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7fe56c6e2320>: {'prior': (uniform[0.05, 0.2]({}), uniform[0.01, 0.99]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter logA of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7fe56c77a740> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7fe56c6e2320>: {'prior': (uniform[2.0, 4.0]({}), uniform[1.61, 3.91]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter h of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7fe58c1b7430> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7fe56c6a40d0>: {'prior': (uniform[0.5, 0.9]({}), uniform[0.2, 1.0]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter omega_cdm of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7fe58c1b7430> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7fe56c6a40d0>: {'prior': (uniform[0.05, 0.2]({}), uniform[0.01, 0.99]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:452: UserWarning: Parameter logA of <desilike.theories.galaxy_clustering.full_shape.FOLPSv2PowerSpectrumMultipoles object at 0x7fe58c1b7430> is different from that of <desilike.observables.galaxy_clustering.compression.BAOCompressionObservable object at 0x7fe56c6a40d0>: {'prior': (uniform[2.0, 4.0]({}), uniform[1.61, 3.91]({}))}.
#   if self.mpicomm.rank == 0: warnings.warn(msg)
# [000582.25] [0/1] 10-26 13:45  MinuitProfiler            INFO     Successfully jit input likelihood.
# [000772.32] [0/1] 10-26 13:48  MinuitProfiler            WARNING  maximize failed: INTERNAL: Generated function failed: CpuCallback error: KeyboardInterrupt: <EMPTY MESSAGE>
#
# At:
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py(2366): _wrapped_callback
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/jax/_src/interpreters/pxla.py(1151): __call__
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/jax/_src/profiler.py(336): wrapper
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/jax/_src/pjit.py(1185): _pjit_call_impl_python
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/jax/_src/pjit.py(1229): call_impl_cache_miss
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/jax/_src/pjit.py(1245): _pjit_call_impl
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/jax/_src/core.py(935): process_primitive
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/jax/_src/core.py(447): bind_with_trace
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/jax/_src/core.py(2740): bind
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/jax/_src/pjit.py(168): _python_pjit_helper
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/jax/_src/pjit.py(257): cache_miss
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/jax/_src/traceback_util.py(179): reraise_with_filtered_traceback
#   /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/profilers/minuit.py(78): chi2m
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/iminuit/minuit.py(756): migrad
#   /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/profilers/minuit.py(130): _maximize_one
#   /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/profilers/base.py(432): maximize
#   /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/profilers/minuit.py(124): maximize
#   /tmp/ipykernel_2281680/3603975209.py(5): <module>
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/IPython/core/interactiveshell.py(3553): run_code
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/IPython/core/interactiveshell.py(3493): run_ast_nodes
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/IPython/core/interactiveshell.py(3311): run_cell_async
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/IPython/core/async_helpers.py(129): _pseudo_sync_runner
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/IPython/core/interactiveshell.py(3106): _run_cell
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/IPython/core/interactiveshell.py(3051): run_cell
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/ipykernel/zmqshell.py(549): run_cell
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/ipykernel/ipkernel.py(446): do_execute
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/ipykernel/kernelbase.py(775): execute_request
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/ipykernel/ipkernel.py(359): execute_request
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/ipykernel/kernelbase.py(437): dispatch_shell
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/ipykernel/kernelbase.py(531): process_one
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/ipykernel/kernelbase.py(542): dispatch_queue
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/asyncio/events.py(80): _run
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/asyncio/base_events.py(1909): _run_once
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/asyncio/base_events.py(603): run_forever
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/tornado/platform/asyncio.py(195): start
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/ipykernel/kernelapp.py(739): start
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/traitlets/config/application.py(1075): launch_instance
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/ipykernel/__main__.py(5): <module>
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/runpy.py(86): _run_code
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/runpy.py(196): _run_module_as_main
#
# [000775.97] [0/1] 10-26 13:48  MinuitProfiler            WARNING  maximize failed: INTERNAL: Generated function failed: CpuCallback error: KeyboardInterrupt: <EMPTY MESSAGE>
#
# At:
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py(2366): _wrapped_callback
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/jax/_src/interpreters/pxla.py(1151): __call__
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/jax/_src/profiler.py(336): wrapper
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/jax/_src/pjit.py(1185): _pjit_call_impl_python
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/jax/_src/pjit.py(1229): call_impl_cache_miss
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/jax/_src/pjit.py(1245): _pjit_call_impl
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/jax/_src/core.py(935): process_primitive
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/jax/_src/core.py(447): bind_with_trace
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/jax/_src/core.py(2740): bind
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/jax/_src/pjit.py(168): _python_pjit_helper
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/jax/_src/pjit.py(257): cache_miss
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/jax/_src/traceback_util.py(179): reraise_with_filtered_traceback
#   /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/profilers/minuit.py(78): chi2m
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/iminuit/minuit.py(756): migrad
#   /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/profilers/minuit.py(130): _maximize_one
#   /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/profilers/base.py(432): maximize
#   /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/profilers/minuit.py(124): maximize
#   /tmp/ipykernel_2281680/3603975209.py(5): <module>
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/IPython/core/interactiveshell.py(3553): run_code
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/IPython/core/interactiveshell.py(3493): run_ast_nodes
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/IPython/core/interactiveshell.py(3311): run_cell_async
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/IPython/core/async_helpers.py(129): _pseudo_sync_runner
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/IPython/core/interactiveshell.py(3106): _run_cell
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/IPython/core/interactiveshell.py(3051): run_cell
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/ipykernel/zmqshell.py(549): run_cell
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/ipykernel/ipkernel.py(446): do_execute
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/ipykernel/kernelbase.py(775): execute_request
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/ipykernel/ipkernel.py(359): execute_request
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/ipykernel/kernelbase.py(437): dispatch_shell
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/ipykernel/kernelbase.py(531): process_one
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/ipykernel/kernelbase.py(542): dispatch_queue
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/asyncio/events.py(80): _run
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/asyncio/base_events.py(1909): _run_once
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/asyncio/base_events.py(603): run_forever
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/tornado/platform/asyncio.py(195): start
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/ipykernel/kernelapp.py(739): start
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/traitlets/config/application.py(1075): launch_instance
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/ipykernel/__main__.py(5): <module>
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/runpy.py(86): _run_code
#   /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/runpy.py(196): _run_module_as_main

# %%
from pathlib import Path
from desilike.samples import Profiles
chain_path = Path('/global/cfs/cdirs/desicollab/users/prakharb/folpsD_paper_chains/y1_chains_profiler/base/Iminuit-fs+bao_klim_0-0.02-0.301_2-0.02-0.301-all-GCcomb_schoneberg2024-bbn_planck2018-ns10-prior_LCDM_folpsD_Ano.npy')
profiles_folps_phys_bao = Profiles.load(chain_path)
profiles_folps_phys_bao = profiles_folps_phys_bao.choice(index='argmax')
likelihood = SumLikelihood(Likelihoods)
likelihood(**profiles_folps_phys_bao).derived_params()
# Out:
# [000573.85] [0/1] 10-25 19:22  Profiles                  INFO     Loading /global/cfs/cdirs/desicollab/users/prakharb/folpsD_paper_chains/y1_chains_profiler/base/Iminuit-fs+bao_klim_0-0.02-0.301_2-0.02-0.301-all-GCcomb_schoneberg2024-bbn_planck2018-ns10-prior_LCDM_folpsD_Ano.npy.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 7
#       5 profiles_folps_phys_bao = profiles_folps_phys_bao.choice(index='argmax')
#       6 likelihood = SumLikelihood(Likelihoods)
# ----> 7 likelihood(**profiles_folps_phys_bao).derived_params()
#
# TypeError: <desilike.likelihoods.base.SumLikelihood object at 0x7f74ec1b6350> argument after ** must be a mapping, not Profiles

# %%
from pathlib import Path

def load_chain_numpy(fi, burnin=0.3,n=1):
    from desilike.samples import Chain
    if n != 1:
        chains = [Chain.load(ff).remove_burnin(burnin) for ff in fi]
    else:
        chains = [Chain.load(fi).remove_burnin(burnin)]
    chain = chains[0].concatenate(chains)
    print(f'chain: {chain}')
    return chain
from desilike.samples import Profiles
chain_path = Path('/global/cfs/cdirs/desicollab/users/prakharb/folpsD_paper_chains/y1_chains_profiler/base_EFT/Iminuit-fs+bao_klim_0-0.02-0.201_2-0.02-0.201-all-GCcomb_schoneberg2024-bbn_planck2018-ns10_physical-prior_LCDM_rept_velocileptors.npy')
profiles = Profiles.load(chain_path)

# %%
profiles.bestfit.choice(index='argmax',input=True)
# Out:
# {'h': ParameterArray(h, None, 0.6883271866911199),
#  'omega_cdm': ParameterArray(omega_cdm, None, 0.11580325517707073),
#  'omega_b': ParameterArray(omega_b, None, 0.022093175836026963),
#  'logA': ParameterArray(logA, None, 3.1881504149846314),
#  'n_s': ParameterArray(n_s, None, 0.9669573805826953),
#  'QSO.b1p': ParameterArray(QSO.b1p, None, 0.8908784427362907),
#  'QSO.b2p': ParameterArray(QSO.b2p, None, -0.8337280946900347),
#  'QSO.bsp': ParameterArray(QSO.bsp, None, 0.2659729066645945),
#  'ELG.b1p': ParameterArray(ELG.b1p, None, 0.5417260505358696),
#  'ELG.b2p': ParameterArray(ELG.b2p, None, 0.020487839062194285),
#  'ELG.bsp': ParameterArray(ELG.bsp, None, 0.8135814003600083),
#  'LRG3.b1p': ParameterArray(LRG3.b1p, None, 1.0895272865470849),
#  'LRG3.b2p': ParameterArray(LRG3.b2p, None, -0.8246073253958701),
#  'LRG3.bsp': ParameterArray(LRG3.bsp, None, -0.3078845443509687),
#  'LRG2.b1p': ParameterArray(LRG2.b1p, None, 1.1223156579142486),
#  'LRG2.b2p': ParameterArray(LRG2.b2p, None, -1.2969756110149935),
#  'LRG2.bsp': ParameterArray(LRG2.bsp, None, 0.5361109517529631),
#  'LRG1.b1p': ParameterArray(LRG1.b1p, None, 1.1565432985554267),
#  'LRG1.b2p': ParameterArray(LRG1.b2p, None, -0.962620228601252),
#  'LRG1.bsp': ParameterArray(LRG1.bsp, None, -0.20711037459169887),
#  'BGS.b1p': ParameterArray(BGS.b1p, None, 1.003409310604105),
#  'BGS.b2p': ParameterArray(BGS.b2p, None, -0.6838826535832275),
#  'BGS.bsp': ParameterArray(BGS.bsp, None, 2.16368499491698),
#  'tau_reio': ParameterArray(tau_reio, None, 0.0544),
#  'm_ncdm': ParameterArray(m_ncdm, None, 0.06),
#  'N_eff': ParameterArray(N_eff, None, 3.046),
#  'w0_fld': ParameterArray(w0_fld, None, -1.0),
#  'wa_fld': ParameterArray(wa_fld, None, 0.0),
#  'Omega_k': ParameterArray(Omega_k, None, 0.0),
#  'QSO.b3p': ParameterArray(QSO.b3p, None, 0.0),
#  'QSO.alpha6p': ParameterArray(QSO.alpha6p, None, 0.0),
#  'QSO.sn4p': ParameterArray(QSO.sn4p, None, 0.0),
#  'ELG.b3p': ParameterArray(ELG.b3p, None, 0.0),
#  'ELG.alpha6p': ParameterArray(ELG.alpha6p, None, 0.0),
#  'ELG.sn4p': ParameterArray(ELG.sn4p, None, 0.0),
#  'LRG3.b3p': ParameterArray(LRG3.b3p, None, 0.0),
#  'LRG3.alpha6p': ParameterArray(LRG3.alpha6p, None, 0.0),
#  'LRG3.sn4p': ParameterArray(LRG3.sn4p, None, 0.0),
#  'LRG2.b3p': ParameterArray(LRG2.b3p, None, 0.0),
#  'LRG2.alpha6p': ParameterArray(LRG2.alpha6p, None, 0.0),
#  'LRG2.sn4p': ParameterArray(LRG2.sn4p, None, 0.0),
#  'LRG1.b3p': ParameterArray(LRG1.b3p, None, 0.0),
#  'LRG1.alpha6p': ParameterArray(LRG1.alpha6p, None, 0.0),
#  'LRG1.sn4p': ParameterArray(LRG1.sn4p, None, 0.0),
#  'BGS.b3p': ParameterArray(BGS.b3p, None, 0.0),
#  'BGS.alpha6p': ParameterArray(BGS.alpha6p, None, 0.0),
#  'BGS.sn4p': ParameterArray(BGS.sn4p, None, 0.0),
#  'QSO.alpha0p': ParameterArray(QSO.alpha0p, None, 5.37127840906213),
#  'QSO.alpha2p': ParameterArray(QSO.alpha2p, None, -0.9375273725204811),
#  'QSO.alpha4p': ParameterArray(QSO.alpha4p, None, -0.824450616437465),
#  'QSO.sn0p': ParameterArray(QSO.sn0p, None, -0.009062835000674075),
#  'QSO.sn2p': ParameterArray(QSO.sn2p, None, -0.42870155211032673),
#  'ELG.alpha0p': ParameterArray(ELG.alpha0p, None, 41.074502113393976),
#  'ELG.alpha2p': ParameterArray(ELG.alpha2p, None, -0.13816488689371065),
#  'ELG.alpha4p': ParameterArray(ELG.alpha4p, None, -13.38382091867461),
#  'ELG.sn0p': ParameterArray(ELG.sn0p, None, -0.18926924375552107),
#  'ELG.sn2p': ParameterArray(ELG.sn2p, None, -0.7201973282612282),
#  'LRG3.alpha0p': ParameterArray(LRG3.alpha0p, None, 24.74276098471832),
#  'LRG3.alpha2p': ParameterArray(LRG3.alpha2p, None, -11.599502279172187),
#  'LRG3.alpha4p': ParameterArray(LRG3.alpha4p, None, -33.57544564345504),
#  'LRG3.sn0p': ParameterArray(LRG3.sn0p, None, -0.430568479589649),
#  'LRG3.sn2p': ParameterArray(LRG3.sn2p, None, 0.3303568705650119),
#  'LRG2.alpha0p': ParameterArray(LRG2.alpha0p, None, -0.20659379983893342),
#  'LRG2.alpha2p': ParameterArray(LRG2.alpha2p, None, 0.5171931328758865),
#  'LRG2.alpha4p': ParameterArray(LRG2.alpha4p, None, 14.397872687125535),
#  'LRG2.sn0p': ParameterArray(LRG2.sn0p, None, 0.1707513978295852),
#  'LRG2.sn2p': ParameterArray(LRG2.sn2p, None, -3.07462516018035),
#  'LRG1.alpha0p': ParameterArray(LRG1.alpha0p, None, 45.840616261474416),
#  'LRG1.alpha2p': ParameterArray(LRG1.alpha2p, None, -13.513905614381418),
#  'LRG1.alpha4p': ParameterArray(LRG1.alpha4p, None, -34.84930061559539),
#  'LRG1.sn0p': ParameterArray(LRG1.sn0p, None, -1.6679503482396203),
#  'LRG1.sn2p': ParameterArray(LRG1.sn2p, None, -3.750344988079745),
#  'BGS.alpha0p': ParameterArray(BGS.alpha0p, None, 48.04628646553155),
#  'BGS.alpha2p': ParameterArray(BGS.alpha2p, None, 37.0748832767016),
#  'BGS.alpha4p': ParameterArray(BGS.alpha4p, None, -56.342957678447895),
#  'BGS.sn0p': ParameterArray(BGS.sn0p, None, -1.485293131358168),
#  'BGS.sn2p': ParameterArray(BGS.sn2p, None, -4.062484800548311)}

# %%
values = {param.name: param.value for param in likelihood.all_params.select(input=True)}
params = [param for param in likelihood.all_params]
values.update(profiles.bestfit.choice(index='argmax', params=params))
values['Omega_m'].value
# Out:
# array(0.30732426)

# %%
from desilike.theories.primordial import Cosmoprimo
cosmo = Cosmoprimo(**values)
print(cosmo.sigma8_m)

# %%
profiles.choice(index='argmax').bestfit['h'].value
# Out:
# array([0.68874756])

# %%
likelihood.all_params
# Out:
# ParameterCollection(['h', 'omega_cdm', 'omega_b', 'logA', 'n_s', 'tau_reio', 'm_ncdm', 'N_eff', 'w0_fld', 'wa_fld', 'Omega_k', 'H0', 'Omega_m', 'sigma8_m', 'QSO.b1p', 'QSO.b2p', 'QSO.bsp', 'QSO.b3p', 'QSO.alpha0p', 'QSO.alpha2p', 'QSO.alpha4p', 'QSO.ctp', 'QSO.sn0p', 'QSO.sn2p', 'QSO.X_FoG_pp', 'loglikelihood', 'logprior', 'ELG.b1p', 'ELG.b2p', 'ELG.bsp', 'ELG.b3p', 'ELG.alpha0p', 'ELG.alpha2p', 'ELG.alpha4p', 'ELG.ctp', 'ELG.sn0p', 'ELG.sn2p', 'ELG.X_FoG_pp', 'LRG3.b1p', 'LRG3.b2p', 'LRG3.bsp', 'LRG3.b3p', 'LRG3.alpha0p', 'LRG3.alpha2p', 'LRG3.alpha4p', 'LRG3.ctp', 'LRG3.sn0p', 'LRG3.sn2p', 'LRG3.X_FoG_pp', 'LRG2.b1p', 'LRG2.b2p', 'LRG2.bsp', 'LRG2.b3p', 'LRG2.alpha0p', 'LRG2.alpha2p', 'LRG2.alpha4p', 'LRG2.ctp', 'LRG2.sn0p', 'LRG2.sn2p', 'LRG2.X_FoG_pp', 'LRG1.b1p', 'LRG1.b2p', 'LRG1.bsp', 'LRG1.b3p', 'LRG1.alpha0p', 'LRG1.alpha2p', 'LRG1.alpha4p', 'LRG1.ctp', 'LRG1.sn0p', 'LRG1.sn2p', 'LRG1.X_FoG_pp', 'BGS.b1p', 'BGS.b2p', 'BGS.bsp', 'BGS.b3p', 'BGS.alpha0p', 'BGS.alpha2p', 'BGS.alpha4p', 'BGS.ctp', 'BGS.sn0p', 'BGS.sn2p', 'BGS.X_FoG_pp'])

# %%
ls /global/cfs/cdirs/desicollab/users/prakharb/folpsD_paper_chains/Emulator_y1_bao
# Out:
# /bin/bash: module: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `module'
# /bin/bash: ml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `ml'
# emu-bao_klim_0-0.02-0.201_2-0.02-0.201-all-GCcomb_schoneberg2024-bbn_planck2018-ns10_physical-prior_LCDM_EFT_BGS.npy
# emu-bao_klim_0-0.02-0.201_2-0.02-0.201-all-GCcomb_schoneberg2024-bbn_planck2018-ns10_physical-prior_LCDM_EFT_BGS.yaml
# emu-bao_klim_0-0.02-0.201_2-0.02-0.201-all-GCcomb_schoneberg2024-bbn_planck2018-ns10_physical-prior_LCDM_EFT_LRG1.npy
# emu-bao_klim_0-0.02-0.201_2-0.02-0.201-all-GCcomb_schoneberg2024-bbn_planck2018-ns10_physical-prior_LCDM_EFT_LRG1.yaml
# emu-bao_klim_0-0.02-0.301_2-0.02-0.301-all-GCcomb_schoneberg2024-bbn_planck2018-ns10_physical-prior_LCDM_folpsD_BGS.npy
# emu-bao_klim_0-0.02-0.301_2-0.02-0.301-all-GCcomb_schoneberg2024-bbn_planck2018-ns10_physical-prior_LCDM_folpsD_BGS.yaml
# emu-bao_klim_0-0.02-0.301_2-0.02-0.301-all-GCcomb_schoneberg2024-bbn_planck2018-ns10_physical-prior_LCDM_folpsD_ELG.npy
# emu-bao_klim_0-0.02-0.301_2-0.02-0.301-all-GCcomb_schoneberg2024-bbn_planck2018-ns10_physical-prior_LCDM_folpsD_ELG.yaml
# emu-bao_klim_0-0.02-0.301_2-0.02-0.301-all-GCcomb_schoneberg2024-bbn_planck2018-ns10_physical-prior_LCDM_folpsD_LRG1.npy
# emu-bao_klim_0-0.02-0.301_2-0.02-0.301-all-GCcomb_schoneberg2024-bbn_planck2018-ns10_physical-prior_LCDM_folpsD_LRG1.yaml
# emu-bao_klim_0-0.02-0.301_2-0.02-0.301-all-GCcomb_schoneberg2024-bbn_planck2018-ns10_physical-prior_LCDM_folpsD_LRG2.npy
# emu-bao_klim_0-0.02-0.301_2-0.02-0.301-all-GCcomb_schoneberg2024-bbn_planck2018-ns10_physical-prior_LCDM_folpsD_LRG2.yaml
# emu-bao_klim_0-0.02-0.301_2-0.02-0.301-all-GCcomb_schoneberg2024-bbn_planck2018-ns10_physical-prior_LCDM_folpsD_LRG3.npy
# emu-bao_klim_0-0.02-0.301_2-0.02-0.301-all-GCcomb_schoneberg2024-bbn_planck2018-ns10_physical-prior_LCDM_folpsD_LRG3.yaml
# emu-bao_klim_0-0.02-0.301_2-0.02-0.301-all-GCcomb_schoneberg2024-bbn_planck2018-ns10_physical-prior_LCDM_folpsD_QSO.npy
# emu-bao_klim_0-0.02-0.301_2-0.02-0.301-all-GCcomb_schoneberg2024-bbn_planck2018-ns10_physical-prior_LCDM_folpsD_QSO.yaml
# emu-bao_klim_0-0.02-0.301_2-0.02-0.301-all-GCcomb_schoneberg2024-bbn_planck2018-ns10_physical-prior_w0waCDM_folpsD_BGS.npy
# emu-bao_klim_0-0.02-0.301_2-0.02-0.301-all-GCcomb_schoneberg2024-bbn_planck2018-ns10_physical-prior_w0waCDM_folpsD_BGS.yaml
# emu-bao_klim_0-0.02-0.301_2-0.02-0.301-all-GCcomb_schoneberg2024-bbn_planck2018-ns10_physical-prior_w0waCDM_folpsD_ELG.npy
# emu-bao_klim_0-0.02-0.301_2-0.02-0.301-all-GCcomb_schoneberg2024-bbn_planck2018-ns10_physical-prior_w0waCDM_folpsD_ELG.yaml
# emu-bao_klim_0-0.02-0.301_2-0.02-0.301-all-GCcomb_schoneberg2024-bbn_planck2018-ns10_physical-prior_w0waCDM_folpsD_LRG1.npy
# emu-bao_klim_0-0.02-0.301_2-0.02-0.301-all-GCcomb_schoneberg2024-bbn_planck2018-ns10_physical-prior_w0waCDM_folpsD_LRG1.yaml
# emu-bao_klim_0-0.02-0.301_2-0.02-0.301-all-GCcomb_schoneberg2024-bbn_planck2018-ns10_physical-prior_w0waCDM_folpsD_LRG2.npy
# emu-bao_klim_0-0.02-0.301_2-0.02-0.301-all-GCcomb_schoneberg2024-bbn_planck2018-ns10_physical-prior_w0waCDM_folpsD_LRG2.yaml
# emu-bao_klim_0-0.02-0.301_2-0.02-0.301-all-GCcomb_schoneberg2024-bbn_planck2018-ns10_physical-prior_w0waCDM_folpsD_LRG3.npy
# emu-bao_klim_0-0.02-0.301_2-0.02-0.301-all-GCcomb_schoneberg2024-bbn_planck2018-ns10_physical-prior_w0waCDM_folpsD_LRG3.yaml
# emu-bao_klim_0-0.02-0.301_2-0.02-0.301-all-GCcomb_schoneberg2024-bbn_planck2018-ns10_physical-prior_w0waCDM_folpsD_QSO.npy
# emu-bao_klim_0-0.02-0.301_2-0.02-0.301-all-GCcomb_schoneberg2024-bbn_planck2018-ns10_physical-prior_w0waCDM_folpsD_QSO.yaml
# emu-bao_klim_0-0.02-0.301_2-0.02-0.301-all-GCcomb_schoneberg2024-bbn_planck2018-ns10_standard-prior_w0waCDM_folpsD_BGS.npy
# emu-bao_klim_0-0.02-0.301_2-0.02-0.301-all-GCcomb_schoneberg2024-bbn_planck2018-ns10_standard-prior_w0waCDM_folpsD_BGS.yaml
# emu-bao_klim_0-0.02-0.301_2-0.02-0.301-all-GCcomb_schoneberg2024-bbn_planck2018-ns10_standard-prior_w0waCDM_folpsD_ELG.npy
# emu-bao_klim_0-0.02-0.301_2-0.02-0.301-all-GCcomb_schoneberg2024-bbn_planck2018-ns10_standard-prior_w0waCDM_folpsD_ELG.yaml
# emu-bao_klim_0-0.02-0.301_2-0.02-0.301-all-GCcomb_schoneberg2024-bbn_planck2018-ns10_standard-prior_w0waCDM_folpsD_LRG1.npy
# emu-bao_klim_0-0.02-0.301_2-0.02-0.301-all-GCcomb_schoneberg2024-bbn_planck2018-ns10_standard-prior_w0waCDM_folpsD_LRG1.yaml
# emu-bao_klim_0-0.02-0.301_2-0.02-0.301-all-GCcomb_schoneberg2024-bbn_planck2018-ns10_standard-prior_w0waCDM_folpsD_LRG2.npy
# emu-bao_klim_0-0.02-0.301_2-0.02-0.301-all-GCcomb_schoneberg2024-bbn_planck2018-ns10_standard-prior_w0waCDM_folpsD_LRG2.yaml
# emu-bao_klim_0-0.02-0.301_2-0.02-0.301-all-GCcomb_schoneberg2024-bbn_planck2018-ns10_standard-prior_w0waCDM_folpsD_LRG3.npy
# emu-bao_klim_0-0.02-0.301_2-0.02-0.301-all-GCcomb_schoneberg2024-bbn_planck2018-ns10_standard-prior_w0waCDM_folpsD_LRG3.yaml
# emu-bao_klim_0-0.02-0.301_2-0.02-0.301-all-GCcomb_schoneberg2024-bbn_planck2018-ns10_standard-prior_w0waCDM_folpsD_QSO.npy
# emu-bao_klim_0-0.02-0.301_2-0.02-0.301-all-GCcomb_schoneberg2024-bbn_planck2018-ns10_standard-prior_w0waCDM_folpsD_QSO.yaml

# %%
likelihood.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:1214, in BaseCalculator.__getattr__(self, name)
#    1213 try:
# -> 1214     return object.__getattribute__(self, name)
#    1215 except AttributeError as exc:
#
# AttributeError: 'SumLikelihood' object has no attribute 'fixed_params'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 likelihood.fixed_params
#
# File /global/u1/p/prakharb/desilike-folps-jax-dev/desilike/base.py:1216, in BaseCalculator.__getattr__(self, name)
#    1214     return object.__getattribute__(self, name)
#    1215 except AttributeError as exc:
# -> 1216     raise AttributeError('calculator {} has no attribute {}; '
#    1217                          'have you run any calculation already by calling this calculator or calculators '
#    1218                          'that depend on it (typically, a likelihood?)'.format(self.__class__.__name__, name)) from exc
#
# AttributeError: calculator SumLikelihood has no attribute fixed_params; have you run any calculation already by calling this calculator or calculators that depend on it (typically, a likelihood?)

# %%
from pathlib import Path

def load_chain_numpy(fi, burnin=0.3,n=1):
    from desilike.samples import Chain
    if n != 1:
        chains = [Chain.load(ff).remove_burnin(burnin) for ff in fi]
    else:
        chains = [Chain.load(fi).remove_burnin(burnin)]
    chain = chains[0].concatenate(chains)
    print(f'chain: {chain}')
    return chain
chain_path = Path('/global/cfs/cdirs/desicollab/users/prakharb/folpsD_paper_chains/y1_chains/EFT/folps_chains/MCMC-fs+bao_klim_0-0.02-0.2_2-0.02-0.2-all-GCcomb_schoneberg2024-bbn_planck2018-ns10_physical-prior_LCDM_folps.npy')
chain = load_chain_numpy(chain_path,burnin=0.3)
chain.choice(index='argmax',input=True)
# Out:
# chain: Chain(shape=(49140,), params=ParameterCollection(['h', 'omega_cdm', 'omega_b', 'logA', 'n_s', 'QSO.b1p', 'QSO.b2p', 'QSO.bsp', 'ELG.b1p', 'ELG.b2p', 'ELG.bsp', 'BGS.b1p', 'BGS.b2p', 'BGS.bsp', 'LRG1.b1p', 'LRG1.b2p', 'LRG1.bsp', 'LRG3.b1p', 'LRG3.b2p', 'LRG3.bsp', 'LRG2.b1p', 'LRG2.b2p', 'LRG2.bsp', 'fweight', 'logposterior', 'tau_reio', 'm_ncdm', 'N_eff', 'w0_fld', 'wa_fld', 'Omega_k', 'QSO.b3p', 'QSO.ctp', 'ELG.b3p', 'ELG.ctp', 'LRG3.b3p', 'LRG3.ctp', 'LRG2.b3p', 'LRG2.ctp', 'LRG1.b3p', 'LRG1.ctp', 'BGS.b3p', 'BGS.ctp', 'H0', 'Omega_m', 'sigma8_m', 'loglikelihood', 'logprior', 'QSO.alpha0p', 'QSO.alpha2p', 'QSO.alpha4p', 'QSO.sn0p', 'QSO.sn2p', 'ELG.alpha0p', 'ELG.alpha2p', 'ELG.alpha4p', 'ELG.sn0p', 'ELG.sn2p', 'LRG3.alpha0p', 'LRG3.alpha2p', 'LRG3.alpha4p', 'LRG3.sn0p', 'LRG3.sn2p', 'LRG2.alpha0p', 'LRG2.alpha2p', 'LRG2.alpha4p', 'LRG2.sn0p', 'LRG2.sn2p', 'LRG1.alpha0p', 'LRG1.alpha2p', 'LRG1.alpha4p', 'LRG1.sn0p', 'LRG1.sn2p', 'BGS.alpha0p', 'BGS.alpha2p', 'BGS.alpha4p', 'BGS.sn0p', 'BGS.sn2p']))
# {'h': ParameterArray(h, None, 0.6827565675958774),
#  'omega_cdm': ParameterArray(omega_cdm, None, 0.11415456777555835),
#  'omega_b': ParameterArray(omega_b, None, 0.021932517144072673),
#  'logA': ParameterArray(logA, None, 2.971441019590064),
#  'n_s': ParameterArray(n_s, None, 0.982626898971443),
#  'QSO.b1p': ParameterArray(QSO.b1p, None, 0.9064194078460998),
#  'QSO.b2p': ParameterArray(QSO.b2p, None, -0.6328395478385153),
#  'QSO.bsp': ParameterArray(QSO.bsp, None, 1.73224057176619),
#  'ELG.b1p': ParameterArray(ELG.b1p, None, 0.6126842695246283),
#  'ELG.b2p': ParameterArray(ELG.b2p, None, -0.6575835125050448),
#  'ELG.bsp': ParameterArray(ELG.bsp, None, 0.3670265002205332),
#  'BGS.b1p': ParameterArray(BGS.b1p, None, 1.105171973276268),
#  'BGS.b2p': ParameterArray(BGS.b2p, None, -0.4246735593219359),
#  'BGS.bsp': ParameterArray(BGS.bsp, None, -0.5711983981117373),
#  'LRG1.b1p': ParameterArray(LRG1.b1p, None, 1.1732951819608866),
#  'LRG1.b2p': ParameterArray(LRG1.b2p, None, -0.9717337220503484),
#  'LRG1.bsp': ParameterArray(LRG1.bsp, None, 1.5032945451982807),
#  'LRG3.b1p': ParameterArray(LRG3.b1p, None, 1.1414238086752493),
#  'LRG3.b2p': ParameterArray(LRG3.b2p, None, -0.8391066602757523),
#  'LRG3.bsp': ParameterArray(LRG3.bsp, None, 0.6329784255096363),
#  'LRG2.b1p': ParameterArray(LRG2.b1p, None, 1.1480586853984953),
#  'LRG2.b2p': ParameterArray(LRG2.b2p, None, -1.2311344050286341),
#  'LRG2.bsp': ParameterArray(LRG2.bsp, None, 1.6506305753262547),
#  'tau_reio': ParameterArray(tau_reio, None, 0.0544),
#  'm_ncdm': ParameterArray(m_ncdm, None, 0.06),
#  'N_eff': ParameterArray(N_eff, None, 3.046),
#  'w0_fld': ParameterArray(w0_fld, None, -1.0),
#  'wa_fld': ParameterArray(wa_fld, None, 0.0),
#  'Omega_k': ParameterArray(Omega_k, None, 0.0),
#  'QSO.b3p': ParameterArray(QSO.b3p, None, 0.0),
#  'QSO.ctp': ParameterArray(QSO.ctp, None, 0.0),
#  'ELG.b3p': ParameterArray(ELG.b3p, None, 0.0),
#  'ELG.ctp': ParameterArray(ELG.ctp, None, 0.0),
#  'LRG3.b3p': ParameterArray(LRG3.b3p, None, 0.0),
#  'LRG3.ctp': ParameterArray(LRG3.ctp, None, 0.0),
#  'LRG2.b3p': ParameterArray(LRG2.b3p, None, 0.0),
#  'LRG2.ctp': ParameterArray(LRG2.ctp, None, 0.0),
#  'LRG1.b3p': ParameterArray(LRG1.b3p, None, 0.0),
#  'LRG1.ctp': ParameterArray(LRG1.ctp, None, 0.0),
#  'BGS.b3p': ParameterArray(BGS.b3p, None, 0.0),
#  'BGS.ctp': ParameterArray(BGS.ctp, None, 0.0),
#  'QSO.alpha0p': ParameterArray(QSO.alpha0p, None, 0.569736977186295),
#  'QSO.alpha2p': ParameterArray(QSO.alpha2p, None, -1.9176282095271173),
#  'QSO.alpha4p': ParameterArray(QSO.alpha4p, None, -1.354409405283501),
#  'QSO.sn0p': ParameterArray(QSO.sn0p, None, 0.032352381655146534),
#  'QSO.sn2p': ParameterArray(QSO.sn2p, None, -0.5843399067304786),
#  'ELG.alpha0p': ParameterArray(ELG.alpha0p, None, 6.039795600107412),
#  'ELG.alpha2p': ParameterArray(ELG.alpha2p, None, 1.872723637479585),
#  'ELG.alpha4p': ParameterArray(ELG.alpha4p, None, 0.7729670265031875),
#  'ELG.sn0p': ParameterArray(ELG.sn0p, None, 0.03306085897024149),
#  'ELG.sn2p': ParameterArray(ELG.sn2p, None, -0.5130098860223138),
#  'LRG3.alpha0p': ParameterArray(LRG3.alpha0p, None, 3.2277629749612218),
#  'LRG3.alpha2p': ParameterArray(LRG3.alpha2p, None, -16.943544819745373),
#  'LRG3.alpha4p': ParameterArray(LRG3.alpha4p, None, -11.338713406888841),
#  'LRG3.sn0p': ParameterArray(LRG3.sn0p, None, 0.11071763863360917),
#  'LRG3.sn2p': ParameterArray(LRG3.sn2p, None, -0.7746974194474431),
#  'LRG2.alpha0p': ParameterArray(LRG2.alpha0p, None, -8.819298216538407),
#  'LRG2.alpha2p': ParameterArray(LRG2.alpha2p, None, -8.45620673067848),
#  'LRG2.alpha4p': ParameterArray(LRG2.alpha4p, None, -5.217793464195113),
#  'LRG2.sn0p': ParameterArray(LRG2.sn0p, None, 0.4683016851837375),
#  'LRG2.sn2p': ParameterArray(LRG2.sn2p, None, -3.1104707439544224),
#  'LRG1.alpha0p': ParameterArray(LRG1.alpha0p, None, 4.379698741777045),
#  'LRG1.alpha2p': ParameterArray(LRG1.alpha2p, None, -11.544273842620942),
#  'LRG1.alpha4p': ParameterArray(LRG1.alpha4p, None, -7.990644063188612),
#  'LRG1.sn0p': ParameterArray(LRG1.sn0p, None, -0.0385916294395555),
#  'LRG1.sn2p': ParameterArray(LRG1.sn2p, None, -5.230217013632288),
#  'BGS.alpha0p': ParameterArray(BGS.alpha0p, None, -6.521306339428237),
#  'BGS.alpha2p': ParameterArray(BGS.alpha2p, None, -11.28798210787873),
#  'BGS.alpha4p': ParameterArray(BGS.alpha4p, None, -7.698918017571994),
#  'BGS.sn0p': ParameterArray(BGS.sn0p, None, 0.6572595976006533),
#  'BGS.sn2p': ParameterArray(BGS.sn2p, None, -3.541194202003866)}

# %%
from pathlib import Path

def load_chain_numpy(fi, burnin=0.3,n=1):
    from desilike.samples import Chain
    if n != 1:
        chains = [Chain.load(ff).remove_burnin(burnin) for ff in fi]
    else:
        chains = [Chain.load(fi).remove_burnin(burnin)]
    chain = chains[0].concatenate(chains)
    print(f'chain: {chain}')
    return chain
chain_path = Path('/global/cfs/cdirs/desicollab/users/prakharb/folpsD_paper_chains/y1_chains/EFT/MCMC-fs+bao_klim_0-0.02-0.201_2-0.02-0.201-all-GCcomb_schoneberg2024-bbn_planck2018-ns10_physical-prior_LCDM_rept_velocileptors.npy')
chain = load_chain_numpy(chain_path,burnin=0.3)
chain.choice(index='argmax',input=True)
# Out:
# chain: Chain(shape=(31710,), params=ParameterCollection(['h', 'omega_cdm', 'omega_b', 'logA', 'n_s', 'QSO.b1p', 'QSO.b2p', 'QSO.bsp', 'LRG1.b1p', 'LRG1.b2p', 'LRG1.bsp', 'ELG.b1p', 'ELG.b2p', 'ELG.bsp', 'LRG3.b1p', 'LRG3.b2p', 'LRG3.bsp', 'BGS.b1p', 'BGS.b2p', 'BGS.bsp', 'LRG2.b1p', 'LRG2.b2p', 'LRG2.bsp', 'fweight', 'logposterior', 'tau_reio', 'm_ncdm', 'N_eff', 'w0_fld', 'wa_fld', 'Omega_k', 'QSO.b3p', 'QSO.alpha6p', 'QSO.sn4p', 'ELG.b3p', 'ELG.alpha6p', 'ELG.sn4p', 'LRG3.b3p', 'LRG3.alpha6p', 'LRG3.sn4p', 'LRG2.b3p', 'LRG2.alpha6p', 'LRG2.sn4p', 'LRG1.b3p', 'LRG1.alpha6p', 'LRG1.sn4p', 'BGS.b3p', 'BGS.alpha6p', 'BGS.sn4p', 'H0', 'Omega_m', 'sigma8_m', 'loglikelihood', 'logprior', 'QSO.alpha0p', 'QSO.alpha2p', 'QSO.alpha4p', 'QSO.sn0p', 'QSO.sn2p', 'ELG.alpha0p', 'ELG.alpha2p', 'ELG.alpha4p', 'ELG.sn0p', 'ELG.sn2p', 'LRG3.alpha0p', 'LRG3.alpha2p', 'LRG3.alpha4p', 'LRG3.sn0p', 'LRG3.sn2p', 'LRG2.alpha0p', 'LRG2.alpha2p', 'LRG2.alpha4p', 'LRG2.sn0p', 'LRG2.sn2p', 'LRG1.alpha0p', 'LRG1.alpha2p', 'LRG1.alpha4p', 'LRG1.sn0p', 'LRG1.sn2p', 'BGS.alpha0p', 'BGS.alpha2p', 'BGS.alpha4p', 'BGS.sn0p', 'BGS.sn2p']))
# {'h': ParameterArray(h, None, 0.6872677909497797),
#  'omega_cdm': ParameterArray(omega_cdm, None, 0.11616595479727596),
#  'omega_b': ParameterArray(omega_b, None, 0.022411584467540997),
#  'logA': ParameterArray(logA, None, 3.043883610749593),
#  'n_s': ParameterArray(n_s, None, 0.9857216312441976),
#  'QSO.b1p': ParameterArray(QSO.b1p, None, 0.9213546331156652),
#  'QSO.b2p': ParameterArray(QSO.b2p, None, -0.6702649149997169),
#  'QSO.bsp': ParameterArray(QSO.bsp, None, 0.588502122566945),
#  'LRG1.b1p': ParameterArray(LRG1.b1p, None, 1.1809017598501743),
#  'LRG1.b2p': ParameterArray(LRG1.b2p, None, -0.7483425499567589),
#  'LRG1.bsp': ParameterArray(LRG1.bsp, None, 0.5037399151515467),
#  'ELG.b1p': ParameterArray(ELG.b1p, None, 0.6033639425880766),
#  'ELG.b2p': ParameterArray(ELG.b2p, None, -0.30980233976223903),
#  'ELG.bsp': ParameterArray(ELG.bsp, None, -0.12158835866131362),
#  'LRG3.b1p': ParameterArray(LRG3.b1p, None, 1.149846857989762),
#  'LRG3.b2p': ParameterArray(LRG3.b2p, None, -1.1588775518143979),
#  'LRG3.bsp': ParameterArray(LRG3.bsp, None, 0.6332725148030122),
#  'BGS.b1p': ParameterArray(BGS.b1p, None, 1.0952955945471567),
#  'BGS.b2p': ParameterArray(BGS.b2p, None, -1.091048241974993),
#  'BGS.bsp': ParameterArray(BGS.bsp, None, 0.2745365652724629),
#  'LRG2.b1p': ParameterArray(LRG2.b1p, None, 1.151249671756926),
#  'LRG2.b2p': ParameterArray(LRG2.b2p, None, -0.8530309578930202),
#  'LRG2.bsp': ParameterArray(LRG2.bsp, None, 0.49272898407908194),
#  'tau_reio': ParameterArray(tau_reio, None, 0.0544),
#  'm_ncdm': ParameterArray(m_ncdm, None, 0.06),
#  'N_eff': ParameterArray(N_eff, None, 3.046),
#  'w0_fld': ParameterArray(w0_fld, None, -1.0),
#  'wa_fld': ParameterArray(wa_fld, None, 0.0),
#  'Omega_k': ParameterArray(Omega_k, None, 0.0),
#  'QSO.b3p': ParameterArray(QSO.b3p, None, 0.0),
#  'QSO.alpha6p': ParameterArray(QSO.alpha6p, None, 0.0),
#  'QSO.sn4p': ParameterArray(QSO.sn4p, None, 0.0),
#  'ELG.b3p': ParameterArray(ELG.b3p, None, 0.0),
#  'ELG.alpha6p': ParameterArray(ELG.alpha6p, None, 0.0),
#  'ELG.sn4p': ParameterArray(ELG.sn4p, None, 0.0),
#  'LRG3.b3p': ParameterArray(LRG3.b3p, None, 0.0),
#  'LRG3.alpha6p': ParameterArray(LRG3.alpha6p, None, 0.0),
#  'LRG3.sn4p': ParameterArray(LRG3.sn4p, None, 0.0),
#  'LRG2.b3p': ParameterArray(LRG2.b3p, None, 0.0),
#  'LRG2.alpha6p': ParameterArray(LRG2.alpha6p, None, 0.0),
#  'LRG2.sn4p': ParameterArray(LRG2.sn4p, None, 0.0),
#  'LRG1.b3p': ParameterArray(LRG1.b3p, None, 0.0),
#  'LRG1.alpha6p': ParameterArray(LRG1.alpha6p, None, 0.0),
#  'LRG1.sn4p': ParameterArray(LRG1.sn4p, None, 0.0),
#  'BGS.b3p': ParameterArray(BGS.b3p, None, 0.0),
#  'BGS.alpha6p': ParameterArray(BGS.alpha6p, None, 0.0),
#  'BGS.sn4p': ParameterArray(BGS.sn4p, None, 0.0),
#  'QSO.alpha0p': ParameterArray(QSO.alpha0p, None, 2.0991749565871127),
#  'QSO.alpha2p': ParameterArray(QSO.alpha2p, None, 3.6233337777502217),
#  'QSO.alpha4p': ParameterArray(QSO.alpha4p, None, 3.0423738367692477),
#  'QSO.sn0p': ParameterArray(QSO.sn0p, None, 0.004033664701759117),
#  'QSO.sn2p': ParameterArray(QSO.sn2p, None, -0.5055127479663306),
#  'ELG.alpha0p': ParameterArray(ELG.alpha0p, None, 3.2406943460207915),
#  'ELG.alpha2p': ParameterArray(ELG.alpha2p, None, 3.7939949281999197),
#  'ELG.alpha4p': ParameterArray(ELG.alpha4p, None, 2.95373909368716),
#  'ELG.sn0p': ParameterArray(ELG.sn0p, None, -0.010393908723056202),
#  'ELG.sn2p': ParameterArray(ELG.sn2p, None, -0.537530388713716),
#  'LRG3.alpha0p': ParameterArray(LRG3.alpha0p, None, 5.434635240137469),
#  'LRG3.alpha2p': ParameterArray(LRG3.alpha2p, None, 1.8556467581498026),
#  'LRG3.alpha4p': ParameterArray(LRG3.alpha4p, None, 1.1577319838793163),
#  'LRG3.sn0p': ParameterArray(LRG3.sn0p, None, -0.08563860553817643),
#  'LRG3.sn2p': ParameterArray(LRG3.sn2p, None, -0.3534723578131269),
#  'LRG2.alpha0p': ParameterArray(LRG2.alpha0p, None, -5.9664312479379245),
#  'LRG2.alpha2p': ParameterArray(LRG2.alpha2p, None, 3.1841698968338252),
#  'LRG2.alpha4p': ParameterArray(LRG2.alpha4p, None, 3.107898711504444),
#  'LRG2.sn0p': ParameterArray(LRG2.sn0p, None, 0.44019631006728516),
#  'LRG2.sn2p': ParameterArray(LRG2.sn2p, None, -3.3888165356908484),
#  'LRG1.alpha0p': ParameterArray(LRG1.alpha0p, None, 5.976396034878667),
#  'LRG1.alpha2p': ParameterArray(LRG1.alpha2p, None, -1.1782019706572369),
#  'LRG1.alpha4p': ParameterArray(LRG1.alpha4p, None, -1.6434079016828382),
#  'LRG1.sn0p': ParameterArray(LRG1.sn0p, None, -0.08249321091822893),
#  'LRG1.sn2p': ParameterArray(LRG1.sn2p, None, -5.088349222596176),
#  'BGS.alpha0p': ParameterArray(BGS.alpha0p, None, -3.3625560135290233),
#  'BGS.alpha2p': ParameterArray(BGS.alpha2p, None, 2.090297080053394),
#  'BGS.alpha4p': ParameterArray(BGS.alpha4p, None, 1.0411540999398814),
#  'BGS.sn0p': ParameterArray(BGS.sn0p, None, 0.05186650934075394),
#  'BGS.sn2p': ParameterArray(BGS.sn2p, None, -2.048921961016258)}
